# %%
import TensorScatteringClass as ten
import numpy as np

t=ten.TensorScatteringClass(CIFfile='/home/spc93/spc_cifs/FeS2_Pa3_pyrites_cod_9000594_cifbib.cif', Site='S1');
t.PlotIntensityInPolarizationChannels('E1E1', lam=12.4/2.47, hkl=np.array([0,1,1]), hkln=np.array([1,0,0]), K=2, Time=1, Parity=1, mk=None, lk=None, sk=None, sigmapi='sigma')
#t.print_tensors()
####################### change energy back
t.PlotIntensityVsPolarizationAnalyserRotation('E1E1', lam=12.4/2.47, hkl=np.array([0,1,1]), hkln=np.array([1,0,0]), psideg=0., pol_eta_deg=np.arange(-90,91,5), pol_th_deg=48, stokesvec_swl=[0, 0, 1], K=2, Time=1, Parity=1)
#(process, lam, hkl, hkln, psideg, pol_eta_deg, pol_th_deg=45, stokesvec_swl=[0, 0, 1], K=None, Time=None, Parity=None, mk=None, lk=None, sk=None, savefile=None)

#ten.plt.savefig('/dls/science/users/spc93/tmp/FeS2_011.pdf')
#001, 011 look ok
#002 allowed
#t.print_tensors()
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/FeS2_Pa3_pyrites_cod_9000594_cifbib.cif
#                      Lattice:  5.417 5.417 5.417 90.00 90.00 90.00
#                    All sites:  Fe1, S1
#                Site selected:  S1
#                  Site vector:  0.385 0.385 0.385
#        No. of spacegroup ops:  24
#       No. of sym ops at site:  3
#  No. of equiv. sites in cell:  8
#    No. of pg ops for crystal:  24
#
# Tensor properties
#
#              Required parity:  Even
#           Required time sym.:  Even
#                          hkl:  [0.0, 1.0, 1.0]
#                 Site allowed:  No
#    Structure factor for site:  -0.00+-0.00i
#           Spacegroup allowed:  No
#               Tensor allowed:  Yes
#                       Parity:  Either
#                         Time:  Either
#                           PT:  Either
#
# Tensor properties
#
#              Required parity:  Even
#           Required time sym.:  Even
# ...

# %%
t.theta*180/np.pi
# Out:
# 40.943629604284574
