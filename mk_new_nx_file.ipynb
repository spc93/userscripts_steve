# %%
import nexusformat.nexus as nx

# %%
#nx = nx.nxload(filestr,'r') #### load one to use bits?

# %%
#nexpy demo
import numpy as np
x=y=np.linspace(0,2*np.pi,101)
X,Y=np.meshgrid(x,y)
z=np.sin(X)*np.sin(Y)
a=nx.NXdata(z,[y,x])
a.save('/home/spc93/tmp/function.nxs')
# Out:
# NXroot('root')

# %%
n = nx.nxload('/home/spc93/tmp/function.nxs')

# %%
print n.tree
# Out:
# root:NXroot
#   @HDF5_Version = '1.10.5'
#   @file_name = '/home/spc93/tmp/function.nxs'
#   @file_time = '2019-11-09T12:41:06.602703'
#   @h5py_version = '2.10.0'
#   @nexusformat_version = '0.4.20'
#   entry:NXentry
#     data:NXdata
#       @axes = ['axis1', 'axis2']
#       @signal = 'signal'
#       axis1 = float64(101)
#       axis2 = float64(101)
#       signal = float64(101x101)

# %%
n.plot()
