# %%
#imports

datadir='/dls/i16/data/2018/nt21479-1/'
cifpath='/home/spc93/spc_cifs/'

import sys
sys.path
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
sys.path.append('/dls_sw/i16/software/python/crystal')

# %matplotlib nbagg
from matplotlib.pyplot import *
from numpy import *
from dlstools import dataloader
d=dataloader.dlsloader(datadir+'%i.dat')
p=dataloader.tiffloader(d, lambda obj: datadir+obj.pilatus2m_path_template)

import TensorScatteringClass as ten
import Crystal as Cr

ciffile=cifpath+'CoCO3_icsd_61066.cif'
#t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
#t.PlotIntensityInPolarizationChannelsVsMagrot('NonResMag', lam=12.4/5.22, hkl=np.array([0,0,9]), hkln=np.array([1,0,0]), psideg=0, lk=np.array([0,0,0]), sk=np.array([1,0,0]), sigmapi='sigma')
#t.PlotIntensityVsPolarizationAnalyserRotation('NonResMag', lam = 12.4/5.22, hkl = np.array([0,0,9]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(361), K=None, Time=None, Parity=None, mk=None, lk=np.array([.0,0,0]), sk=np.array([.1,0,0]) , savefile=None)
#t.PlotIntensityVsPolarizationAnalyserRotation('Scalar', lam = 12.4/5.22, hkl = np.array([0,0,6]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(361), K=None, Time=None, Parity=None, mk=None, lk=np.array([.0,0,0]), sk=np.array([.1,0,0]) , savefile=None)
# Out:
# === Importing dlstools package
# /dls_sw/apps/scisoftpy/2.7/scisoftpy/_external/tifffile.py:284: UserWarning: ImportError: No module named '_tifffile'. Loading of some compressed images will be very slow. Tifffile.c can be obtained at http://www.lfd.uci.edu/~gohlke/
#   "ImportError: No module named '_tifffile'. "
# Could not import plotting routines
# No module named py4j.java_gateway
# === Need to obtain specfilewrapper.py and compatible specfile.so from ERSF PyMCA package in order to load spec files

# %%
figure()
d(712752)
plot(d.eta, d.sum)
d.Transmission
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.0002183

# %%
print '%.2g' % (1.98771e+6/0.002183)
# Out:
# 9.1e+08

# %%
figure()
d(712753
plot(d.eta, d.sum)
d.Transmission
# Out:
#   File "<ipython-input-9-9f0ad559db86>", line 3
#     plot(d.eta, d.sum)
#        ^
# SyntaxError: invalid syntax

# %%
figure()
d(712753)
plot(d.eta, d.sum)
d.Transmission
# Out:
# <img src="data:image/png;base64,..." width="640">
# 3.225e-06

# %%
print '%.2g' % (24369.3/3.225e-6)
# Out:
# 7.6e+09

# %%
ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
#t.PlotIntensityInPolarizationChannelsVsMagrot('NonResMag', lam=12.4/5.22, hkl=np.array([0,0,9]), hkln=np.array([1,0,0]), psideg=0, lk=np.array([0,0,0]), sk=np.array([1,0,0]), sigmapi='sigma')
#t.PlotIntensityVsPolarizationAnalyserRotation('NonResMag', lam = 12.4/5.22, hkl = np.array([0,0,9]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(361), K=None, Time=None, Parity=None, mk=None, lk=np.array([.0,0,0]), sk=np.array([.1,0,0]) , savefile=None)
t.PlotIntensityVsPolarizationAnalyserRotation('Scalar', lam = 12.4/5.22, hkl = np.array([0,0,6]), hkln = np.array([1,0,0]), psideg = 0, pol_eta_deg=range(-10,101), K=None, Time=None, Parity=None, mk=None, lk=np.array([.0,0,0]), sk=np.array([.1,0,0]) , savefile=None)
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="640">

# %%
figure()
d(712762)
plot(d.rotp, d.APD)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
figure()
d(712765)
plot(d.eta, d.roi2_sum)
d.Transmission
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.1088

# %%
33069.2/0.1088
# Out:
# 303944.85294117645

# %%
print '%.2g' % (33069.2/0.1088)
# Out:
# 3e+05

# %%
print '%.2g' % (3e5/7.6e9)
# Out:
# 3.9e-05

# %%
ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityInPolarizationChannelsVsMagrot('NonResMag', lam=12.4/5.22, hkl=np.array([0,0,9]), hkln=np.array([1,0,0]), psideg=0, lk=np.array([0,0,0]), sk=np.array([1,0,0]), sigmapi='sigma')
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="640">

# %%
figure()
d(712766)
plot(d.magrot, d.roi2_sum)
d.Transmission
# Out:
# <img src="data:image/png;base64,..." width="640">
# 0.1088

# %%
ciffile=cifpath+'CoCO3_icsd_61066.cif'
t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityVsPolarizationAnalyserRotation('NonResMag', lam = 12.4/5.22, hkl = np.array([0,0,9]), hkln = np.array([1,0,0]), psideg = 90, pol_eta_deg=range(-10,101), K=None, Time=None, Parity=None, mk=None, lk=np.array([.0,0,0]), sk=np.array([.1,0,0]) , savefile=None)
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="640">

# %%
figure()
d(712771)
plot(d.rotp, d.APD)
d(712772)
plot(d.rotp, d.APD)
# Out:
# <img src="data:image/png;base64,..." width="640">
