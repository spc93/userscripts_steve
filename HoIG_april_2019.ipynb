# %%
import sys
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from dlstools import *
from dlstools.pdnx import *
from matplotlib.pyplot import *
from dlstools.quickfit import *
from dlstools.dirty_fit import fit
from mpl_toolkits.mplot3d import Axes3D ########## was not previously required!!
#%matplotlib inline
# %matplotlib nbagg
p='/dls/i16/data/2019/cm22970-2/%i.nxs'
# Out:
# === Importing dlstools package

# %%
# %matplotlib nbagg

# %% [raw]
# YIG a=12.376
# Look for 008 at 8 keV
# L3=8.071

# %%
#(cut face, natural face, other natural fac) * 2
figure()
for scan in range(746355, 746361):
    n=pdnx(p % scan)
    plot(n.eta, n['sum'],label=str(scan))
legend(); grid(1); title('HoIG Laser cut and natural faces')
#cut face not bad but lower intensity and wider tails. Need to remove damaged region
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,u'HoIG Laser cut and natural faces')

# %%
n.nx.entry1.before_scan.diffractometer_sample.chi
# Out:
# NXfield(89.0500001212)

# %%
n.nx.entry1.before_scan.diffractometer_sample.delta
# Out:
# NXfield(60.1198887888)

# %%
figure()
for scan in range(746365, 746387):
    n=pdnx(p % scan)
    n['sy']=n.nx.entry1.before_scan.positions.sy
    gca(projection='3d').plot(n.sy, n.eta, n['sum'])
xlabel('sy'); ylabel('eta'); title('eta scans vs sy')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0.92,u'eta scans vs sy')

# %%
p='/dls/i16/data/2019/mm22314-1/%i.nxs'

# %%
n=pdnx(p % 746407)
# Out:
# === Error loading file /dls/i16/data/2019/cm22970-2/746407.nxs

# %%
n
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/1.7.0/64/envs/cctbx/lib/python2.7/site-packages/IPython/core/formatters.pyc in __call__(self, obj)
#     697                 type_pprinters=self.type_printers,
#     698                 deferred_pprinters=self.deferred_printers)
# --> 699             printer.pretty(obj)
#     700             printer.flush()
#     701             return stream.getvalue()
#
# /dls_sw/apps/python/anaconda/1.7.0/64/envs/cctbx/lib/python2.7/site-packages/IPython/lib/pretty.pyc in pretty(self, obj)
#     401                         if cls is not object \
#     402                                 and callable(cls.__dict__.get('__repr__')):
# --> 403                             return _repr_pprint(obj, self, cycle)
#     404
#     405             return _default_pprint(obj, self, cycle)
#
# ...

# %%
n.find('en')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-19-5288945fac00> in <module>()
# ----> 1 n.find('en')
#
# /dls_sw/i16/software/python/dlstools/pdnx.pyc in find(self, keystring)
#     111     def find(self, keystring=''):
#     112         'Return nexus fields and values for keystring'
# --> 113         for key_sequence in self.findkeys(keystring):
#     114             obj = self.nx
#     115             for key in key_sequence:
#
# /dls_sw/i16/software/python/dlstools/pdnx.pyc in findkeys(self, keystring)
#     106         global _keylist
#     107         _keylist=[]
# --> 108         self._find_key(self.nx, keystring)
#     109         return _keylist
#     110
#
# /dls_sw/apps/python/anaconda/1.7.0/64/envs/cctbx/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    3610             return object.__getattribute__(self, name)
# ...

# %%
n.find('delta')

# %% [markdown]
# # 15/7/2019 - polished and etched with HF
# Better than before polish but still not quite as good as facet.
# Try a different etch?

# %% [raw]
# #datadir('/dls/i16/data/2019/cm22970-3')
# #energy.si()
# #8 keV
# #HIG 008
# #more stable with no wait this time
# #784051-63
# #for sxval in frange(0.8,-1.6,-.2):
# #    pos sx sxval
# #    scancn eta .001 51 checkbeam pil3 1
#
# #align to side facet and ensure no shadowing
# #pos phi 45
# #>>> sx
# #sx : -1.2000mm (-2.5000:2.5000) mot(-50.000:50.000)
# #>>> sy
# #sy : 0.042400mm (-2.5000:2.5000) mot(-10.000:10.000)
# #>>> sz
# #sz : 14.750mm (5.0000:30.000) mot(-1000.5:1000.0)
# # eta scan 784073
#
# #>>> sx;sy;sz
# #sx : -1.0000mm (-2.5000:2.5000) mot(-50.000:50.000)
# #sy : -0.15740mm (-2.5000:2.5000) mot(-10.000:10.000)
# #sz : 14.750mm (5.0000:30.000) mot(-1000.5:1000.0)
# # eta scan 784072
#
# #784075-79
# sxini=sx()
# syini=sy()
# for sxyval in frange(0,2,.1):
#     pos sx sxini+sxyval
#     pos sy syini-sxyval
#     scancn eta .001 101 checkbeam pil3 1

# %%
import sys
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from dlstools import *
from dlstools.pdnx import *
from mpl_toolkits.mplot3d import Axes3D ########## was not previously required!!
#%matplotlib inline
# %matplotlib nbagg
p='/dls/i16/data/2019/cm22970-3/%i.nxs'

# %%
n=pdnx(p % 784051)

# %%
figure()
for scan in range(784051, 784064):
    n=pdnx(p % scan)
    n['sx']=n.nx.entry1.before_scan.positions.sx
    gca(projection='3d').plot(n.sx, n.eta, n['sum'])
xlabel('sx'); ylabel('eta'); title('eta scans vs sx')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0.92,u'eta scans vs sx')

# %%
figure()
for scan in range(784051, 784064):
    n=pdnx(p % scan)
    plot(n.eta-np.mean(n.eta), n['sum'],'g',label='001 or shadow')

for scan in range(784075, 784080):
    n=pdnx(p % scan)
    plot(n.eta-np.mean(n.eta), n['sum'],'r',label='001 or natural facet')
legend()  
grid(1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
n.find('Atten')
n.find('m2y')
# Out:
# .nx.entry1.before_scan.gains_atten.Atten : 	150.0
# .nx.entry1.before_scan.mirrors.m2y : 	2.4839125

# %% [markdown]
# ## After phosophric acid etch

# %% [raw]
# datadir('/dls/i16/data/2019/cm22970-3/')
# #YIG 008 - etched with phosphoric acid
# #a=12.376 look for 008
# #pos energy 8
# #listub
# #loadub 10
#
# #energy.si()
# #pos atten 150
#
# #sperp -.3 left edge of cut face
# #sperp 0.6 right edge of cut face
#
# #sample moving a bit - varnish still not quite dry? (after ~60 mins)
# #785740-49
# #or sperpval in frange(-0.8,1.2,0.2):
# #   pos sperp sperpvalenergy.monogap
# #   scancn eta .001 51 pil3 1
# #   go peak
# #still slight broadening
#
# #energy.monogap = 14
# #lookfor 8 keV dcmharminic 3
# #can't get beam through ppp??

# %%
figure()
for scan in range(785740, 785750):
    n=pdnx(p % scan)
    n['sperp']=n.nx.entry1.before_scan.positions.sperp
    gca(projection='3d').plot(n.sperp, n.eta, n['sum'])
xlabel('sperp'); ylabel('eta'); title('eta scans vs sx')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,0.92,u'eta scans vs sx')

# %%
figure()
for scan in range(785740, 785750):
    n=pdnx(p % scan)
    plot(n.eta-np.mean(n.eta), n['sum'])
# Out:
# <img src="data:image/png;base64,..." width="495">

# %%
n.nx.entry1.before_scan.positions.sperp
# Out:
# NXfield(0.000147685433148)

# %%
n.find('Base_z')
n.find('table_vert')
# Out:
# .nx.entry1.before_scan.positions.Base_z : 	-0.1759675
# .nx.entry1.before_scan.positions.table_vert : 	-7.0154

# %%
n
# Out:
#     TimeFromEpoch        TimeSec  count_time  delta_axis_offset        eta  ic1monitor         kap     kdelta      kgam       kmu        kphi        kth  maxval   maxx  maxy  path          rc    sum
# 0    1.564568e+09  416294.887171         1.0                8.8  30.047553  963.384418 -135.117019  60.119889  0.000183  0.000002  112.277575  87.325128     7.0  243.0  92.0   1.0  298.415649   64.0
# 1    1.564568e+09  416296.946359         1.0                8.8  30.048553  963.182928 -135.117019  60.119889  0.000183  0.000006  112.277575  87.326128    10.0  244.0  92.0   2.0  298.402466   65.0
# 2    1.564568e+09  416298.990100         1.0                8.8  30.049553  963.132861 -135.117019  60.119889  0.000178  0.000002  112.277575  87.327128     8.0  244.0  91.0   3.0  298.389709   73.0
# ...
