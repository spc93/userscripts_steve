# %%
import sys
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from dlstools import *
from dlstools.pdnx import *
from matplotlib.pyplot import *

# %matplotlib inline

p='/dls/i16/data/2020/cm26473-1/%i.nxs'

# %%
n=pdnx(p % 821293)
print(n.nx.entry1.title)
n
# Out:
# scan kthZebra 55.991500212163 56.991500212163 0.001 kthZebraPil3 0.05
#       count_time  filepath   kthZebra
# 0          0.047       0.0  55.991197
# 1          0.047       0.0  55.991739
# 2          0.047       0.0  55.992490
# 3          0.047       0.0  55.993173
# ...          ...       ...        ...
# 997        0.047       0.0  56.986470
# 998        0.047       0.0  56.987524
# 999        0.047       0.0  56.988533
# 1000       0.047       0.0  56.989593
#
# [1001 rows x 3 columns]

# %%
n=pdnx(p % 821296)
print(n.nx.entry1.title)
n
# Out:
# scan kphiZebra -0.5 0.5 0.001 kphiZebraPil3 0.05
#       count_time  filepath  kphiZebra
# 0          0.047       0.0     -0.499
# 1          0.047       0.0     -0.499
# 2          0.047       0.0     -0.497
# 3          0.047       0.0     -0.497
# ...          ...       ...        ...
# 997        0.047       0.0      0.499
# 998        0.047       0.0      0.499
# 999        0.047       0.0      0.500
# 1000       0.047       0.0      0.501
#
# [1001 rows x 3 columns]

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   entry1:NXentry
#     before_scan:NXcollection
#       PPR:NXcollection
#         ppchi = -44.99998643
#         pppiezo1 = 0.0
#         pppiezo2 = 12345.012359999999
#         ppth1 = -0.0007169474
#         ppth2 = -11.9997316842
#         ppz1 = 12.0
#         ppz2 = 12.0
#       alpha:NXcollection
#         alpha = -0.04505193411503882
#       beamline_slits:NXcollection
#         s1xcentre = -0.0055
#         s1xgap = 2.511
#         s1ycentre = 0.001
#         s1ygap = 1.0
#         s2xcentre = -0.00079375
#         s2xgap = 4.9988625
#         s2ycentre = 0.499
#         s2ygap = 20.0
#         s3xcentre = 2.69725
#         s3xgap = 25.0015
#         s3ycentre = -0.682
#         s3ygap = 20.125
#         s4xcentre = -5.875
#         s4xgap = 36.6504
#         s4ycentre = 0.0
#         s4ygap = 28.005
#         shtr3x = 11.93
#         shtr3y = 4.25
#       beta:NXcollection
#         beta = 0.04505193411503882
#       d3a:NXcollection
#         d3a = 90.0
#       d3d:NXcollection
#         d3d = 33.0
#       delta_offset:NXcollection
#         delta_offset = 0.0
#       dettrans:NXcollection
#         dettrans = 0.0
#       diffractometer_sample:NXcollection
#         azih = 0.8164965809277261
#         azik = -0.408248290463863
#         azil = -0.40824829046386296
#         beta = -9999999.99999999
#         chi = 89.99992691245329
#         delta = 0.0
#         delta_axis_offset = 0
#         en = 5.276548714053815
#         eta = -0.045051934117701364
#         gam = 5.077e-07
#         h = 1.5137138740761255e-08
#         k = 3.3391426564785788e-09
#         kphi = -0.48
#         l = 2.6935037719305227e-08
#         mu = 2.0585e-06
#         phi = -57.5280519341177
#       dummypd:NXcollection
#         x = 600.0
#         y = 0.0
#         z = 0.0
#       gains_atten:NXcollection
#         Atten = 0.0
#         Transmission = 1.0
#         diode_gain = 0
#         ic1_gain = 3
#         ic2_gain = 3
#       jjslits:NXcollection
#         s5xgap = 5.0
#         s5xtrans = -0.0001
#         s5ygap = 5.0002
#         s5ytrans = 0.0001
#         s6xgap = 5.0116
#         s6xtrans = 3.5152
#         s6ygap = 5.0011
#         s6ytrans = 8.5482
#       lakeshore:NXcollection
#         Ta = 0.0
#         Tb = 0.0
#         Tc = 0.0
#         Td = 0.0
#         Tset = 0.0
#       mirrors:NXcollection
#         m1piezo = 0.0
#         m1pitch = 3.810325123477
#         m1roll = 0.097119223882
#         m1x = 1.659339500001
#         m1y = -2.4061375
#         m1yaw = 0.399830864686
#         m2bender = 305.0
#         m2pitch = 3.811319573454
#         m2roll = 0.39900140536
#         m2x = 14.447000000001
#         m2y = -8.9635375
#         m2yaw = -0.037803167776
#         m3pitch = -0.00011980000000000324
#         m3x = -4.0002474999999995
#         m4pitch = 1.940000000000275e-05
#         m4x = 4.0004349999999995
#       mono:NXcollection
#         T1dcmSi111 = 97.81770979947932
#         T2dcmSi111 = 11.696657642060144
#         bragg = -21.7315
#         dcmfinepitch = 0.0
#         dcmlat = -40.937
#         dcmpitch = -21.1574176
#         dcmroll1 = 19.9522492
#         dcmroll2 = 18.7135312
#         en = 5.276548714053815
#         perp = 40.785
#       mrwolf:NXcollection
#         Day = 29
#         Hours = 15
#         Minutes = 31
#         Month = 6
#         Seconds = 15
#         Year = 2020
#       offsets:NXcollection
#         base_z_offset = -14.400250623564085
#         idgap_offset = 0.5735778741866069
#         m1y_offset = -15.988239373564085
#         m2_coating_offset = 0
#         m2y_offset = -22.545639373564086
#         ztable_offset = -21.043931873564084
#       p2:NXcollection
#         p2rot = 6.67755
#         p2x1 = -5.02625
#         p2y1 = 185.6515625
#         p2zbot = 125.8384425
#         p2ztop = -41.4271875
#       pa:NXcollection
#         stokes = 0.00012
#         thp = -0.0014
#         tthp = 0.929559
#         zp = 9.845500000000001
#       positions:NXcollection
#         Base_z = -0.81814875
#         Base_z1 = -0.81814875
#         Base_z2 = -0.81814575
#         Base_z3 = -0.81814575
#         base_y = 21.965
#         spara = -3.066955493970091e-05
#         sperp = 0.00013805570759588563
#         sx = 0.0001
#         sy = 0.0001
#         sz = 11.0
#         table_horiz = 20.466874999999998
#         table_vert = -7.46183
#       ppchi:NXcollection
#         ppchi = -44.999994057
#       ppchitemp:NXcollection
#         ppchitemp = 24.8
#       pppitch:NXcollection
#         pppitch = 0.0159
#       ppth1:NXcollection
#         ppth1 = -0.0007169474
#       ppth1temp:NXcollection
#         ppth1temp = 24.7
#       ppth2:NXcollection
#         ppth2 = -11.9997316842
#       ppth2temp:NXcollection
#         ppth2temp = 25.3
#       ppx:NXcollection
#         ppx = 9.2
#       ppy:NXcollection
#         ppy = -8.0423
#       ppyaw:NXcollection
#         ppyaw = -0.0803
#       ppz1:NXcollection
#         ppz1 = 12.0
#       ppz1temp:NXcollection
#         ppz1temp = 24.6
#       ppz2:NXcollection
#         ppz2 = 12.0
#       ppz2temp:NXcollection
#         ppz2temp = 25.0
#       psi:NXcollection
#         psi = nan
#       s7xgap:NXcollection
#         s7xgap = 5.0
#       s7xtrans:NXcollection
#         s7xtrans = 0.044
#       s7ygap:NXcollection
#         s7ygap = 4.9999
#       s7ytrans:NXcollection
#         s7ytrans = 0.0402
#       source:NXcollection
#         Uharmonic = 5
#         idgap = 9.46995
#         rc = 38.000816345214844
#       xtlinfo:NXcollection
#         UB11 = 0.0
#         UB12 = 0.8173990771087457
#         UB13 = -0.8173990771087457
#         UB21 = 0.6674035517127693
#         UB22 = 0.6674035517127694
#         UB23 = 0.6674035517127694
#         UB31 = 0.9438511544081721
#         UB32 = -0.47192557720408607
#         UB33 = -0.471925577204086
#         a = 5.435390206058785
#         alpha1 = 90.0
#         alpha2 = 90.0
#         alpha3 = 90.0
#         b = 5.435390206058785
#         c = 5.435390206058785
#     definition = NXmx
#     end_time = '2020-06-29T15:32:06.037+01:00'
#     entry_identifier = 821296
#     features = [                   3                    6 -4539647395532570642]
#     instrument:NXinstrument
#       attenuator:NXattenuator
#         attenuator_transmission = 1.0
#       kphiZebra:NXpositioner
#         kphiZebra = float64(1001)
#           @axis = '1'
#           @label = '1'
#           @local_name = 'kphiZebra.kphiZebra'
#           @primary = '1'
#           @target = '/entry1/instrument/kphiZebra/kphiZebra'
#       kphiZebraPil3:NXdetector
#         count_time = float64(1001)
#           @local_name = 'kphiZebraPil3.count_time'
#         data_file:NXnote
#           file_name =
#             @data_filename = 1
#         image_data =
#           @data_filename = 1
#           @signal = 1
#           @target = '/entry1/instrument/kphiZebraPil3/image_data'
#         local_name = kphiZebraPil3
#       name = i16
#       source:NXsource
#         current = 38.0008
#           @units = 'mA'
#         energy = 3.0009
#           @units = 'GeV'
#         name = DLS
#         probe = x-ray
#         type = Synchrotron X-Ray Source
#       transformations:NXtransformations
#         delta = 0.0
#           @axis = '1'
#           @depends_on = 'entry1/instrument/transformations/gamma'
#           @local_name = 'kdelta.kdelta'
#           @transformation_type = 'rotation'
#           @units = 'deg'
#           @vector = [0. 1. 0.]
#         gamma = -3.529e-06
#           @axis = '1'
#           @depends_on = '.'
#           @local_name = 'kgam.kgam'
#           @transformation_type = 'rotation'
#           @units = 'deg'
#           @vector = [1. 0. 0.]
#     kphiZebraPil3:NXdata
#       image_data -> /entry1/instrument/kphiZebraPil3/image_data
#       kphiZebra -> /entry1/instrument/kphiZebra/kphiZebra
#     measurement:NXdata
#       @axes = 'kphiZebra'
#       @signal = 'filepath'
#       count_time = float64(1001)
#       filepath = float64(1001)
#       kphiZebra = float64(1001)
#     program_name = GDA 9.17.0
#     sample:NXsample
#       beam:NXbeam
#         incident_energy = 5.276548714053815
#           @axis = '1'
#           @local_name = 'en.en'
#         incident_wavelength = 0.23497213662197847
#           @units = 'nm'
#       depends_on = /entry1/sample/transformations/phi
#       name = Default Sample
#       transformations:NXtransformations
#         kappa = -134.7557519925
#           @axis = '1'
#           @depends_on = 'entry1/sample/transformations/theta'
#           @local_name = 'kap.kap'
#           @transformation_type = 'rotation'
#           @units = 'deg'
#           @vector = [ 0.          0.64278761 -0.76604443]
#         mu = 2.0585e-06
#           @axis = '1'
#           @depends_on = '.'
#           @local_name = 'kmu.km'
#           @transformation_type = 'rotation'
#           @units = 'deg'
#           @vector = [1. 0. 0.]
#         phi = -0.48
#           @axis = '1'
#           @depends_on = 'entry1/sample/transformations/kappa'
#           @local_name = 'kphi.kphi'
#           @transformation_type = 'rotation'
#           @units = 'deg'
#           @vector = [0. 1. 0.]
#         theta = 57.0
#           @axis = '1'
#           @depends_on = 'entry1/sample/transformations/m'
#           @local_name = 'kth.kth'
#           @transformation_type = 'rotation'
#           @units = 'deg'
#           @vector = [0. 1. 0.]
#       ub_matrix = float64(1x3x3)
#       unit_cell = [[ 5.43539021  5.43539021  5.43539021 90.         90.         90.        ]]
#         @angle_units = 'deg'
#         @length_units = 'angstrom'
#     scan_command = scan kphiZebra -0.5 0.5 0.001 kphiZebraPil3 0.05
#     scan_dimensions = 1001
#     scan_identifier = 1962c70d-d11d-4d74-9efb-ab0018d45009
#     start_time = 2020-06-29T15:31:11.606+01:00
#     title = scan kphiZebra -0.5 0.5 0.001 kphiZebraPil3 0.05
#     title_old = Scan of sample with GDA
#     user01:NXuser
#       username = i16user

# %%
n.find('image_data')
# Out:
# .nx.entry1.instrument.kphiZebraPil3.image_data :
# .nx.entry1.kphiZebraPil3.image_data :

# %%
a=n.nx.entry1.kphiZebraPil3.image_data

# %%
a.data_filename
# Out:
# 1
