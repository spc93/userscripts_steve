# %%
#23-24 june 2017 /2017/cm16772-2/ NeXus & .dat files
# sgome not in NeXus file - need to use .dat files

# cvscan tests 18dec2020 added

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools import dataloader
from matplotlib.pyplot import *
#import matplotlib.pyplot as plt
path='/dls/i16/data/2017/cm16772-2/'
d=dataloader.dlsloader(path+'%i.dat')

#%matplotlib inline
# %matplotlib notebook
#%matplotlib nbagg

# %%
d(641574)
# Out:
# #641574  sgome kphi kap kth kmu kdelta kgam delta_axis_offset TimeSec ic1monitor rc count_time path maxx maxy maxval sum metadata

# %% [raw]
# #day24june17a.py
#
# #set up smargon motors
# #sgphi=SingleEpicsPositionerClass('sgphi','BL16I-MO-SGON-01:PHI.VAL','BL16I-MO-SGON-01:PHI.RBV','BL16I-MO-SGON-01:PHI.DMOV','BL16I-MO-SGON-01:PHI.STOP','deg','%.4f')
# #sgome=SingleEpicsPositionerClass('sgome','BL16I-MO-SGON-01:OMEGA.VAL','BL16I-MO-SGON-01:OMEGA.RBV','BL16I-MO-SGON-01:OMEGA.DMOV','BL16I-MO-SGON-01:OMEGA.STOP','deg','%.4f')
# #sgchi=SingleEpicsPositionerClass('sgchi','BL16I-MO-SGON-01:CHI.VAL','BL16I-MO-SGON-01:CHI.RBV','BL16I-MO-SGON-01:CHI.DMOV','BL16I-MO-SGON-01:CHI.STOP','deg','%.4f')
#
# #sample is drifting a bit (on the wax?)
# #641572
# #scancn mu .01 41 pil .5
# #go maxval
# #73
# #scancn mu .001 41 pil .5
# #go maxval
# #74
# #scancn sgome 0.001 41 pil .5
# #go maxval
# #75
# #scancn sgome 0.001 41 w 2 pil .5
# #go maxval
# #76
# #scancn sgphi 0.001 41 pil .5
# #go maxval
# #77
# #scancn sgphi 0.001 41 w 2 pil .5
# #79
#
# #641586
# while True:
# 	pos mu 43.48
# 	scancn mu .01 41 pil .5
# 	go maxval
# 	scancn mu .001 41 pil .5
# 	go maxval
# 	scancn sgome 0.001 41 pil .5
# 	go maxval
# 	scancn sgome -0.001 41 pil .5
# 	go maxval
# 	scancn sgphi 0.001 41 pil .5
# 	go maxval
# 	scancn sgphi -0.001 41 pil .5
# 	go maxval

# %%
#zero at +ve peak centres

#for i in range(641587, 641610):
#    print(i, d(i).cmd)



figure()
subplot(3,1,1)
icount = 0
#for i in range(641587, 641630, 6): #mu scans
#for i in range(641589, 641800, 6): #sgome scans
for i in range(641588, 641900, 6): #sgome scans  (bidirectional)
    d(i)
    #print(d)
    meanval = np.mean(d.sgome)
    plot(d.sgome - meanval, d.sum, 'k', linewidth=.3)
    d(i+1)
    #print(d)
    plot(d.sgome - meanval, d.sum, 'r', linewidth=.3)  
    icount += 1
xlabel('Smargon Omega')
ylabel('Counts'); title(d.cmd); grid(1)
print(icount)


#figure()
subplot(3,1,2)
icount = 0
for i in range(641590, 641900, 6): #sgphi scans (bidirectional)
    d(i)
    #print(d.cmd)
    #print(d)
    meanval = np.mean(d.sgphi)
    plot(d.sgphi - meanval, d.sum, 'k', linewidth=.3)
    d(i+1)
    #print(d.cmd)
    #print(d)
    plot(d.sgphi - meanval, d.sum, 'r', linewidth=.3)  
    icount += 1
xlabel('Smargon Phi')
ylabel('Counts'); title(d.cmd); grid(1)
print(icount)


#figure()
subplot(3,1,3)
icount = 0
for i in range(641587, 641900, 6): #sgome scans  (bidirectional)
    d(i)
    #print(d)
    #meanval = np.mean(d.sgome)
    plot(d.mu, d.sum, 'k', linewidth=.3)
    icount += 1
xlabel('Newport mu')
ylabel('Counts'); title(d.cmd); grid(1)
print(icount)

gcf().tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="537">
# 52
# 52
# 53

# %%
#after plotting
#stretch
#gcf().tight_layout()
#savefig('/home/spc93/tmp/smargon1.pdf')

# %%
import sys
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from dlstools import *
from dlstools.pdnx import *
from matplotlib.pyplot import *

from dlstools.quickfit import *
import matplotlib.pyplot as plt

from IPython.core.display import HTML
pd.set_option('display.max_rows',8)

#%matplotlib inline
# %matplotlib notebook
#%matplotlib nbagg

p='/dls/i16/data/2020/mm25392-2/%i.nxs'

# %%
#scans with sgomeZebra etc are cvscans
#all test scans are here
#looks like they worked but with no hdf5 file writing
for scan in range(873167,873184):
    try:
        n = pdnx(p % scan)
        print '#', scan
        print(n.nx.entry1.scan_command)
        #display(HTML(n.to_html()))
        print(n)

    except:
        pass
# Out:
# === Error loading file /dls/i16/data/2020/mm25392-2/873167.nxs
# # 873167
# === Error loading file /dls/i16/data/2020/mm25392-2/873168.nxs
# # 873168
# === Error loading file /dls/i16/data/2020/mm25392-2/873169.nxs
# # 873169
# === Error loading file /dls/i16/data/2020/mm25392-2/873170.nxs
# # 873170
# # 873171
# scan sgomegaZebra 0 10 0.01 smargonZebraPil3 0.1
#    count_time  sgomegaZebra  filepath
# 0       0.097           0.0       0.0
# 1       0.097           0.0       0.0
# 2       0.097           0.0       0.0
# 3       0.097           0.0       0.0
# 4       0.097           0.0       0.0
# 5       0.097           0.0       0.0
# === Error loading file /dls/i16/data/2020/mm25392-2/873172.nxs
# # 873172
# === Error loading file /dls/i16/data/2020/mm25392-2/873173.nxs
# # 873173
# === Error loading file /dls/i16/data/2020/mm25392-2/873174.nxs
# # 873174
# === Error loading file /dls/i16/data/2020/mm25392-2/873175.nxs
# # 873175
# # 873176
# scan kphiZebra 56.045 58.045 0.01 kphiZebraPil3 0.1
#      count_time  filepath  kphiZebra
# 0         0.097       0.0     56.045
# 1         0.097       0.0     56.055
# 2         0.097       0.0     56.065
# 3         0.097       0.0     56.075
# ..          ...       ...        ...
# 197       0.097       0.0     58.015
# 198       0.097       0.0     58.026
# 199       0.097       0.0     58.035
# 200       0.097       0.0     58.046
#
# [201 rows x 3 columns]
# # 873177
# scan kphiZebra 56.045 58.045 0.01 kphiZebraPil3 0.1
#      count_time  filepath  kphiZebra
# 0         0.097       0.0     56.045
# 1         0.097       0.0     56.056
# 2         0.097       0.0     56.066
# 3         0.097       0.0     56.076
# ..          ...       ...        ...
# 197       0.097       0.0     58.016
# 198       0.097       0.0     58.027
# 199       0.097       0.0     58.036
# 200       0.097       0.0     58.046
#
# [201 rows x 3 columns]
# === Error loading file /dls/i16/data/2020/mm25392-2/873178.nxs
# # 873178
# === Error loading file /dls/i16/data/2020/mm25392-2/873179.nxs
# # 873179
# # 873180
# scan sgphiZebra 0 10 0.01 smargonZebraPil3 0.1
#     count_time  sgphiZebra  filepath
# 0        0.097         0.0       0.0
# 1        0.097         0.0       0.0
# 2        0.097         0.0       0.0
# 3        0.097         0.0       0.0
# ..         ...         ...       ...
# 6        0.097         0.0       0.0
# 7        0.097         0.0       0.0
# 8        0.097         0.0       0.0
# 9        0.097         0.0       0.0
#
# [10 rows x 3 columns]
# # 873181
# scan sgomegaZebra 0 10 0.01 smargonZebraPil3 0.1
#       count_time  sgomegaZebra  filepath
# 0          0.097           0.0       0.0
# 1          0.097           0.0       0.0
# 2          0.097           0.0       0.0
# 3          0.097           0.0       0.0
# ...          ...           ...       ...
# 997        0.097           0.0       0.0
# 998        0.097           0.0       0.0
# 999        0.097           0.0       0.0
# 1000       0.097           0.0       0.0
#
# [1001 rows x 3 columns]
# # 873182
# scan sgomegaZebra 0 1 0.01 smargonZebraPil3 0.1
#    count_time  sgomegaZebra  filepath
# 0       0.097           0.0       0.0
# # 873183
# scan sgomegaZebra 0 1 0.01 smargonZebraPil3 0.1
#    count_time  sgomegaZebra  filepath
# 0       0.097           0.0       0.0
