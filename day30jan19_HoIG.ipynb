# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 
p='/dls/i16/data/2019/cm22970-1/%i.nxs'
# Out:
# === Importing dlstools package

# %% [markdown]
# # HiIG scans

# %% [raw]
# #day30jan19b.py
# #'/dls/i16/data/2019/cm22970-1'
# #energy 8 keV
# #HoIG
# #setlat('HoIG',12.376)
#
# #hh=[0,0,8]; pos delta c2th(hh) eta c2th(hh)/2+20
# #hh=[4,2,0]; pos delta c2th(hh) eta c2th(hh)/2+20
# #hh=[4,4,0]; pos delta c2th(hh) eta c2th(hh)/2+20
# #nothing!
#
# #pos atten 20
# #scan delta 40 115 1 eta 40 .5 pil3 .5    #found peak - (12,6,0)
# #734746, 47
# #scancn eta .001 81 pil3 .5
#
# #trialub
#
# #734748
# #scan sr2 [6 6 0 0] [6 6 0 360] [0 0 0 .5] pil3 .5 scroi # one peak - ok
#
# #734779
# #for phival in frange(-120, -20, 5):
# #    pos phi phival
# #    con phi
# #    pos hkl [8 0 0]
# #    scancn eta .005 81 pil3 .5 lcroi

# %%
#21,6,0 symmetric reflection from large facet 8 keV
n=pdnx(p % 734746)
#n.plt('eta','sum');
figure(); plot(n.eta, n['sum']); title(n.scan); grid(1)
n=pdnx(p % 734747)
plot(n.eta, n['sum']); title(n.scan); grid(1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
n.find('sx')
n.find('sy')
n.find('sz')
# Out:
# .nx.entry1.before_scan.positions.sx : 	0.8088
# .nx.entry1.before_scan.positions.sy : 	-0.588
# .nx.entry1.before_scan.positions.sz : 	11.02187

# %%
n=pdnx(p % 734748)
n.plt('azimuthal', 'roi1_sum', logy=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#8,0,0 reflection after realigning (first was not 12,6,0)
#two eta scans for each of three positions on sample
#n.plt('eta','sum');
#width ~ 0.007 - very good!
figure(); 
n=pdnx(p % 734847);plot(n.eta, n['sum']); title(n.scan); grid(1)
n=pdnx(p % 734848); plot(n.eta, n['sum']); title(n.scan); grid(1)
n=pdnx(p % 734849); plot(n.eta, n['sum']); title(n.scan); grid(1)
n=pdnx(p % 734850); plot(n.eta, n['sum']); title(n.scan); grid(1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Mica scans

# %% [raw]
# ########## mica ############
#
# #direct beam is 950 uA
#
# #734891-917
# #odd order peaks only harmonics
# #pos do 0
# #pos x1 1
# #for ll in range(2,20,2):
# #    pos hkl [0 0 ll]
# #    scancn eta .01 21 diode
# #    go maxval
# #    scancn delta .1 11 diode
# #    go peak
# #    scancn eta .0025 81 diode

# %%
c=20.1

# %%
figure()
diode_direct = 950
for scan in range(734893,734917+1,3):
    n=pdnx(p % scan); 
    print n.scan
    plot(n.eta, n.diode/diode_direct); title(n.scan); grid(1); xlabel('eta'); ylabel('Reflectivity')
# Out:
# <img src="data:image/png;base64,..." width="640">
# /dls/i16/data/2019/cm22970-1/734893.nxs
# scan eta 4.5989792982847195 4.798979298284719 0.0025 diode
# /dls/i16/data/2019/cm22970-1/734896.nxs
# scan eta 9.071802551374669 9.271802551374668 0.0025 diode
# /dls/i16/data/2019/cm22970-1/734899.nxs
# scan eta 13.590628650413914 13.790628650413913 0.0025 diode
# /dls/i16/data/2019/cm22970-1/734902.nxs
# scan eta 18.207548553340466 18.40754855334047 0.0025 diode
# /dls/i16/data/2019/cm22970-1/734905.nxs
# scan eta 22.94034494380383 23.140344943803832 0.0025 diode
# /dls/i16/data/2019/cm22970-1/734908.nxs
# scan eta 27.895999568626017 28.09599956862602 0.0025 diode
# /dls/i16/data/2019/cm22970-1/734911.nxs
# scan eta 33.04639427293869 33.246394272938694 0.0025 diode
# /dls/i16/data/2019/cm22970-1/734914.nxs
# scan eta 38.51847570448796 38.718475704487965 0.0025 diode
# /dls/i16/data/2019/cm22970-1/734917.nxs
# scan eta 44.444417902215626 44.64441790221563 0.0025 diode

# %% [markdown]
# ## URu2Si2

# %% [raw]
# ######## URu2Si2
# #pos hkl [0 0 5.989]
#
# #pos ss [.05 .5]
# #pos atten 55
#
# #734937
# #map out sample surface to look for 006 extra peak
# sxcen=1.1
# sycen=0
# pos hkl [0 0 5.989]
# scan sx sxcen-.6 sxcen+.6 .05 sy sycen-.6 sycen+.6 .05 checkbeam pil3 .5 lcroi
#
# i=0
# for syval in frange(sycen-.6, sycen+.6,.05):
#     for sxval in frange(sxcen-.6, sxcen+.6,.05):
#         i+=1
#         pos sx sxval sy syval
#         pos hkl [0 0 5.989]
#         scancn l .001 41 checkbeam pil3 .5 lcroi

# %%
#2d grid scan at position of spurious peak
n = pdnx(p % 734937)
pcolor(n.nx.entry1.measurement.sx, n.nx.entry1.measurement.sy, n.nx.entry1.measurement.roi2_sum); colorbar();
xlabel('sx (mm)'); ylabel('sy (mm)'); title('# 734937')
# Out:
# Text(0.5,1,u'# 734937')

# %%
#l scan at each sample position sx, sy
figure()
for scan in range(734938, 734938+625):
    n = pdnx(p % scan)
    semilogy(n.l, n.roi2_sum)
