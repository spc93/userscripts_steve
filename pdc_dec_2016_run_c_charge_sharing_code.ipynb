# %% [raw]
# #look at data from dec_2016 first
# #all processed data in MT16227-1/processing
# #/dls/i16/data/2017/mt16227-1/processing/12_12_2016/Sorted

# %%
#processing single file for charge-sharing energy plots with c program read_timepix_events_1.2
#maxToAdiff, maxPixdiff 
import os
cfile='/dls/science/users/spc93/c/read_timepix_events_1.3'
strprms = ' 80 5'

root_top_in='/dls/i16/data/2017/mt16227-1/processing/12_12_2016/Sorted/20161212_I16_W2J2_TOP_Decoded_Sorted/'
root_bot_in='/dls/i16/data/2017/mt16227-1/processing/12_12_2016/Sorted/20161212_I16_W5I6_BOT_Decoded_Sorted/'
root_top_out='/dls/i16/data/2017/mt16227-1/processing/12_12_2016/Sorted/20161212_I16_W2J2_TOP_Decoded_Sorted_read_timepix_events_1.3/'
root_bot_out='/dls/i16/data/2017/mt16227-1/processing/12_12_2016/Sorted/20161212_I16_W5I6_BOT_Decoded_Sorted_read_timepix_events_1.3/'

root_folders = [{'in':root_top_in, 'out':root_top_out}, {'in':root_bot_in, 'out':root_bot_out}]

for folders in root_folders:
    print folders['in']
    print folders['out']

    file_list=os.listdir(folders['in']); file_list.sort();
    icounter = 0
    for file in file_list:
        icounter += 1
        infile = folders['in'] + file
        outfile = folders['out'] + file
        cmd=cfile + ' ' + infile + ' ' + outfile + strprms
        print icounter, cmd
        os.system(cmd)
# Out:
# /dls/i16/data/2017/mt16227-1/processing/12_12_2016/Sorted/20161212_I16_W2J2_TOP_Decoded_Sorted/
# /dls/i16/data/2017/mt16227-1/processing/12_12_2016/Sorted/20161212_I16_W2J2_TOP_Decoded_Sorted_read_timepix_events_1.3/
# 1 /dls/science/users/spc93/c/read_timepix_events_1.3 /dls/i16/data/2017/mt16227-1/processing/12_12_2016/Sorted/20161212_I16_W2J2_TOP_Decoded_Sorted/long5_2016-12-12-15-49-23.483445_decoded_Sorted.dat /dls/i16/data/2017/mt16227-1/processing/12_12_2016/Sorted/20161212_I16_W2J2_TOP_Decoded_Sorted_read_timepix_events_1.3/long5_2016-12-12-15-49-23.483445_decoded_Sorted.dat 80 5
# 2 /dls/science/users/spc93/c/read_timepix_events_1.3 /dls/i16/data/2017/mt16227-1/processing/12_12_2016/Sorted/20161212_I16_W2J2_TOP_Decoded_Sorted/long5_2016-12-12-15-50-24.060502_decoded_Sorted.dat /dls/i16/data/2017/mt16227-1/processing/12_12_2016/Sorted/20161212_I16_W2J2_TOP_Decoded_Sorted_read_timepix_events_1.3/long5_2016-12-12-15-50-24.060502_decoded_Sorted.dat 80 5
# ...
