# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
from mpl_toolkits.mplot3d import Axes3D ########## was not previously required!!
# %matplotlib notebook 
p='/dls/i16/data/2019/mt20742-2/%i.nxs'

# %%
n=pdnx(p % 735671)
n.find('sz')
print n.scan
n.nx.entry1.before_scan.positions.sz
# Out:
# .nx.entry1.before_scan.positions.sz : 	7.66471
# .nx.entry1.roi2.sz :
# .nx.entry1.instrument.sz : 	sz
# .nx.entry1.instrument.sz.sz : 	[7.65 7.7  7.75 ... 9.05 9.1  9.15]
# .nx.entry1.roi1.sz :
# .nx.entry1.measurement.sz : 	[7.65 7.7  7.75 ... 9.05 9.1  9.15]
# .nx.entry1.pil3_100k.sz :
# /dls/i16/data/2019/mt20742-2/735671.nxs
# scan sz 7.65 9.15 0.05 pil3_100k 1 roi2 roi1
# NXfield(7.66471)

# %%
n=pdnx(p % 735654)
n.find('incident_energy')
#print n.nx.tree
# Out:
# .nx.entry1.sample.beam.incident_energy : 	11.2190024561

# %%
figure(); 
for scan in range(735675, 735791, 2):
    n=pdnx(p % scan)
    n['Ta'] = n.nx.entry1.before_scan.lakeshore.Ta
    gca(projection='3d').plot(n.Ta, n.eta, n.roi2_sum) 
gca().set_zlim3d(300000, 600000)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /dls_sw/i16/software/python/dlstools/pdnx.py:62: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   setattr(self,'nx',_nx)

# %%
figure(); 
for scan in range(735675+1, 735791, 2):
    n=pdnx(p % scan)
    n['Ta'] = n.nx.entry1.before_scan.lakeshore.Ta
    gca(projection='3d').plot(n.Ta, n.sz, n.roi2_sum) 
#gca().set_zlim3d(300000, 600000)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
figure(); 
for scan in range(735795, 735815):
    n=pdnx(p % scan)
    n['energy'] = n.nx.entry1.sample.beam.incident_energy
    gca(projection='3d').plot(n.energy, n.eta, n.roi2_sum) 
#gca().set_zlim3d(300000, 600000)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
n
# Out:
#     TimeFromEpoch        TimeSec  beamOK  count_time  delta_axis_offset        eta  ic1monitor         kap     kdelta  kgam  kmu        kphi        kth     maxval  maxx   maxy  path          rc  roi2_maxval  roi2_maxx  roi2_maxy  roi2_sum          sum         energy
# 0    1.549020e+09  861635.895340     1.0         2.0                8.8  20.009284  677.730998 -110.954414  41.518567   0.0  0.0  136.278506  63.068988   773999.0  10.0   79.0   1.0  300.832153         76.0       47.0       49.0  120570.0   59768442.0  11.1999984223
# 1    1.549020e+09  861638.674478     1.0         2.0                8.8  20.059284  515.928109 -110.954414  41.518567   0.0  0.0  136.278506  63.118988  1110655.0   9.0   15.0   2.0  300.807678         72.0       29.0        0.0  120619.0   69791451.0  11.1999984223
# ...
