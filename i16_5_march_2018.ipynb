# %%
datadir='/dls/i16/data/2018/cm19668-1/'

import sys
sys.path
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
# %matplotlib nbagg
from matplotlib.pyplot import *
from numpy import *
#from dlstools.quickfit import *
#from dlstools.dirty_fit import fit
from dlstools import dataloader
d=dataloader.dlsloader(datadir+'%i.dat')
p=dataloader.tiffloader(d, lambda obj: datadir+obj.pilatus2m_path_template)
psnap=dataloader.tiffloader(datadir+'snapped-data/pilatus2M/'+'%05i.tif')

# %%
# Image from Thu Jan 25 18:35:14 2018 (first/previous test)
d(670844)
p(1); figure(); imshow(p.image_01,clim=(0,100)); title('#%i' % d.SRSRUN)
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">
# Text(0.5,1,u'#670844')

# %% [markdown]
# ## Data from 5th March 2018
# No data on flipper = x1 was closed!

# %%
xscans=range(678664,678680,2)
fracdiff=[]
for scan in xscans:
    fracdiff+=list(d(scan).fracdiff)
fracdiff=array(fracdiff)
print('=== fracdiff mean: %.5f +/- %.5f' % (mean(fracdiff), std(fracdiff)/sqrt(len(fracdiff))))
# Out:
# === fracdiff mean: 0.00008 +/- 0.00008

# %%
xscans=range(678664,678680,2)
allsums=[]
for scan in xscans:
    d(scan)
    for im_no in d(scan).filenum:     
        psnap(im_no)
        print im_no
        allsums+=[sum(psnap.image_01)]
figure(); plot(allsums)
# Out:
# 7212
# 7220
# 7228
# 7236
# 7244
# 7252
# 7260
# 7268
# 7276
# 7284
# 7292
# 7300
# 7308
# 7316
# 7324
# 7332
# 7340
# 7348
# 7356
# 7364
# 7372
# 7380
# 7388
# 7396
# 7404
# 7412
# 7420
# 7428
# 7436
# 7444
# 7452
# 7460
# 7468
# 7476
# 7484
# 7492
# 7500
# 7508
# 7516
# 7524
# 7532
# 7540
# 7548
# 7556
# 7564
# 7572
# 7580
# 7588
# 7596
# 7604
# 7940
# 7948
# 7956
# 7964
# 7972
# 7980
# 7988
# 7996
# 8004
# 8012
# 8020
# 8028
# 8036
# 8044
# 8052
# 8060
# 8068
# 8076
# 8084
# 8092
# 8100
# 8108
# 8116
# 8124
# 8132
# 8140
# 8148
# 8156
# 8164
# 8172
# 8180
# 8188
# 8196
# 8204
# 8212
# 8220
# 8228
# 8236
# 8244
# 8252
# 8260
# 8268
# 8276
# 8284
# 8292
# 8300
# 8308
# 8316
# 8324
# 8332
# 8668
# 8676
# 8684
# 8692
# 8700
# 8708
# 8716
# 8724
# 8732
# 8740
# 8748
# 8756
# 8764
# 8772
# 8780
# 8788
# 8796
# 8804
# 8812
# 8820
# 8828
# 8836
# 8844
# 8852
# 8860
# 8868
# 8876
# 8884
# 8892
# 8900
# 8908
# 8916
# 8924
# 8932
# 8940
# 8948
# 8956
# 8964
# 8972
# 8980
# 8988
# 8996
# ...

# %%
figure(); imshow(psnap.image_01, clim=(0,10))
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">
