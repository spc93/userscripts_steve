# %% [markdown]
# # Python code to parse nexus base class nxdl files to python dict and create
#
#
# ## This branch is new vserion that deals with measures (value, unit)
#
# ## units are stings (data properties)
#
# # create subclasses of NeXusMeasure which are UnitCategories ?????
# # baseclass
# #           nexusfield some UnitCategory
# # what if no unit category?
#
# # need python 3.8? onto_path not defined otherwise
# # how to use verionIRI?

# %% [raw]
# # testing code - to remove
#
#
# from github import Github
# import urllib
#
# token = "e9bedb765c37956e75c9a552f93455034ce54aa5"
# g = Github(token)
#
# #repo = g.get_repo('nexusformat/definitions')
# #for file in repo.get_contents("base_classes"):
# #    print(file.download_url)
#
# repo = g.get_repo('nexusformat/definitions')
# for file in repo.get_contents(''):
#     print(file.download_url)
#
# #repo = g.get_repo('ExPaNDS-eu/ExPaNDS-experimental-techniques-ontology')
# #for file in repo.get_contents("source"):
# #    print(file.download_url)
#
# import xml.dom.minidom
# import urllib
#
# types_url = 'https://raw.githubusercontent.com/nexusformat/definitions/main/nxdlTypes.xsd'
# nexus_url = 'https://raw.githubusercontent.com/nexusformat/definitions/main/base_classes/NXcollimator.nxdl.xml'
#
#
# dom1 = xml.dom.minidom.parse(urllib.request.urlopen(types_url))
# dom2 = xml.dom.minidom.parse(urllib.request.urlopen(nexus_url))
#
# ns = dom1.getElementsByTagName('xs:simpleType')
# #print(ns)
# for n in ns:
#     n.getAttribute('name')
#     #rint(n)
#     print(n.attributes.items())
#     d = n.getElementsByTagName('xs:documentation')
#     print(d[0].firstChild.nodeValue)
#
#
# #names = dom1.getElementsByTagName('name')
# #print(names)

# %%
#pip install owlready2
#pip install --user owlready2
#import github

# %%
#get a list of NeXus base class urls from github


#pip install pygithub
token = "e9bedb765c37956e75c9a552f93455034ce54aa5"

out_path = '/home/spc93/ontology/'


#onto_iri = 'http://test.org/NeXus_onto5.owl'
#onto_iri = 'http://purl.org/xyz_test/NeXus.owl'
onto_iri = 'http://purl.org/nexusformat/NeXusOntology'

# pickle files used to avoid uneccesary parsing of NeXus files, mainly for development
defn_pickle_file = '/home/spc93/tmp/defn.p'
baseclass_pickle_file = '/home/spc93/tmp/baseclass.p'
types_pickle_file = '/home/spc93/tmp/types.p'

base_class_web_page_prefix = 'https://manual.nexusformat.org/classes/base_classes/'
application_definition_web_page_prefix = 'https://manual.nexusformat.org/classes/applications/'
types_url = 'https://raw.githubusercontent.com/nexusformat/definitions/main/nxdlTypes.xsd'


join_string = '.'      #string added between joined names
join_string_label = ' ' #string added between joined names for rdfs:label

nexus_website = 'https://www.nexusformat.org/'
nexus_repository = 'https://github.com/nexusformat'

default_units = 'NX_UNITLESS'   #use this if units not specified

import datetime
import pickle
    
#use closest owlready2 data types
type_convert = {
    'NX_CHAR':str,
    'NX_FLOAT':float,
    'NX_INT':int,
    'NX_UINT':int,
    'NX_POSINT':int,
    'NX_NUMBER':float,
    'NX_DATE_TIME':datetime.datetime,
    'NX_BOOLEAN':bool,
    'NX_BINARY':int,
    'ISO8601':datetime.datetime
}  


onto_comment = '''

    This ontology extracts information about NeXus classes and fields from
    NeXus nxdl definition files on the NeXus GitHub site.
    See 'seeAlso' for links to the NeXus project, including licencing information.
    This project was undertaken under ExPaNDS WP3.2 (https://expands.eu/)
    
    Purpose
    The ontology is designed to fulfil several purposes. First, it creates unique identifiers
    for each of the NeXus fields which would normally exist only within the namespaces of the
    defining NeXus classes. This is the primary goal and provides PIDs for annotation and tagging.
    The second purpose is to allow, via separate ontologies, NeXus fields and classes to be mapped
    onto equivalent or related terms defined elsewhere.
    Finally, we hope that this ontology, when used with a tool such as Protege, will provide a
    useful 'NeXus Explorer' tool to gain a quick overview of NeXus with links to official NeXus 
    documentation.
    
    Design Philosophy
    The terms in the ontology are extracted almost entirely from NeXus nxdl definition file and converted to
    an OWL ontology using the owlready2 python module (https://pypi.org/project/Owlready2/)
    NeXus classes - Base Classes and Application Definitions - are expressed as OWL classes.
    NeXus fields, which contain the NeXus metadata, are expressed as Owl data properties.
    While NeXus provides a subclassing method ('extends') for NeXus classes, this is not currently reflected
    in the corresponding OWL classes.
    One can think of the main purpose of the ontology as being to 'flatten' the NeXus fields into a single
    namespace, rather than existing in the multiple namespaces of the NeXus classes. This requires longer and
    more explicit names for the NeXus fields, which are created by prepending the NeXus base class name to the
    NeXus field name. It is very important to note that a NeXus application definition can extend a base class
    adding new fields, and that it is understood (see NeXus documentation) that the new fields then reserve names
    within the class dictionary in order to avoid later duplication. These new fields are therefore shown as data
    properties of the NeXus Base Classes, even though they are defined outside the original class definition.
    
    NeXus classes are reviewed periodically by the NeXus NIAC. It is anticipated that this ontology can be updated 
    quickly and automatically to reflect the updated definitions.
    
    Caveats
    Some NeXus classes (e.g. NXtransformations) are related specifically to the class that they are contained in.
    This relationship is not preserves.
    NeXus allows multiple instances of metadata fields within a dataset. Relating multiple field values to a
    single identifier will require a selection algorithm.
    
'''

# %%
# execute instead of NeXus parsig cells to use saved data and save time

classDict = pickle.load( open(baseclass_pickle_file , "rb" ) )
applicationDict = pickle.load( open(defn_pickle_file , "rb" ) )
typesDict = pickle.load( open(types_pickle_file , "rb" ) )

# %% [raw]
# # Create a dictionary of NeXus simple types (unit categories)
#
# from github import Github
# import xml.dom.minidom
# import urllib
# import pickle
#
# nexus_url = 'https://raw.githubusercontent.com/nexusformat/definitions/main/base_classes/NXcollimator.nxdl.xml'
#
# types_dom = xml.dom.minidom.parse(urllib.request.urlopen(types_url))
#
# typesDict = {}
# for nxtype in types_dom.getElementsByTagName('xs:simpleType'):
#     name = nxtype.getAttribute('name')
#     doc = nxtype.getElementsByTagName('xs:documentation')
#     docstr = doc[0].firstChild.nodeValue
#     docstr = docstr.replace('\n','').replace('\t','')
#     typesDict[name] = {'doc': docstr}
#     #print(name, docstr[0].firstChild.nodeValue)
#
# pickle.dump(typesDict, open(types_pickle_file, "wb" ) )

# %% [raw]
# # parse nexus base class files via url to python dictionary
#
#
# from github import Github
# import xml.dom.minidom
# import os
# import urllib
# import time
# import pickle
# from pprint import pprint
#
#
# g = Github(token)
# repo = g.get_repo('nexusformat/definitions')
#
# base_class_url = []
# for file in repo.get_contents("base_classes"):
#     if str(file).split('.')[-2] == 'nxdl':
#         base_class_url += [file.download_url]
#
#
# _maxTries = 10 # try to parse file this many times before giving up
#
# def addFieldToDict(classDict, field, defn_name): # make a function to be reused later
#     #defn_name is used to add application definition to field dict if the field is defined in an app deff.
#     field_name = field.getAttribute('name')
#
#
#     deprecationAttribute = field.getAttribute('deprecated')
#     if not deprecationAttribute == '':
#         print("=== Deprecation warning %s in %s: %s" % (field_name, className, deprecationAttribute))
#
#     long_name = className + join_string + field_name
#     label = className + join_string_label + field_name
#
#     if not long_name in classDict[className]['fields'].keys():
#         print('~~~ field did not exist: %s' % long_name)
#         classDict[className]['fields'][long_name] = {} # create dictionary for field if doesn't exist
#
#
#         classDict[className]['fields'][long_name]['fieldName'] = field_name
#         classDict[className]['fields'][long_name]['units'] = field.getAttribute('units')
#         if classDict[className]['fields'][long_name]['units']=='':
#             classDict[className]['fields'][long_name]['units'] = default_units
#
#         print('@@@', classDict[className]['fields'][long_name]['units']) #################################
#
#         classDict[className]['fields'][long_name]['xml_file'] = file #xml file where field is defined
#         classDict[className]['fields'][long_name]['defn_name'] = defn_name # application defn name is passed in if field is defined in a defn, else None is used
#         classDict[className]['fields'][long_name]['label'] = label # compound name for label
#
#         _type = field.getAttribute('type')
#         if _type == '':
#             _type = 'NX_CHAR'   # default if not specified
#
#         classDict[className]['fields'][long_name]['type'] = _type
#
#         try:
#             field_doc = field.getElementsByTagName('doc')[0].firstChild.nodeValue.replace('\n','')
#         except:
#             field_doc = ''
#         classDict[className]['fields'][long_name]['fieldDoc'] = field_doc
#
#
# #     classDict[className]['fields'][long_name]['fieldName'] = field_name
# #     classDict[className]['fields'][long_name]['units'] = field.getAttribute('units')
# #     classDict[className]['fields'][long_name]['xml_file'] = file #xml file where field is defined
#
# #     _type = field.getAttribute('type')
# #     if _type == '':
# #         _type = 'NX_CHAR'   # default if not specified
#
# #     classDict[className]['fields'][long_name]['type'] = _type
#
# #     try:
# #         field_doc = field.getElementsByTagName('doc')[0].firstChild.nodeValue.replace('\n','')
# #     except:
# #         field_doc = ''
# #     classDict[className]['fields'][long_name]['fieldDoc'] = field_doc
#
#
#
#
#
# classDict = {} # create empty classDict dictionary
#
# #for file in file_list:
# for file in base_class_url:
#     print(file)
#
#     for i in range(_maxTries):
#         try:
#             dom1 = xml.dom.minidom.parse(urllib.request.urlopen(file))
#             break
#         except:
#             print('=== Problem parsing %s; try %i times then give up' % (file, _maxTries))
#             time.sleep(1)
#
#     defn = dom1.getElementsByTagName('definition')[0]
#
#     className = defn.getAttribute('name') #class name from name attribute in definition
#
#     if not className in classDict.keys():
#         classDict[className] = {} # each class is a dictionary - create a new one if doesn't exist
#
#     classDict[className]['xml_file'] = file
#
#     #category = defn.getAttribute('category')
#     classDict[className]['extends'] = defn.getAttribute('extends')
#     #classDict[className]['classDoc'] = dom1.getElementsByTagName('doc')[0].firstChild.nodeValue.replace('\n','')
#
#
#     docstr = ''
#     for docelement in dom1.getElementsByTagName('doc'):
#         if docelement.parentNode.tagName == 'definition':
#             docstr = docelement.firstChild.nodeValue.replace('\n','')
#             break
#     classDict[className]['classDoc'] = docstr
#
#
#
#
#     if not 'fields' in classDict[className].keys():
#         classDict[className]['fields'] = {} # create fields dictionary for class if doesn't exist
#
#
#     # look for fields in group but not recursive
#     flds = (field for field in defn.getElementsByTagName('field') if field.parentNode == defn)
#
#     for field in flds:
#         addFieldToDict(classDict, field, None)
#
#     classDict[className]['groups_cited'] = []
#     for group in defn.getElementsByTagName('group'):
#         groupName = group.getAttribute('type')
#         classDict[className]['groups_cited'] += [groupName]
#
#
# pickle.dump(classDict, open(baseclass_pickle_file, "wb" ) )
# #pprint(classDict)

# %% [raw]
# # parse nexus application definitions
# # extract extra base class fields and add to base class dictionary
#
# # cntrl / to comment/uncomment
# # tab/shift_tab to block tab/untab
#
#
# import xml.dom.minidom
# import os
# #import yaml
# import urllib
# import time
# import pickle
#
#
# #get a list of NeXus base application definition urls from github
# application_url = []
# for file in repo.get_contents("applications"):
#     try:
#         if str(file).split('.')[-2] == 'nxdl':
#             application_url += [file.download_url]
#     except:
#         pass
#
#
# applicationDict = {}
#
# for file in application_url:
#
#
#     dom1 = xml.dom.minidom.parse(urllib.request.urlopen(file)) # pick one at random
#
#     appdefn = dom1.getElementsByTagName('definition')[0]
#     defn_name = appdefn.getAttribute('name')
#
#     group = dom1.getElementsByTagName('group')
#     classList, classNameList = [], []
#     for defn in group:
#         className = defn.getAttribute('type')
#         #classList += [defn] ################################################### don't need defn - just DOM element
#         classNameList += [className]
#
#         # look for fields in group but not recursive
#         flds = (field for field in defn.getElementsByTagName('field') if field.parentNode == defn)
#         for field in flds:
#             #not useful as it shows all fields from classes in defs even if already defined in class ######### delete comment
#             print('xxx Added field %s from class %s in definition %s' % (field.getAttribute('name'), className, defn_name)) #########
#             addFieldToDict(classDict, field, defn_name)
#
#
#     docstr = ''
#     for docelement in dom1.getElementsByTagName('doc'):
#         if docelement.parentNode.tagName == 'definition':
#             docstr = docelement.firstChild.nodeValue.replace('\n','')
#             break
#
#
#     # get informat ion about application definition (name, xml_file, extends, doc) and add to dict
#     #defn = dom1.getElementsByTagName('definition')[0]
#     #defn_name = defn.getAttribute('name')
#     applicationDict[defn_name] = {} # new entry with definition nae as key
#     applicationDict[defn_name]['extends'] = appdefn.getAttribute('extends')
#     #applicationDict[defn_name]['doc'] = dom1.getElementsByTagName('doc')[0].firstChild.nodeValue.replace('\n','')
#     applicationDict[defn_name]['doc'] = docstr
#     applicationDict[defn_name]['xml_file'] = file
#     applicationDict[defn_name]['groups_cited'] = classNameList
#     #applicationDict[defn_name]['base_classes'] = classList  ################################################### don't need defn - just DOM element
#
#
#
# pickle.dump(classDict, open(baseclass_pickle_file, "wb" ) ) # re-save class dict (now has new fields)
# pickle.dump(applicationDict, open(defn_pickle_file, "wb" ) )
# #pprint(applicationDict)

# %%
# # messy attempt to create something that looks like NeXus data types

# this worked but created extra classes, object properties and instances ### come back tothis later?

# # re-write later
# # remove c individuals

# from owlready2 import *
# import types
# #import copy

# onto_path.append(out_path)
# onto = get_ontology(onto_iri)


# typedict = {} #dictionary of new types created in owlready2 (key = nx type string, value = new type, needed later)

# for _nxtype in type_convert.keys():

#     class Hex(object):
#         def __init__(self, value):
#             self.value = value

    
#     #declare_datatype(Hex, '%s#%s' % (onto_iri, _nxtype), parser, unparser)
#     declare_datatype(Hex,  '%s#%s' % (onto_iri, _nxtype), lambda x : None, lambda x : '')


#     typedict[_nxtype] = Hex
        
#     with onto:
#         class p(Thing >> Hex): pass
#         class C(Thing): pass
#         c1 = C()
#         c1.p.append(Hex(14))

#     onto.save()
    
#     #print(typedict)

# %%
#pip install owlready2
#pip install --upgrade owlready2

from owlready2 import *
import types
import datetime

onto_path.append(out_path)
onto = get_ontology(onto_iri)

with onto:

    ## Classes (generic)
    
    onto.metadata.versionInfo.append(
        'Version date: %s\n' % datetime.date.today().strftime("%b-%d-%Y")) # How to add versionIRI?

    
    class NeXus(Thing):
        comment = 'NeXus concept'
        
    class dataset(Thing):
        comment = 'Dummy data set'
      
  
    #class NeXusField(NeXus):
    #    comment = 'NeXus field. Unique names are created by prepending the NeXus class name to the NeXus field name'
    
    #class testDataProperty(DataProperty): #################################### delete
    #    range = [float]
    #    comment = 'a test'
    
    #class NeXusField(DataProperty, FunctionalProperty):
    #    comment = 'NeXus field (DataProperty). Unique names are created by prepending the NeXus class name to the NeXus field name'
    
    class NeXusField(ObjectProperty):
        domain = [dataset]
        comment = 'NeXus field (ObjectProperty). Unique names are created by prepending the NeXus class name to the NeXus field name'
      
    class NXobject(NeXus):
        comment = 'NXobject'
    
    class NeXusBaseClass(NXobject):
        comment = 'NeXusBaseClass'
        seeAlso = 'https://manual.nexusformat.org/classes/index.html'
    
    class NeXusApplicationDefinition(NXobject):
        comment = 'NeXus Application Definition'
        seeAlso = 'https://manual.nexusformat.org/classes/index.html'
      
    #class NeXusUnitCategory(NeXus):
    #    comment = 'NeXus Unit Category'
        
    #class NeXusUnit(NeXusUnitCategory):
    #    comment = 'NeXus Unit'
        
    ## properties (generic)
    
    #class hasField(NXobject >> NeXusField):
    #    comment = 'NXobject has NeXus field relationship'
    
    ## is there a shorthand form with inverse?
    ## how to assert the reverse inverse? By reasoner?
    
    #class isFieldOf(ObjectProperty):
    #    domain           = [NeXusField]
    #    range            = [NXobject]
    #    inverse_property = hasField
        
    # TypeError: unsupported operand type(s) for >>: 'DataPropertyClass' and 'ThingClass'
    #class hasUnit(NeXusField >> NeXusUnit):
    #    comment = 'NeXus Field has Unit relationship'
        
    class citesGroup(NXobject >> NeXusBaseClass):
        comment = 'NXobject cites base class relationship'
        
    #TypeError: unsupported operand type(s) for >>: 'DataPropertyClass' and 'type'
    #class hasFieldName(NeXusField >> str):
    #    comment = 'NeXus field name of NeXus field. NeXus field names are unique only within the NeXus class in which they are defined.'
    
    #class NXDLurl(AnnotationProperty):
    #    pass
    
    class extends(AnnotationProperty):
        pass
    
    class NeXusType(AnnotationProperty):
        pass
    
    class unit(AnnotationProperty):
        pass
    
    class NeXusClass(AnnotationProperty):
        pass
    
    class unitCategory(NeXus):
        comment = 'NeXus unit category. Can be considered instances of a measure. Assign data properties ' \
            'hasValue(any), hasMinValue(any), hasMaxValue(any), hasUnits(str)'
        
    class hasValue(DataProperty, FunctionalProperty):
        domain = [unitCategory]
        comment = 'NeXus field value'
        
    class hasMinValue(DataProperty, FunctionalProperty):
        domain = [unitCategory]
        comment = 'Minimum of NeXus field value'
        
    class hasMaxValue(DataProperty, FunctionalProperty):
        domain = [unitCategory]
        comment = 'Maximum of NeXus field value'    
    
    class hasUnit(DataProperty, FunctionalProperty):
        domain = [unitCategory]
        range = [str]
        comment = 'NeXus unit (string). Should be consistent with unit category.'
    
    
    for unit in typesDict.keys():
        if unit == 'anyUnitsAttr': # general description, not specific unit category
            unitCategory.comment.append(typesDict[unit]['doc']) # use to document unitCategory class
        elif unit == 'primitiveType': # do nothing with this entry
            pass
        else:
            typesDict[unit]['class'] = types.new_class(unit, (unitCategory,)) # create new unit category subclass
            typesDict[unit]['class'].comment.append(typesDict[unit]['doc'])   # document it

    
    
    for nxBaseClass in classDict.keys():
        
        if not nxBaseClass == 'NXobject':    # NXobject can't be subclass of NXobject
            _nx_class = types.new_class(nxBaseClass, (NeXusBaseClass,))
            classDict[nxBaseClass]['onto_class'] =  _nx_class    # add class to dict 
            _nx_class.comment.append(classDict[nxBaseClass]['classDoc'])
            _nx_class.extends.append(classDict[nxBaseClass]['extends'])
            #_nx_class.seeAlso.append(classDict[nxBaseClass]['xml_file'])   
            web_page = base_class_web_page_prefix + nxBaseClass + '.html' 
            
            _nx_class.seeAlso.append(web_page) 
                
            #domn = dataset  ########################################### delete line? 
            for nxField in classDict[nxBaseClass]['fields'].keys():
                #rng = type_convert[classDict[nxBaseClass]['fields'][nxField]['type']] #convert NeXus type to Owlready2 type
                
                #problem if inheriting from NeXusField
                #_nx_field = types.new_class(nxField, (NeXusField,))
                #_nx_field = types.new_class(nxField, (DataProperty, FunctionalProperty,))               
                #_nx_field.range = [rng]
                
     
                _nx_field = types.new_class(nxField, (NeXusField, ))
        
                classDict[nxBaseClass]['fields'][nxField]['class'] = _nx_field
    
                
                _nx_field.comment.append(classDict[nxBaseClass]['fields'][nxField]['fieldDoc'])
                _nx_field.label.append(classDict[nxBaseClass]['fields'][nxField]['label']) #############
      
                #_nx_field.NXDLurl.append(classDict[nxBaseClass]['fields'][nxField]['xml_file'])
        
        
                defn_name = classDict[nxBaseClass]['fields'][nxField]['defn_name']
            
                print('!!', nxField, defn_name) #############################################
            
                if defn_name != None:
                    #Field is defined by an application definition; give app defn web page (no anchor - might add later)
                    web_page = application_definition_web_page_prefix + defn_name + '.html'
                    _nx_field.seeAlso.append(web_page)
                else:
                    #Field is defined by base class file; give base class web page with arhchor
                    
                    anchor = '#%s-%s-field' % (nxBaseClass.lower(), 
                                               classDict[nxBaseClass]['fields'][nxField]['fieldName'].lower())
                    anchor = anchor.replace('_', '-') # replace symbols for anchors
                    
                    web_page = base_class_web_page_prefix + nxBaseClass + '.html' + anchor
                    _nx_field.seeAlso.append(web_page)
                
                print('!!', web_page)
                    
            
                #_nx_field.NeXusType.append(classDict[nxBaseClass]['fields'][nxField]['type'])
                
                #if classDict[nxBaseClass]['fields'][nxField]['units'] != '':
                #    _nx_field.unit.append(classDict[nxBaseClass]['fields'][nxField]['units'])
                    
                #tried to use NeXus types but created extra classes and object properties. Return to this later.  
                #_nx_class.is_a.append(_nx_field.some(type_convert[classDict[nxBaseClass]['fields'][nxField]['type']])) # 

                #_nx_class.is_a.append(_nx_field.some(measure))
                #
                #
                #
                # get unit for field from classDict
                # get unit class from unit from typesDict
                #_nx_class.is_a.append(_nx_field.some(unitclass))
                #
                
                
                unit_string = classDict[nxBaseClass]['fields'][nxField]['units']
                print(unit_string) #####################################
                unit_class = typesDict[unit_string]['class']
                print(unit_class) ###########################################
                _nx_class.is_a.append(_nx_field.some(unit_class))
                
                
                _nx_field.NeXusClass.append(_nx_class)

                print('unit class', unit_class)
                _nx_field.range = [unit_class] #################################
                

    # second loop required to ensure all classes defined before trying to cite them            
    for nxBaseClass in classDict.keys():  
        if not nxBaseClass == 'NXobject':    # NXobject can't be subclass of NXobject
            for cited in classDict[nxBaseClass]['groups_cited']:
                classDict[nxBaseClass]['onto_class'].is_a.append(citesGroup.some(classDict[cited]['onto_class']))
                
                
    for application in applicationDict.keys():
        _nx_app = types.new_class(application, (NeXusApplicationDefinition,))
        _nx_app.comment.append(applicationDict[application]['doc'])
        _nx_app.extends.append(applicationDict[application]['extends'])

        web_page = application_definition_web_page_prefix + application + '.html'
        _nx_app.seeAlso.append(web_page)
        
        for base_class in applicationDict[application]['groups_cited']:
            _nx_app.is_a.append(citesGroup.some(classDict[base_class]['onto_class']))

    onto.metadata.seeAlso.append(nexus_website)
    onto.metadata.seeAlso.append(nexus_repository)    
    onto.metadata.comment.append(onto_comment)   

onto.save()
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation
# !! NXaperture.material None
# !! https://manual.nexusformat.org/classes/base_classes/NXaperture.html#nxaperture-material-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXaperture.description None
# !! https://manual.nexusformat.org/classes/base_classes/NXaperture.html#nxaperture-description-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXaperture.shape NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXaperture.x_gap NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXaperture.y_gap NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXattenuator.distance None
# !! https://manual.nexusformat.org/classes/base_classes/NXattenuator.html#nxattenuator-distance-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXattenuator.type None
# !! https://manual.nexusformat.org/classes/base_classes/NXattenuator.html#nxattenuator-type-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXattenuator.thickness None
# !! https://manual.nexusformat.org/classes/base_classes/NXattenuator.html#nxattenuator-thickness-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXattenuator.scattering_cross_section None
# !! https://manual.nexusformat.org/classes/base_classes/NXattenuator.html#nxattenuator-scattering-cross-section-field
# NX_CROSS_SECTION
# NeXusOntology.NX_CROSS_SECTION
# unit class NeXusOntology.NX_CROSS_SECTION
# !! NXattenuator.absorption_cross_section None
# !! https://manual.nexusformat.org/classes/base_classes/NXattenuator.html#nxattenuator-absorption-cross-section-field
# NX_CROSS_SECTION
# NeXusOntology.NX_CROSS_SECTION
# unit class NeXusOntology.NX_CROSS_SECTION
# !! NXattenuator.attenuator_transmission None
# !! https://manual.nexusformat.org/classes/base_classes/NXattenuator.html#nxattenuator-attenuator-transmission-field
# NX_DIMENSIONLESS
# NeXusOntology.NX_DIMENSIONLESS
# unit class NeXusOntology.NX_DIMENSIONLESS
# !! NXattenuator.status None
# !! https://manual.nexusformat.org/classes/base_classes/NXattenuator.html#nxattenuator-status-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXbeam.distance None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-distance-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXbeam.incident_energy None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-incident-energy-field
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXbeam.final_energy None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-final-energy-field
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXbeam.energy_transfer None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-energy-transfer-field
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXbeam.incident_wavelength None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-incident-wavelength-field
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXbeam.incident_wavelength_spread None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-incident-wavelength-spread-field
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXbeam.incident_beam_divergence None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-incident-beam-divergence-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXbeam.extent None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-extent-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXbeam.final_wavelength None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-final-wavelength-field
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXbeam.incident_polarization None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-incident-polarization-field
# NX_ANY
# NeXusOntology.NX_ANY
# unit class NeXusOntology.NX_ANY
# !! NXbeam.final_polarization None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-final-polarization-field
# NX_ANY
# NeXusOntology.NX_ANY
# unit class NeXusOntology.NX_ANY
# !! NXbeam.final_wavelength_spread None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-final-wavelength-spread-field
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXbeam.final_beam_divergence None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-final-beam-divergence-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXbeam.flux None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam.html#nxbeam-flux-field
# NX_FLUX
# NeXusOntology.NX_FLUX
# unit class NeXusOntology.NX_FLUX
# !! NXbeam.incident_wavelength_weight NXmx
# !! https://manual.nexusformat.org/classes/applications/NXmx.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXbeam.incident_wavelength_weights NXmx
# !! https://manual.nexusformat.org/classes/applications/NXmx.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXbeam.total_flux NXmx
# !! https://manual.nexusformat.org/classes/applications/NXmx.html
# NX_FREQUENCY
# NeXusOntology.NX_FREQUENCY
# unit class NeXusOntology.NX_FREQUENCY
# !! NXbeam.incident_beam_size NXmx
# !! https://manual.nexusformat.org/classes/applications/NXmx.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXbeam.profile NXmx
# !! https://manual.nexusformat.org/classes/applications/NXmx.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXbeam.incident_polarisation_stokes NXmx
# !! https://manual.nexusformat.org/classes/applications/NXmx.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXbeam_stop.description None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam_stop.html#nxbeam-stop-description-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXbeam_stop.size None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam_stop.html#nxbeam-stop-size-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXbeam_stop.x None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam_stop.html#nxbeam-stop-x-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXbeam_stop.y None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam_stop.html#nxbeam-stop-y-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXbeam_stop.distance_to_detector None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam_stop.html#nxbeam-stop-distance-to-detector-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXbeam_stop.status None
# !! https://manual.nexusformat.org/classes/base_classes/NXbeam_stop.html#nxbeam-stop-status-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXbending_magnet.critical_energy None
# !! https://manual.nexusformat.org/classes/base_classes/NXbending_magnet.html#nxbending-magnet-critical-energy-field
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXbending_magnet.bending_radius None
# !! https://manual.nexusformat.org/classes/base_classes/NXbending_magnet.html#nxbending-magnet-bending-radius-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXbending_magnet.magnetic_field None
# !! https://manual.nexusformat.org/classes/base_classes/NXbending_magnet.html#nxbending-magnet-magnetic-field-field
# NX_CURRENT
# NeXusOntology.NX_CURRENT
# unit class NeXusOntology.NX_CURRENT
# !! NXbending_magnet.accepted_photon_beam_divergence None
# !! https://manual.nexusformat.org/classes/base_classes/NXbending_magnet.html#nxbending-magnet-accepted-photon-beam-divergence-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXbending_magnet.source_distance_x None
# !! https://manual.nexusformat.org/classes/base_classes/NXbending_magnet.html#nxbending-magnet-source-distance-x-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXbending_magnet.source_distance_y None
# !! https://manual.nexusformat.org/classes/base_classes/NXbending_magnet.html#nxbending-magnet-source-distance-y-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXbending_magnet.divergence_x_plus None
# !! https://manual.nexusformat.org/classes/base_classes/NXbending_magnet.html#nxbending-magnet-divergence-x-plus-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXbending_magnet.divergence_x_minus None
# !! https://manual.nexusformat.org/classes/base_classes/NXbending_magnet.html#nxbending-magnet-divergence-x-minus-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXbending_magnet.divergence_y_plus None
# !! https://manual.nexusformat.org/classes/base_classes/NXbending_magnet.html#nxbending-magnet-divergence-y-plus-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXbending_magnet.divergence_y_minus None
# !! https://manual.nexusformat.org/classes/base_classes/NXbending_magnet.html#nxbending-magnet-divergence-y-minus-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcapillary.type None
# !! https://manual.nexusformat.org/classes/base_classes/NXcapillary.html#nxcapillary-type-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcapillary.manufacturer None
# !! https://manual.nexusformat.org/classes/base_classes/NXcapillary.html#nxcapillary-manufacturer-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcapillary.maximum_incident_angle None
# !! https://manual.nexusformat.org/classes/base_classes/NXcapillary.html#nxcapillary-maximum-incident-angle-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcapillary.accepting_aperture None
# !! https://manual.nexusformat.org/classes/base_classes/NXcapillary.html#nxcapillary-accepting-aperture-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcapillary.working_distance None
# !! https://manual.nexusformat.org/classes/base_classes/NXcapillary.html#nxcapillary-working-distance-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcapillary.focal_size None
# !! https://manual.nexusformat.org/classes/base_classes/NXcapillary.html#nxcapillary-focal-size-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcite.description None
# !! https://manual.nexusformat.org/classes/base_classes/NXcite.html#nxcite-description-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcite.url None
# !! https://manual.nexusformat.org/classes/base_classes/NXcite.html#nxcite-url-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcite.doi None
# !! https://manual.nexusformat.org/classes/base_classes/NXcite.html#nxcite-doi-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcite.endnote None
# !! https://manual.nexusformat.org/classes/base_classes/NXcite.html#nxcite-endnote-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcite.bibtex None
# !! https://manual.nexusformat.org/classes/base_classes/NXcite.html#nxcite-bibtex-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcollection.fixed_energy NXspe
# !! https://manual.nexusformat.org/classes/applications/NXspe.html
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXcollection.ki_over_kf_scaling NXspe
# !! https://manual.nexusformat.org/classes/applications/NXspe.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcollection.psi NXspe
# !! https://manual.nexusformat.org/classes/applications/NXspe.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcollimator.type None
# !! https://manual.nexusformat.org/classes/base_classes/NXcollimator.html#nxcollimator-type-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcollimator.soller_angle None
# !! https://manual.nexusformat.org/classes/base_classes/NXcollimator.html#nxcollimator-soller-angle-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcollimator.divergence_x None
# !! https://manual.nexusformat.org/classes/base_classes/NXcollimator.html#nxcollimator-divergence-x-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcollimator.divergence_y None
# !! https://manual.nexusformat.org/classes/base_classes/NXcollimator.html#nxcollimator-divergence-y-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcollimator.frequency None
# !! https://manual.nexusformat.org/classes/base_classes/NXcollimator.html#nxcollimator-frequency-field
# NX_FREQUENCY
# NeXusOntology.NX_FREQUENCY
# unit class NeXusOntology.NX_FREQUENCY
# !! NXcollimator.blade_thickness None
# !! https://manual.nexusformat.org/classes/base_classes/NXcollimator.html#nxcollimator-blade-thickness-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcollimator.blade_spacing None
# !! https://manual.nexusformat.org/classes/base_classes/NXcollimator.html#nxcollimator-blade-spacing-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcollimator.absorbing_material None
# !! https://manual.nexusformat.org/classes/base_classes/NXcollimator.html#nxcollimator-absorbing-material-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcollimator.transmitting_material None
# !! https://manual.nexusformat.org/classes/base_classes/NXcollimator.html#nxcollimator-transmitting-material-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcollimator.length NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcollimator.distance NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.usage None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-usage-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcrystal.type None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-type-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcrystal.chemical_formula None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-chemical-formula-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcrystal.order_no None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-order-no-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcrystal.cut_angle None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-cut-angle-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.space_group None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-space-group-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcrystal.unit_cell None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-unit-cell-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.unit_cell_a None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-unit-cell-a-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.unit_cell_b None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-unit-cell-b-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.unit_cell_c None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-unit-cell-c-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.unit_cell_alpha None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-unit-cell-alpha-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.unit_cell_beta None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-unit-cell-beta-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.unit_cell_gamma None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-unit-cell-gamma-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.unit_cell_volume None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-unit-cell-volume-field
# NX_VOLUME
# NeXusOntology.NX_VOLUME
# unit class NeXusOntology.NX_VOLUME
# !! NXcrystal.orientation_matrix None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-orientation-matrix-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcrystal.wavelength None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-wavelength-field
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXcrystal.d_spacing None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-d-spacing-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.scattering_vector None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-scattering-vector-field
# NX_WAVENUMBER
# NeXusOntology.NX_WAVENUMBER
# unit class NeXusOntology.NX_WAVENUMBER
# !! NXcrystal.reflection None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-reflection-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcrystal.thickness None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-thickness-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.density None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-density-field
# NX_MASS_DENSITY
# NeXusOntology.NX_MASS_DENSITY
# unit class NeXusOntology.NX_MASS_DENSITY
# !! NXcrystal.segment_width None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-segment-width-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.segment_height None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-segment-height-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.segment_thickness None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-segment-thickness-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.segment_gap None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-segment-gap-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.segment_columns None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-segment-columns-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.segment_rows None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-segment-rows-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcrystal.mosaic_horizontal None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-mosaic-horizontal-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.mosaic_vertical None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-mosaic-vertical-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.curvature_horizontal None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-curvature-horizontal-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.curvature_vertical None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-curvature-vertical-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.is_cylindrical None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-is-cylindrical-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcrystal.cylindrical_orientation_angle None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-cylindrical-orientation-angle-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.polar_angle None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-polar-angle-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.azimuthal_angle None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-azimuthal-angle-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.bragg_angle None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-bragg-angle-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.temperature None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-temperature-field
# NX_TEMPERATURE
# NeXusOntology.NX_TEMPERATURE
# unit class NeXusOntology.NX_TEMPERATURE
# !! NXcrystal.temperature_coefficient None
# !! https://manual.nexusformat.org/classes/base_classes/NXcrystal.html#nxcrystal-temperature-coefficient-field
# NX_ANY
# NeXusOntology.NX_ANY
# unit class NeXusOntology.NX_ANY
# !! NXcrystal.ei NXtas
# !! https://manual.nexusformat.org/classes/applications/NXtas.html
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXcrystal.rotation_angle NXtas
# !! https://manual.nexusformat.org/classes/applications/NXtas.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXcrystal.ef NXtas
# !! https://manual.nexusformat.org/classes/applications/NXtas.html
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXcylindrical_geometry.vertices None
# !! https://manual.nexusformat.org/classes/base_classes/NXcylindrical_geometry.html#nxcylindrical-geometry-vertices-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXcylindrical_geometry.cylinders None
# !! https://manual.nexusformat.org/classes/base_classes/NXcylindrical_geometry.html#nxcylindrical-geometry-cylinders-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXcylindrical_geometry.detector_number None
# !! https://manual.nexusformat.org/classes/base_classes/NXcylindrical_geometry.html#nxcylindrical-geometry-detector-number-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.VARIABLE None
# !! https://manual.nexusformat.org/classes/base_classes/NXdata.html#nxdata-variable-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.VARIABLE_errors None
# !! https://manual.nexusformat.org/classes/base_classes/NXdata.html#nxdata-variable-errors-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.DATA None
# !! https://manual.nexusformat.org/classes/base_classes/NXdata.html#nxdata-data-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.errors None
# !! https://manual.nexusformat.org/classes/base_classes/NXdata.html#nxdata-errors-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.scaling_factor None
# !! https://manual.nexusformat.org/classes/base_classes/NXdata.html#nxdata-scaling-factor-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.offset None
# !! https://manual.nexusformat.org/classes/base_classes/NXdata.html#nxdata-offset-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.title None
# !! https://manual.nexusformat.org/classes/base_classes/NXdata.html#nxdata-title-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.x None
# !! https://manual.nexusformat.org/classes/base_classes/NXdata.html#nxdata-x-field
# NX_ANY
# NeXusOntology.NX_ANY
# unit class NeXusOntology.NX_ANY
# !! NXdata.y None
# !! https://manual.nexusformat.org/classes/base_classes/NXdata.html#nxdata-y-field
# NX_ANY
# NeXusOntology.NX_ANY
# unit class NeXusOntology.NX_ANY
# !! NXdata.z None
# !! https://manual.nexusformat.org/classes/base_classes/NXdata.html#nxdata-z-field
# NX_ANY
# NeXusOntology.NX_ANY
# unit class NeXusOntology.NX_ANY
# !! NXdata.Q NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_PER_LENGTH
# NeXusOntology.NX_PER_LENGTH
# unit class NeXusOntology.NX_PER_LENGTH
# !! NXdata.I NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.Idev NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.Qdev NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_PER_LENGTH
# NeXusOntology.NX_PER_LENGTH
# unit class NeXusOntology.NX_PER_LENGTH
# !! NXdata.dQw NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_PER_LENGTH
# NeXusOntology.NX_PER_LENGTH
# unit class NeXusOntology.NX_PER_LENGTH
# !! NXdata.dQl NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_PER_LENGTH
# NeXusOntology.NX_PER_LENGTH
# unit class NeXusOntology.NX_PER_LENGTH
# !! NXdata.Qmean NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_PER_LENGTH
# NeXusOntology.NX_PER_LENGTH
# unit class NeXusOntology.NX_PER_LENGTH
# !! NXdata.ShadowFactor NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_DIMENSIONLESS
# NeXusOntology.NX_DIMENSIONLESS
# unit class NeXusOntology.NX_DIMENSIONLESS
# !! NXdata.lambda NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXdata.T NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_DIMENSIONLESS
# NeXusOntology.NX_DIMENSIONLESS
# unit class NeXusOntology.NX_DIMENSIONLESS
# !! NXdata.Tdev NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_DIMENSIONLESS
# NeXusOntology.NX_DIMENSIONLESS
# unit class NeXusOntology.NX_DIMENSIONLESS
# !! NXdata.data NXiqproc
# !! https://manual.nexusformat.org/classes/applications/NXiqproc.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.variable NXiqproc
# !! https://manual.nexusformat.org/classes/applications/NXiqproc.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.qx NXiqproc
# !! https://manual.nexusformat.org/classes/applications/NXiqproc.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.qy NXiqproc
# !! https://manual.nexusformat.org/classes/applications/NXiqproc.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.azimuthal NXspe
# !! https://manual.nexusformat.org/classes/applications/NXspe.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdata.azimuthal_width NXspe
# !! https://manual.nexusformat.org/classes/applications/NXspe.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdata.polar NXspe
# !! https://manual.nexusformat.org/classes/applications/NXspe.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdata.polar_width NXspe
# !! https://manual.nexusformat.org/classes/applications/NXspe.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdata.distance NXspe
# !! https://manual.nexusformat.org/classes/applications/NXspe.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdata.error NXspe
# !! https://manual.nexusformat.org/classes/applications/NXspe.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.energy NXspe
# !! https://manual.nexusformat.org/classes/applications/NXspe.html
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXdata.qz NXsqom
# !! https://manual.nexusformat.org/classes/applications/NXsqom.html
# NX_WAVENUMBER
# NeXusOntology.NX_WAVENUMBER
# unit class NeXusOntology.NX_WAVENUMBER
# !! NXdata.en NXsqom
# !! https://manual.nexusformat.org/classes/applications/NXsqom.html
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXdata.stxm_scan_type NXstxm
# !! https://manual.nexusformat.org/classes/applications/NXstxm.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.sample_y NXstxm
# !! https://manual.nexusformat.org/classes/applications/NXstxm.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.sample_x NXstxm
# !! https://manual.nexusformat.org/classes/applications/NXstxm.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdata.wavelength NXxlaue
# !! https://manual.nexusformat.org/classes/applications/NXxlaue.html
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXdetector.time_of_flight None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-time-of-flight-field
# NX_TIME_OF_FLIGHT
# NeXusOntology.NX_TIME_OF_FLIGHT
# unit class NeXusOntology.NX_TIME_OF_FLIGHT
# !! NXdetector.raw_time_of_flight None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-raw-time-of-flight-field
# NX_PULSES
# NeXusOntology.NX_PULSES
# unit class NeXusOntology.NX_PULSES
# !! NXdetector.detector_number None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-detector-number-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.data None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-data-field
# NX_ANY
# NeXusOntology.NX_ANY
# unit class NeXusOntology.NX_ANY
# !! NXdetector.data_errors None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-data-errors-field
# NX_ANY
# NeXusOntology.NX_ANY
# unit class NeXusOntology.NX_ANY
# !! NXdetector.x_pixel_offset None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-x-pixel-offset-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.y_pixel_offset None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-y-pixel-offset-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.z_pixel_offset None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-z-pixel-offset-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.distance None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-distance-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.polar_angle None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-polar-angle-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdetector.azimuthal_angle None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-azimuthal-angle-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdetector.description None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-description-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.serial_number None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-serial-number-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.local_name None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-local-name-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.solid_angle None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-solid-angle-field
# NX_SOLID_ANGLE
# NeXusOntology.NX_SOLID_ANGLE
# unit class NeXusOntology.NX_SOLID_ANGLE
# !! NXdetector.x_pixel_size None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-x-pixel-size-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.y_pixel_size None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-y-pixel-size-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.dead_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-dead-time-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.gas_pressure None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-gas-pressure-field
# NX_PRESSURE
# NeXusOntology.NX_PRESSURE
# unit class NeXusOntology.NX_PRESSURE
# !! NXdetector.detection_gas_path None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-detection-gas-path-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.crate None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-crate-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.slot None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-slot-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.input None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-input-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.type None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-type-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.real_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-real-time-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.start_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-start-time-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.stop_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-stop-time-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.calibration_date None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-calibration-date-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.layout None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-layout-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.count_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-count-time-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.sequence_number None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-sequence-number-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.beam_center_x None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-beam-center-x-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.beam_center_y None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-beam-center-y-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.frame_start_number None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-frame-start-number-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.diameter None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-diameter-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.acquisition_mode None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-acquisition-mode-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.angular_calibration_applied None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-angular-calibration-applied-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.angular_calibration None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-angular-calibration-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.flatfield_applied None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-flatfield-applied-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.flatfield None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-flatfield-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.flatfield_errors None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-flatfield-errors-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.pixel_mask_applied None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-pixel-mask-applied-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.pixel_mask None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-pixel-mask-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.countrate_correction_applied None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-countrate-correction-applied-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.bit_depth_readout None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-bit-depth-readout-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.detector_readout_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-detector-readout-time-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.trigger_delay_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-trigger-delay-time-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.trigger_delay_time_set None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-trigger-delay-time-set-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.trigger_internal_delay_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-trigger-internal-delay-time-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.trigger_dead_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-trigger-dead-time-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.frame_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-frame-time-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.gain_setting None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-gain-setting-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.saturation_value None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-saturation-value-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.underload_value None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-underload-value-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.number_of_cycles None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-number-of-cycles-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.sensor_material None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-sensor-material-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.sensor_thickness None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-sensor-thickness-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.threshold_energy None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector.html#nxdetector-threshold-energy-field
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXdetector.lens_mode NXarpes
# !! https://manual.nexusformat.org/classes/applications/NXarpes.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.entrance_slit_shape NXarpes
# !! https://manual.nexusformat.org/classes/applications/NXarpes.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.entrance_slit_setting NXarpes
# !! https://manual.nexusformat.org/classes/applications/NXarpes.html
# NX_ANY
# NeXusOntology.NX_ANY
# unit class NeXusOntology.NX_ANY
# !! NXdetector.entrance_slit_size NXarpes
# !! https://manual.nexusformat.org/classes/applications/NXarpes.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.pass_energy NXarpes
# !! https://manual.nexusformat.org/classes/applications/NXarpes.html
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXdetector.time_per_channel NXarpes
# !! https://manual.nexusformat.org/classes/applications/NXarpes.html
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXdetector.angles NXarpes
# !! https://manual.nexusformat.org/classes/applications/NXarpes.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdetector.energies NXarpes
# !! https://manual.nexusformat.org/classes/applications/NXarpes.html
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXdetector.sensor_size NXarpes
# !! https://manual.nexusformat.org/classes/applications/NXarpes.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.region_origin NXarpes
# !! https://manual.nexusformat.org/classes/applications/NXarpes.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.region_size NXarpes
# !! https://manual.nexusformat.org/classes/applications/NXarpes.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.name NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.SDD NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.slit_length NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_PER_LENGTH
# NeXusOntology.NX_PER_LENGTH
# unit class NeXusOntology.NX_PER_LENGTH
# !! NXdetector.x_position NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.y_position NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXdetector.roll NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdetector.pitch NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdetector.yaw NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdetector.energy NXfluo
# !! https://manual.nexusformat.org/classes/applications/NXfluo.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.depends_on NXmx
# !! https://manual.nexusformat.org/classes/applications/NXmx.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.distance_derived NXmx
# !! https://manual.nexusformat.org/classes/applications/NXmx.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.beam_center_derived NXmx
# !! https://manual.nexusformat.org/classes/applications/NXmx.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.flatfield_error NXmx
# !! https://manual.nexusformat.org/classes/applications/NXmx.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.rotation_angle NXsas
# !! https://manual.nexusformat.org/classes/applications/NXsas.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdetector.aequatorial_angle NXsas
# !! https://manual.nexusformat.org/classes/applications/NXsas.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdetector.image_key NXtomo
# !! https://manual.nexusformat.org/classes/applications/NXtomo.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.x_rotation_axis_pixel_position NXtomo
# !! https://manual.nexusformat.org/classes/applications/NXtomo.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.y_rotation_axis_pixel_position NXtomo
# !! https://manual.nexusformat.org/classes/applications/NXtomo.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector.tilt_angle NXxnb
# !! https://manual.nexusformat.org/classes/applications/NXxnb.html
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXdetector_group.group_names None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector_group.html#nxdetector-group-group-names-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXdetector_group.group_index None
# !! https://manual.nexusformat.org/classes/base_classes/NXdetector_group.html#nxdetector-group-group-index-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# ...
# NX_EMITTANCE
# NeXusOntology.NX_EMITTANCE
# unit class NeXusOntology.NX_EMITTANCE
# !! NXsource.emittance_y None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-emittance-y-field
# NX_EMITTANCE
# NeXusOntology.NX_EMITTANCE
# unit class NeXusOntology.NX_EMITTANCE
# !! NXsource.sigma_x None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-sigma-x-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXsource.sigma_y None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-sigma-y-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXsource.flux None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-flux-field
# NX_FLUX
# NeXusOntology.NX_FLUX
# unit class NeXusOntology.NX_FLUX
# !! NXsource.energy None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-energy-field
# NX_ENERGY
# NeXusOntology.NX_ENERGY
# unit class NeXusOntology.NX_ENERGY
# !! NXsource.current None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-current-field
# NX_CURRENT
# NeXusOntology.NX_CURRENT
# unit class NeXusOntology.NX_CURRENT
# !! NXsource.voltage None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-voltage-field
# NX_VOLTAGE
# NeXusOntology.NX_VOLTAGE
# unit class NeXusOntology.NX_VOLTAGE
# !! NXsource.frequency None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-frequency-field
# NX_FREQUENCY
# NeXusOntology.NX_FREQUENCY
# unit class NeXusOntology.NX_FREQUENCY
# !! NXsource.period None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-period-field
# NX_PERIOD
# NeXusOntology.NX_PERIOD
# unit class NeXusOntology.NX_PERIOD
# !! NXsource.target_material None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-target-material-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsource.number_of_bunches None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-number-of-bunches-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsource.bunch_length None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-bunch-length-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXsource.bunch_distance None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-bunch-distance-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXsource.pulse_width None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-pulse-width-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXsource.mode None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-mode-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsource.top_up None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-top-up-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsource.last_fill None
# !! https://manual.nexusformat.org/classes/base_classes/NXsource.html#nxsource-last-fill-field
# NX_CURRENT
# NeXusOntology.NX_CURRENT
# unit class NeXusOntology.NX_CURRENT
# !! NXsource.radiation NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsource.beam_shape NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsource.incident_wavelength NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXsource.wavelength_min NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXsource.wavelength_max NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXsource.incident_wavelength_spread NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXsource.beam_size_x NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXsource.beam_size_y NXcanSAS
# !! https://manual.nexusformat.org/classes/applications/NXcanSAS.html
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXsubentry.title None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-title-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.experiment_identifier None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-experiment-identifier-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.experiment_description None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-experiment-description-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.collection_identifier None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-collection-identifier-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.collection_description None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-collection-description-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.entry_identifier None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-entry-identifier-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.definition None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-definition-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.definition_local None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-definition-local-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.start_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-start-time-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.end_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-end-time-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.duration None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-duration-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXsubentry.collection_time None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-collection-time-field
# NX_TIME
# NeXusOntology.NX_TIME
# unit class NeXusOntology.NX_TIME
# !! NXsubentry.run_cycle None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-run-cycle-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.program_name None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-program-name-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.revision None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-revision-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXsubentry.pre_sample_flightpath None
# !! https://manual.nexusformat.org/classes/base_classes/NXsubentry.html#nxsubentry-pre-sample-flightpath-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXtransformations.AXISNAME None
# !! https://manual.nexusformat.org/classes/base_classes/NXtransformations.html#nxtransformations-axisname-field
# NX_TRANSFORMATION
# NeXusOntology.NX_TRANSFORMATION
# unit class NeXusOntology.NX_TRANSFORMATION
# !! NXtransformations.AXISNAME_end None
# !! https://manual.nexusformat.org/classes/base_classes/NXtransformations.html#nxtransformations-axisname-end-field
# NX_TRANSFORMATION
# NeXusOntology.NX_TRANSFORMATION
# unit class NeXusOntology.NX_TRANSFORMATION
# !! NXtransformations.AXISNAME_increment_set None
# !! https://manual.nexusformat.org/classes/base_classes/NXtransformations.html#nxtransformations-axisname-increment-set-field
# NX_TRANSFORMATION
# NeXusOntology.NX_TRANSFORMATION
# unit class NeXusOntology.NX_TRANSFORMATION
# !! NXtranslation.distances None
# !! https://manual.nexusformat.org/classes/base_classes/NXtranslation.html#nxtranslation-distances-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXuser.name None
# !! https://manual.nexusformat.org/classes/base_classes/NXuser.html#nxuser-name-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXuser.role None
# !! https://manual.nexusformat.org/classes/base_classes/NXuser.html#nxuser-role-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXuser.affiliation None
# !! https://manual.nexusformat.org/classes/base_classes/NXuser.html#nxuser-affiliation-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXuser.address None
# !! https://manual.nexusformat.org/classes/base_classes/NXuser.html#nxuser-address-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXuser.telephone_number None
# !! https://manual.nexusformat.org/classes/base_classes/NXuser.html#nxuser-telephone-number-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXuser.fax_number None
# !! https://manual.nexusformat.org/classes/base_classes/NXuser.html#nxuser-fax-number-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXuser.email None
# !! https://manual.nexusformat.org/classes/base_classes/NXuser.html#nxuser-email-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXuser.facility_user_id None
# !! https://manual.nexusformat.org/classes/base_classes/NXuser.html#nxuser-facility-user-id-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXuser.ORCID None
# !! https://manual.nexusformat.org/classes/base_classes/NXuser.html#nxuser-orcid-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXvelocity_selector.type None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-type-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXvelocity_selector.rotation_speed None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-rotation-speed-field
# NX_FREQUENCY
# NeXusOntology.NX_FREQUENCY
# unit class NeXusOntology.NX_FREQUENCY
# !! NXvelocity_selector.radius None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-radius-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXvelocity_selector.spwidth None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-spwidth-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXvelocity_selector.length None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-length-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXvelocity_selector.num None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-num-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXvelocity_selector.twist None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-twist-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXvelocity_selector.table None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-table-field
# NX_ANGLE
# NeXusOntology.NX_ANGLE
# unit class NeXusOntology.NX_ANGLE
# !! NXvelocity_selector.height None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-height-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXvelocity_selector.width None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-width-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXvelocity_selector.wavelength None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-wavelength-field
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXvelocity_selector.wavelength_spread None
# !! https://manual.nexusformat.org/classes/base_classes/NXvelocity_selector.html#nxvelocity-selector-wavelength-spread-field
# NX_WAVELENGTH
# NeXusOntology.NX_WAVELENGTH
# unit class NeXusOntology.NX_WAVELENGTH
# !! NXxraylens.lens_geometry None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-lens-geometry-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXxraylens.symmetric None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-symmetric-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXxraylens.cylindrical None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-cylindrical-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXxraylens.focus_type None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-focus-type-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXxraylens.lens_thickness None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-lens-thickness-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXxraylens.lens_length None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-lens-length-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXxraylens.curvature None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-curvature-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXxraylens.aperture None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-aperture-field
# NX_LENGTH
# NeXusOntology.NX_LENGTH
# unit class NeXusOntology.NX_LENGTH
# !! NXxraylens.number_of_lenses None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-number-of-lenses-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXxraylens.lens_material None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-lens-material-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXxraylens.gas None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-gas-field
# NX_UNITLESS
# NeXusOntology.NX_UNITLESS
# unit class NeXusOntology.NX_UNITLESS
# !! NXxraylens.gas_pressure None
# !! https://manual.nexusformat.org/classes/base_classes/NXxraylens.html#nxxraylens-gas-pressure-field
# NX_PRESSURE
# NeXusOntology.NX_PRESSURE
# unit class NeXusOntology.NX_PRESSURE

# %%
_nx_field.range = [unit_class]

# %%
unit_class
# Out:
# NeXusOntology.NX_PRESSURE

# %%
# create individuals 


with onto:
        
    sample_temp_1 = typesDict['NX_TEMPERATURE']['class']('sample_temp_1')
    sample_temp_1.hasUnit = 'Kelvin'
    sample_temp_1.hasValue = 10
    
    dataset_1 = dataset('dataset1')
    setattr(dataset_1,'NXsample.temperature', [sample_temp_1])
    
    
    beam_energy_1 = typesDict['NX_ENERGY']['class']('beam_energy_1')
    beam_energy_1.hasUnit = 'keV'
    beam_energy_1.hasValue = 12.4
    
    dataset_2 = dataset('dataset2')
    setattr(dataset_2,'NXbeam.final_energy', [beam_energy_1])
    
    

        
onto.save()
