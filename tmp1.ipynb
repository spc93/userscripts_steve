# %%
import sys
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from dlstools import *
from dlstools.pdnx import *
from matplotlib.pyplot import *

# %matplotlib inline

p='/dls/i16/data/2020/cm26473-1/DAQ-2020-07-05/%i.nxs'
# Out:
# === Importing dlstools package

# %%
n = pdnx(p % 822456)

# %%
n
# Out:
#      count_time  filepath  kphiZebra
# 0         0.097       0.0     56.044
# 1         0.097       0.0     56.055
# 2         0.097       0.0     56.064
# 3         0.097       0.0     56.075
# ..          ...       ...        ...
# 197       0.097       0.0     58.015
# 198       0.097       0.0     58.025
# 199       0.097       0.0     58.035
# 200       0.097       0.0     58.045
#
# [201 rows x 3 columns]

# %%
print(n.nx.entry1.kphiZebraPil3.tree)
n.nx.entry1.kphiZebraPil3.data[100].plot()
sum(sum(n.nx.entry1.kphiZebraPil3.data[10]))
# Out:
# kphiZebraPil3:NXdata
#   data -> 822456-pilatus3_100k-files/822456.hdf['/entry/instrument/detector/data']
#   image_data -> /entry1/instrument/kphiZebraPil3/image_data
#   kphiZebra -> /entry1/instrument/kphiZebra/kphiZebra
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-bbacc53813b2> in <module>
#       1 print(n.nx.entry1.kphiZebraPil3.tree)
#       2 n.nx.entry1.kphiZebraPil3.data[100].plot()
# ----> 3 sum(sum(n.nx.entry1.kphiZebraPil3.data[10]))
#
# <__array_function__ internals> in sum(*args, **kwargs)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.7/lib/python3.7/site-packages/numpy/core/fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial, where)
#    2227
#    2228     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2229                           initial=initial, where=where)
#    2230
#    2231
#
# ...

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   entry1:NXentry
#     before_scan:NXcollection
#       PPR:NXcollection
#         ppchi = -10.000026645
#         pppiezo1 = 0.0
#         pppiezo2 = 12345.012359999999
#         ppth1 = -41.7461233774
#         ppth2 = 31.7846731514
#         ppz1 = 26.0
#         ppz2 = 25.0
#       alpha:NXcollection
#         alpha = 1.0003049258144199
#       beamline_slits:NXcollection
#         s1xcentre = -0.0055
#         s1xgap = 2.511
#         s1ycentre = 0.001
#         s1ygap = 1.0
#         s2xcentre = -0.00079375
#         s2xgap = 4.9988625
#         s2ycentre = 0.499
#         s2ygap = 20.0
#         s3xcentre = 2.69725
#         s3xgap = 25.0015
#         s3ycentre = -0.682
#         s3ygap = 20.125
#         s4xcentre = -5.875
#         s4xgap = 36.6504
#         s4ycentre = 0.0
#         s4ygap = 28.005
#         shtr3x = 11.93
#         shtr3y = 4.32
#       beta:NXcollection
#         beta = -1.0005114925421854
#       delta_offset:NXcollection
# ...

# %%
n.find('program_name')
# Out:
# .nx.entry1.program_name : 	 GDA 9.17.0

# %%
from numpy import *
arccos(1/sqrt(3))*180/pi
# Out:
# 54.735610317245346
