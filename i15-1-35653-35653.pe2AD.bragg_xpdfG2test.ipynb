# %%
inpath = "/dls/i15-1/data/2020/cy24550-3/processed/i15-1-35653-35653.pe2AD.bragg.nxs"

# %%
outpath = "/dls/i15-1/data/2020/cy24550-3/processed/notebooks/i15-1-35653-35653.pe2AD.bragg_xpdfG2test.nxs"

# %%
import sys
sys.path.append('/dls_sw/i15-1/scripts/notebooks')
from XpdfG2 import XpdfG2, XpdfG2NX
# Out:
# GSAS-II binary directory: /dls_sw/apps/python/anaconda/4.6.14/64/envs/GSAS2/GSASII/bindist
# 6 values read from config file /dls_sw/apps/python/anaconda/4.6.14/64/envs/GSAS2/GSASII/config.py

# %%
pdf = XpdfG2NX(inpath,gda2=True)
# Out:
# /dls/i15-1/data/2020/cy24550-3/processed/tmp/i15-1-35653-35653.pe2AD.bragg_sam.xy read by Reader comma/tab/semicolon separated
# Instrument parameters read: /dls_sw/i15-1/scripts/Xpdf/ProcessingFiles/xpdf_76keV_1p5mm_cap.instprm (G2 fmt) bank None
# /dls/i15-1/data/2020/cy24550-3/processed/tmp/i15-1-35653-35653.pe2AD.bragg_con1.xy read by Reader comma/tab/semicolon separated
# Instrument parameters read: /dls_sw/i15-1/scripts/Xpdf/ProcessingFiles/xpdf_76keV_1p5mm_cap.instprm (G2 fmt) bank None
#   Optimizing corrections to improve G(r) at low r
#   start: Flat Bkg=0.0, BackRatio=0.000, Ruland=0.025 (RMS:60.7657)
#   end:   Flat Bkg=318.9, BackRatio=0.000, Ruland=0.015) *** 5.352902243993881 ***
#
#   Optimizing corrections to improve G(r) at low r
#   start: Flat Bkg=318.9, BackRatio=0.000, Ruland=0.015 (RMS:5.3529)
#   end:   Flat Bkg=561.6, BackRatio=0.051, Ruland=0.013) *** 5.083620653226221 ***
#
#   Optimizing corrections to improve G(r) at low r
# ...

# %% [markdown]
# Plotting processed data:

# %%
pdf.plot('Bragg')

# %%
pdf.plot('S(Q)')

# %%
pdf.plot('G(R)')

# %%
pdf.save_nexus(outpath)
