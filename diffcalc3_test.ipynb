# %%
# maybe have functions with no bracket return string output and with () return values or dict?

# %%
import sys
sys.path.append('/dls_sw/apps/diffcalc/3/diffcalc3')

# %%
from startup.i16 import * 

newub("Example_i16")
setlat("SiO2", 4.913, 5.405)
ub()
sixc()
pos(mu, -2)
addorient([0, 0, 1], [0, 0, 1], sixc(), "norm")
addorient([0, 1, 0], [0, 1, 0], sixc(), "plane")
setnhkl([1, 0, 0])
con(qaz, 0, alpha, 0, eta,  0)
hkl_to_angles(0, 0, 1)
angles_to_hkl((0.0, 0.0, 0.0, 3.31, 0.0, 10.62))
sim(hkl, [0, 0, 1])
pos(hkl, [0, 0, 1])
scan(alpha, 0, 10, 1, hkl, [0, 0, 1], sixc, hklverbose.alpha, hklverbose.beta)
scan(qaz, 0, 90, 10, hkl, [0, 0, 1], sixc, hklverbose.alpha, hklverbose.beta)
con(qaz, 90, psi, 90, chi, 90)
scan(psi, 90, 0, 10, hkl, [0, 0, 1], sixc, hklverbose.alpha, hklverbose.beta)
setmiscut(0)
scan(psi, 90, 0, 10, hkl, [0, 0, 1], sixc, hklverbose.alpha, hklverbose.beta)
# Out:
# WARNING: There is no record of the last ub calculation used
# UBCALC
#
#    name:     Example_i16
#
# REFERNCE
#
#    n_hkl:      1.00000   0.00000   0.00000 <- set
#
# SURFACE NORMAL
#
#    n_phi:      0.00000   0.00000   1.00000 <- set
#
# CRYSTAL
#
#    name:          SiO2
#
#    a, b, c:    4.91300   4.91300   5.40500
#               90.00000  90.00000  90.00000  Tetragonal
#
#    B matrix:   1.27889   0.00000   0.00000
#                0.00000   1.27889   0.00000
#                0.00000   0.00000   1.16248
#
# UB MATRIX
#
#    <<< none calculated >>>
#
# REFLECTIONS
#
#    <<< none specified >>>
#
# CRYSTAL ORIENTATIONS
#
#    <<< none specified >>>
# mu:       -2.0000
# Calculating UB matrix.
#    n_phi:  1.00000  -0.00000  -0.00000
#    n_hkl:  1.00000   0.00000   0.00000 <- set
#     qaz  : 0.0000
#     alpha: 0.0000
#     eta  : 0.0000
# euler would move to:
#       phi :    0.0000
#       chi :    0.0000
#       eta :    0.0000
#        mu :    3.3078
#     delta :    0.0000
#       gam :   10.6157
#
#     alpha :    0.0000
#      beta :   -0.0000
#    betain :    3.3078
#   betaout :    7.3078
#       naz :   90.0000
#       psi :  -90.0000
#       qaz :    0.0000
#       tau :   90.0000
#     theta :    5.3078
#    ttheta :   10.6157
# hkl:      h: 0.00000 k: 0.00000 l: 1.00000
#   alpha      phi      chi      eta       mu    delta       gam    alpha      beta        h        k        l
# -------  -------  -------  -------  -------  -------  --------  -------  --------  -------  -------  -------
# 0.00000   0.0000   0.0000   0.0000   3.3078   0.0000   10.6157  0.00000  -0.00000  0.00000  0.00000  1.00000
# 1.00000   1.0037   0.0350   0.0000   3.3082   0.0000   10.6157  1.00000  -1.00000  -0.00000  0.00000  1.00000
# 2.00000   2.0074   0.0701   0.0000   3.3091   0.0000   10.6157  2.00000  -2.00000  -0.00000  0.00000  1.00000
# 3.00000   3.0111   0.1051   0.0000   3.3106   0.0000   10.6157  3.00000  -3.00000  -0.00000  0.00000  1.00000
# 4.00000   4.0148   0.1401   0.0000   3.3128   0.0000   10.6157  4.00000  -4.00000  -0.00000  0.00000  1.00000
# 5.00000   5.0185   0.1750   0.0000   3.3155   0.0000   10.6157  5.00000  -5.00000  -0.00000  0.00000  1.00000
# 6.00000   6.0223   0.2099   0.0000   3.3189   0.0000   10.6157  6.00000  -6.00000  -0.00000  0.00000  1.00000
# 7.00000   7.0261   0.2447   0.0000   3.3229   0.0000   10.6157  7.00000  -7.00000  -0.00000  0.00000  1.00000
# 8.00000   8.0298   0.2795   0.0000   3.3275   0.0000   10.6157  8.00000  -8.00000  -0.00000  0.00000  1.00000
# 9.00000   9.0337   0.3142   0.0000   3.3327   0.0000   10.6157  9.00000  -9.00000  -0.00000  0.00000  1.00000
# 10.00000   10.0375   0.3487   0.0000   3.3385   0.0000   10.6157  10.00000  -10.00000  -0.00000  0.00000  1.00000
#     qaz       phi      chi      eta       mu    delta       gam     alpha       beta         h        k        l
# -------  --------  -------  -------  -------  -------  --------  --------  ---------  --------  -------  -------
# 0.00000   10.0375   0.3487   0.0000   3.3385   0.0000   10.6157  10.00000  -10.00000  -0.00000  0.00000  1.00000
# 10.00000   10.6265   10.3316   0.0000   3.3935   1.8332   10.4580  10.00000  -10.00000  -0.00000  0.00000  1.00000
# 20.00000   11.2545   20.3133   0.0000   3.5601   3.6124    9.9888  10.00000  -10.00000  -0.00000  0.00000  1.00000
# 30.00000   11.9700   30.2924   0.0000   3.8671   5.2850    9.2197  10.00000  -10.00000   0.00000  -0.00000  1.00000
# 40.00000   12.8494   40.2668   0.0000   4.3769   6.8006    8.1706  10.00000  -10.00000  -0.00000  0.00000  1.00000
# 50.00000   14.0365   50.2321   0.0000   5.2232   8.1127    6.8697  10.00000  -10.00000  -0.00000  -0.00000  1.00000
# 60.00000   15.8581   60.1790   0.0000   6.7248   9.1802    5.3538  10.00000  -10.00000  -0.00000  0.00000  1.00000
# 70.00000   19.2795   70.0788   0.0000   9.8407   9.9687    3.6679  10.00000  -10.00000  -0.00000  -0.00000  1.00000
# 80.00000   28.9211   79.7934   0.0000   19.1858   10.4526    1.8641  10.00000  -10.00000  -0.00000  -0.00000  1.00000
# 90.00000   105.9940   86.6434   0.0000   95.9667   10.6157    0.0000  10.00000  -10.00000   0.00000  -0.00000  1.00000
#     qaz  : 90.0000
#     psi  : 90.0000
#     chi  : 90.0000
#      psi        phi       chi      eta       mu     delta      gam     alpha     beta         h        k        l
# --------  ---------  --------  -------  -------  --------  -------  --------  -------  --------  -------  -------
# 90.00000   180.0000   90.0000   7.3078   0.0000   10.6157   0.0000  -0.00000  0.00000  -0.00000  0.00000  1.00000
# 80.00000  -172.7229   90.0000   7.2857  -2.7390   10.6157   0.0000  -9.95668  9.95668  -0.00000  0.00000  1.00000
# 70.00000  -165.4184   90.0000   7.2196  -5.4501   10.6157   0.0000  -19.91060  19.91060  -0.00000  0.00000  1.00000
# 60.00000  -158.0578   90.0000   7.1104  -8.1041   10.6157   0.0000  -29.85826  29.85826  -0.00000  0.00000  1.00000
# 50.00000  -150.6099   90.0000   6.9594  -10.6695   10.6157   0.0000  -39.79416  39.79416  -0.00000  0.00000  1.00000
# 40.00000  -143.0397   90.0000   6.7686  -13.1108   10.6157   0.0000  -49.70809  49.70809  -0.00000  0.00000  1.00000
# 30.00000  -135.3065   90.0000   6.5407  -15.3868   10.6157   0.0000  -59.57716  59.57716  -0.00000  0.00000  1.00000
# 20.00000  -127.3618   90.0000   6.2789  -17.4490   10.6157   0.0000  -69.33556  69.33556  -0.00000  0.00000  1.00000
# 10.00000  -119.1467   90.0000   5.9874  -19.2380   10.6157   0.0000  -78.69131  78.69131  -0.00000  0.00000  1.00000
#  0.00000  -110.5885   90.0000   5.6711  -20.6812   10.6157   0.0000  -84.69215  84.69215  -0.00000  0.00000  1.00000
# Recalculating UB matrix.
#    n_phi:  0.00000   0.00000   1.00000 <- set
#    n_hkl:  0.00000   0.00000   1.00000
#      psi        phi       chi      eta       mu     delta      gam    alpha      beta        h        k        l
# --------  ---------  --------  -------  -------  --------  -------  -------  --------  -------  -------  -------
# 90.00000   180.0000   90.0000   5.3078   0.0000   10.6157   0.0000  0.00000  -0.00000  0.00000  0.00000  1.00000
# 80.00000  -170.0000   90.0000   5.3078   0.0000   10.6157   0.0000  -9.95668   9.95668  0.00000  0.00000  1.00000
# 70.00000  -160.0000   90.0000   5.3078   0.0000   10.6157   0.0000  -19.91060  19.91060  0.00000  0.00000  1.00000
# 60.00000  -150.0000   90.0000   5.3078   0.0000   10.6157   0.0000  -29.85826  29.85826  -0.00000  0.00000  1.00000
# 50.00000  -140.0000   90.0000   5.3078   0.0000   10.6157   0.0000  -39.79416  39.79416  -0.00000  0.00000  1.00000
# 40.00000  -130.0000   90.0000   5.3078   0.0000   10.6157   0.0000  -49.70809  49.70809  -0.00000  0.00000  1.00000
# 30.00000  -120.0000   90.0000   5.3078   0.0000   10.6157   0.0000  -59.57716  59.57716  -0.00000  0.00000  1.00000
# 20.00000  -110.0000   90.0000   5.3078   0.0000   10.6157   0.0000  -69.33556  69.33556  -0.00000  0.00000  1.00000
# 10.00000  -100.0000   90.0000   5.3078   0.0000   10.6157   0.0000  -78.69131  78.69131  -0.00000  0.00000  1.00000
#  0.00000   -90.0000   90.0000   5.3078   0.0000   10.6157   0.0000  -84.69215  84.69215  -0.00000  0.00000  1.00000

# %%
ub()
# Out:
# UBCALC
#
#    name:     Example_i16
#
# REFERNCE
#
#    n_phi:      1.00000   0.00000   0.00000
#    n_hkl:      1.00000   0.00000   0.00000 <- set
#
# SURFACE NORMAL
#
#    n_phi:      0.00000   0.00000   1.00000 <- set
#    n_hkl:      0.00000   0.00000   1.00000
#
# CRYSTAL
#
#    name:          SiO2
#
#    a, b, c:    4.91300   4.91300   5.40500
#               90.00000  90.00000  90.00000  Tetragonal
#
#    B matrix:   1.27889   0.00000   0.00000
#                0.00000   1.27889   0.00000
#                0.00000   0.00000   1.16248
#
# UB MATRIX
#
#    U matrix:   1.00000   0.00000   0.00000
#                0.00000   1.00000   0.00000
#                0.00000   0.00000   1.00000
#
#    miscut angle:  0
#
#    UB matrix:  1.27889   0.00000   0.00000
#                0.00000   1.27889   0.00000
#                0.00000   0.00000   1.16248
#
# REFLECTIONS
#
#    <<< none specified >>>
#
# CRYSTAL ORIENTATIONS
#
#          H     K     L       X     Y     Z       PHI      CHI      ETA       MU    DELTA      GAM  TAG
#    1  0.00  0.00  1.00   0.00  0.00  1.00    0.0000   0.0000   0.0000  -2.0000   0.0000   0.0000  norm
#    2  0.00  1.00  0.00   0.00  1.00  0.00    0.0000   0.0000   0.0000  -2.0000   0.0000   0.0000  plane

# %%
sim(hkl, [0, 0, 1])
# Out:
# euler would move to:
#       phi :  -90.0000
#       chi :   90.0000
#       eta :    5.3078
#        mu :    0.0000
#     delta :   10.6157
#       gam :    0.0000
#
#     alpha :  -84.6922
#      beta :   84.6922
#    betain :    5.3078
#   betaout :    5.3078
#       naz :   90.0000
#       psi :    0.0000
#       qaz :   90.0000
#       tau :   90.0000
#     theta :    5.3078
#    ttheta :   10.6157

# %%
a = sim(hkl, [0, 0, 1])
# Out:
# euler would move to:
#       phi :  -90.0000
#       chi :   90.0000
#       eta :    5.3078
#        mu :    0.0000
#     delta :   10.6157
#       gam :    0.0000
#
#     alpha :  -84.6922
#      beta :   84.6922
#    betain :    5.3078
#   betaout :    5.3078
#       naz :   90.0000
#       psi :    0.0000
#       qaz :   90.0000
#       tau :   90.0000
#     theta :    5.3078
#    ttheta :   10.6157

# %%
a

# %%
ub()
# Out:
# UBCALC
#
#    name:     Example_i16
#
# REFERNCE
#
#    n_phi:      1.00000   0.00000   0.00000
#    n_hkl:      1.00000   0.00000   0.00000 <- set
#
# SURFACE NORMAL
#
#    n_phi:      0.00000   0.00000   1.00000 <- set
#    n_hkl:      0.00000   0.00000   1.00000
#
# CRYSTAL
#
#    name:          SiO2
#
#    a, b, c:    4.91300   4.91300   5.40500
#               90.00000  90.00000  90.00000  Tetragonal
#
#    B matrix:   1.27889   0.00000   0.00000
#                0.00000   1.27889   0.00000
#                0.00000   0.00000   1.16248
#
# UB MATRIX
#
#    U matrix:   1.00000   0.00000   0.00000
#                0.00000   1.00000   0.00000
#                0.00000   0.00000   1.00000
#
#    miscut angle:  0
#
#    UB matrix:  1.27889   0.00000   0.00000
#                0.00000   1.27889   0.00000
#                0.00000   0.00000   1.16248
#
# REFLECTIONS
#
#    <<< none specified >>>
#
# CRYSTAL ORIENTATIONS
#
#          H     K     L       X     Y     Z       PHI      CHI      ETA       MU    DELTA      GAM  TAG
#    1  0.00  0.00  1.00   0.00  0.00  1.00    0.0000   0.0000   0.0000  -2.0000   0.0000   0.0000  norm
#    2  0.00  1.00  0.00   0.00  1.00  0.00    0.0000   0.0000   0.0000  -2.0000   0.0000   0.0000  plane

# %%
a = ub()
# Out:
# UBCALC
#
#    name:     Example_i16
#
# REFERNCE
#
#    n_phi:      1.00000   0.00000   0.00000
#    n_hkl:      1.00000   0.00000   0.00000 <- set
#
# SURFACE NORMAL
#
#    n_phi:      0.00000   0.00000   1.00000 <- set
#    n_hkl:      0.00000   0.00000   1.00000
#
# CRYSTAL
#
#    name:          SiO2
#
#    a, b, c:    4.91300   4.91300   5.40500
#               90.00000  90.00000  90.00000  Tetragonal
#
#    B matrix:   1.27889   0.00000   0.00000
#                0.00000   1.27889   0.00000
#                0.00000   0.00000   1.16248
#
# UB MATRIX
#
#    U matrix:   1.00000   0.00000   0.00000
#                0.00000   1.00000   0.00000
#                0.00000   0.00000   1.00000
#
#    miscut angle:  0
#
#    UB matrix:  1.27889   0.00000   0.00000
#                0.00000   1.27889   0.00000
#                0.00000   0.00000   1.16248
#
# REFLECTIONS
#
#    <<< none specified >>>
#
# CRYSTAL ORIENTATIONS
#
#          H     K     L       X     Y     Z       PHI      CHI      ETA       MU    DELTA      GAM  TAG
#    1  0.00  0.00  1.00   0.00  0.00  1.00    0.0000   0.0000   0.0000  -2.0000   0.0000   0.0000  norm
#    2  0.00  1.00  0.00   0.00  1.00  0.00    0.0000   0.0000   0.0000  -2.0000   0.0000   0.0000  plane

# %%
a
