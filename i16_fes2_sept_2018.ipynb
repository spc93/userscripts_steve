# %%
import sys
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from dlstools.dataloader import *
from dlstools import *
from matplotlib.pyplot import *
from dlstools.quickfit import *
from dlstools.dirty_fit import fit
# %matplotlib nbagg

p='/dls/i16/data/2018/cm19668-4/%i.nxs'

# %%
#Jun FeS2 001 natural 8 keV
n=pdnx(p % 710942);
n.plot(x='eta', y=['sum','maxval']); title(n.scan)
fit(gauss_c)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Function name: gaussian + const
#       area:              334 +/- 3
#     centre:         34.90263 +/- 0.00005
#      width:          0.01277 +/- 0.00013
#   constant:              406 +/- 68

# %% [markdown]
# #Steve FeS2 001 natural 8 keV on cryo mount
# n=pdnx(p % 710969);
# n.plot(x='eta', y='sum'); title(n.scan)
# fit(gauss_c)

# %%
#Jun FeS2 022 natural polished 8 keV
n=pdnx(p % 710981);
n.plot(x='eta', y=['sum','maxval']); title(n.scan)
fit(gauss_c)

# %% [markdown]
# # Now 2.5 keV

# %% [markdown]
# # Have eta scans vs energy (see book) - peak @ 2.4697 keV

# %% [markdown]
# ## FeS2 001 sigma-pi resonance peak

# %%
figure(); 
for scan in range(711537, 711537+36+1):
    n=pdnx(p % scan);
    psi=n.nx.entry1.before_scan.diffractometer_sample.psi * np.ones(n.eta.shape)
    gca(projection='3d').plot(np.array(n.eta), np.array(psi), np.array(n.APD))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## FeS2 001 total intensity resonance peak

# %%
figure(); 
for scan in range(711574, 711574+36+1):
    n=pdnx(p % scan);
    psi=n.nx.entry1.before_scan.diffractometer_sample.psi * np.ones(n.eta.shape)
    gca(projection='3d').plot(np.array(n.eta), np.array(psi), np.array(n['sum']))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## FeS2 002 total intensity resonance peak

# %%
figure(); 
for scan in range(711611, 711611+36+1):
    n=pdnx(p % scan);
    psi=n.nx.entry1.before_scan.diffractometer_sample.psi * np.ones(n.eta.shape)
    gca(projection='3d').plot(np.array(n.eta), np.array(psi), np.array(n['sum']))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Fluo scan on FeS2 delta 130 eta 90
# No helium ~ 5 cm air before and after sample; Pilatus threshold 2 keV
#
# Is second dip due to a glitch?

# %%
figure(); 
n=pdnx(p % 711876); plot(n.DCMenergy, n['sum']); plot(n.DCMenergy, n.ic1monitor); title(n.scan)
n=pdnx(p % 711877); plot(n.DCMenergy, n['sum']); plot(n.DCMenergy, n.ic1monitor); title(n.scan)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5,1,u'/dls/i16/data/2018/cm19668-4/711877.nxs\nscan energy 2.46 2.5 2.5E-4 pil3_100k 2')

# %% [markdown]
# # BPM signal shows huge dip. Normalizing to BPM seems to over-compensate?

# %%
figure(); 
n1=pdnx(p % 711876); plot(n1.DCMenergy, n1['sum']);
n2=pdnx(p % 711877); plot(n2.DCMenergy, n2['sum']);
n_norm=pdnx(p % 711880); plot(n_norm.DCMenergy, n_norm['sum']);
figure()
plot(n_norm.DCMenergy, n1['sum']/n_norm['sum']);
background=380
plot(n_norm.DCMenergy, (n1['sum']-background)/n_norm['sum']);
plot(n_norm.DCMenergy, (n2['sum']-background)/n_norm['sum']);
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Thiourea

# %%
figure()

nn1=pdnx(p % 711884);
nn2=pdnx(p % 711885); fac=1.12

n_norm=pdnx(p % 711880); 

background=400
plot(n_norm.DCMenergy, (nn1['sum']-background)/n_norm['sum']);
plot(n_norm.DCMenergy, (nn2['sum']-background)/fac/n_norm['sum']);


nn1=pdnx(p % 711887);
nn2=pdnx(p % 711888); fac=1.12

n_norm=pdnx(p % 711880); 

background=400
plot(n_norm.DCMenergy, (nn1['sum']-background)/n_norm['sum']);
plot(n_norm.DCMenergy, (nn2['sum']-background)/fac/n_norm['sum']);
# Out:
# <img src="data:image/png;base64,..." width="640">
