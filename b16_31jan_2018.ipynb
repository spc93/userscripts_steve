# %%
datadir='/dls/b16/data/2018/mt17690-1/'

import sys
sys.path
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
from matplotlib.pyplot import *
# %matplotlib nbagg
from numpy import *
##%matplotlib inline
from dlstools import dataloader
from dlstools.dataloader import vec2mat

d=dataloader.dlsloader(datadir+'%i.dat')
p=dataloader.tiffloader(d, lambda obj: datadir+obj.pilatus2m_path_template)
# Out:
# === Importing dlstools package
# === Need to obtain specfilewrapper.py and compatible specfile.so from ERSF PyMCA package in order to load spec files
# /dls_sw/apps/scisoftpy/2.7/scisoftpy/_external/tifffile.py:284: UserWarning: ImportError: No module named '_tifffile'. Loading of some compressed images will be very slow. Tifffile.c can be obtained at http://www.lfd.uci.edu/~gohlke/
#   "ImportError: No module named '_tifffile'. "
# Could not import plotting routines
# No module named py4j.java_gateway

# %%
scans=range(265322+1,265361+1,2)
en=[]; mpsum=[]; fcy=[]
for scan in scans:
    d(scan)
    fcy+=list(d.fcY)
    mpsum+=list(d.sum)
    en+=list(d.fcY * 0 + d.energy)
mx, my, mz = vec2mat(en, fcy, mpsum);
#figure(); gca(projection='3d').plot(en, fcy, mpsum)
#figure();  pcolor(mx, my, mz)
#figure(figsize=(8, 6)); 
figure(); gca(projection='3d').plot_surface(mx, my, mz, cmap=cm.hot)    
#figure(figsize=(14, 12)); gca(projection='3d').plot_wireframe(mx, my, mz)

#print len(en), len(fcy), len(mpsum)

# %%
d(265322)
d.plot('mtYaw', 'sum')
# Out:
# Replacing duplicate key 'energy' with 'energy1'
# Replacing duplicate key 'ai1' with 'ai11'
# Replacing duplicate key 'ai2' with 'ai21'
# Replacing duplicate key 'chi' with 'chi1'
# Replacing duplicate key 'phi' with 'phi1'
# Replacing duplicate key 'fc_fcAlpha' with 'fc_fcAlpha1'
# Replacing duplicate key 'fc_fc2Theta' with 'fc_fc2Theta1'
# Replacing duplicate key 'fc_fcTheta' with 'fc_fcTheta1'
# Replacing duplicate key 'fc_fcChi' with 'fc_fcChi1'
# Replacing duplicate key 'fc_fcPhi' with 'fc_fcPhi1'
# Replacing duplicate key 'fc_fcX' with 'fc_fcX1'
# Replacing duplicate key 'fc_fcY' with 'fc_fcY1'
# Replacing duplicate key 'fc_fcZ' with 'fc_fcZ1'
# Replacing duplicate key 's1_s1ho' with 's1_s1ho1'
# Replacing duplicate key 's1_s1hg' with 's1_s1hg1'
# Replacing duplicate key 's1_s1vo' with 's1_s1vo1'
# Replacing duplicate key 's1_s1vg' with 's1_s1vg1'
# Replacing duplicate key 's4_s4ho' with 's4_s4ho1'
# Replacing duplicate key 's4_s4hg' with 's4_s4hg1'
# Replacing duplicate key 's4_s4vo' with 's4_s4vo1'
# Replacing duplicate key 's4_s4vg' with 's4_s4vg1'
# Replacing duplicate key 's7_s7ho' with 's7_s7ho1'
# Replacing duplicate key 's7_s7hg' with 's7_s7hg1'
# Replacing duplicate key 's7_s7vo' with 's7_s7vo1'
# Replacing duplicate key 's7_s7vg' with 's7_s7vg1'
# Replacing duplicate key 'tb3_tb3xcoarse' with 'tb3_tb3xcoarse1'
# Replacing duplicate key 'tb3_tb3zcoarse' with 'tb3_tb3zcoarse1'
# Replacing duplicate key 'tb3_tb3x' with 'tb3_tb3x1'
# Replacing duplicate key 'tb3_tb3y' with 'tb3_tb3y1'
# Replacing duplicate key 'mtYaw' with 'mtYaw1'
# Replacing duplicate key 'fcbaseHeight' with 'fcbaseHeight1'
# Replacing duplicate key 'fcbaseX' with 'fcbaseX1'
# Replacing duplicate key 'mtXcoarse' with 'mtXcoarse1'
# Replacing duplicate key 'test2mot6' with 'test2mot61'
# <img src="data:image/png;base64,..." width="639.8499802953507">

# %%
show()
