# %% [markdown]
# ## NCBO REST Python examples

# %% [markdown]
# To retrieve your API key, log into your account on the BioPortal website. If you don't have an account, you'll need to create one.
#
# Your API key will be listed in plain text on your account settings page.

# %%
API_KEY = "0280ec35-b8e0-4ac5-ab24-ded510c9ed0f"

# %% [markdown]
# ## annotate_test.py

# %%
#text_to_annotate = "Melanoma is a malignant tumor of melanocytes which are found predominantly in skin but also in the bowel and the eye."
text_to_annotate = "xray crystal rocking curve width"

# %%
import urllib.request, urllib.error, urllib.parse
import json
import os
from pprint import pprint

REST_URL = "http://data.bioontology.org"
#API_KEY = ""

def get_json(url):
    opener = urllib.request.build_opener()
    opener.addheaders = [('Authorization', 'apikey token=' + API_KEY)]
    return json.loads(opener.open(url).read())

def print_annotations(annotations, get_class=True):
    for result in annotations:
        class_details = result["annotatedClass"]
        if get_class:
            try:
                class_details = get_json(result["annotatedClass"]["links"]["self"])
            except urllib.error.HTTPError:
                print(f"Error retrieving {result['annotatedClass']['@id']}")
                continue
        print("Class details")
        print("\tid: " + class_details["@id"])
        print("\tprefLabel: " + class_details["prefLabel"])
        print("\tontology: " + class_details["links"]["ontology"])

        print("Annotation details")
        for annotation in result["annotations"]:
            print("\tfrom: " + str(annotation["from"]))
            print("\tto: " + str(annotation["to"]))
            print("\tmatch type: " + annotation["matchType"])

        if result["hierarchy"]:
            print("\n\tHierarchy annotations")
            for annotation in result["hierarchy"]:
                try:
                    class_details = get_json(annotation["annotatedClass"]["links"]["self"])
                except urllib.error.HTTPError:
                    print(f"Error retrieving {annotation['annotatedClass']['@id']}")
                    continue
                pref_label = class_details["prefLabel"] or "no label"
                print("\t\tClass details")
                print("\t\t\tid: " + class_details["@id"])
                print("\t\t\tprefLabel: " + class_details["prefLabel"])
                print("\t\t\tontology: " + class_details["links"]["ontology"])
                print("\t\t\tdistance from originally annotated class: " + str(annotation["distance"]))

        print("\n\n")

#text_to_annotate = "Melanoma is a malignant tumor of melanocytes which are found predominantly in skin but also in the bowel and the eye."

# Annotate using the provided text
annotations = get_json(REST_URL + "/annotator?text=" + urllib.parse.quote(text_to_annotate))

# Print out annotation details
print_annotations(annotations)

# Annotate with hierarchy information
annotations = get_json(REST_URL + "/annotator?max_level=3&text=" + urllib.parse.quote(text_to_annotate))
print_annotations(annotations)

# Annotate with prefLabel, synonym, definition returned
annotations = get_json(REST_URL + "/annotator?include=prefLabel,synonym,definition&text=" + urllib.parse.quote(text_to_annotate))
print_annotations(annotations, False)
# Out:
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#13220
# 	prefLabel: 13220
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 1
# 	to: 4
# 	match type: SYN
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C49899
# 	prefLabel: Crystal Device
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: SYN
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#33786
# 	prefLabel: 33786
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: SYN
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#35446
# 	prefLabel: crystal structure
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/FOODON_03430143
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/FOODON
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/X-21301
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://scai.fraunhofer.de/CSEO#CSEO_00000085
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/CSEO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PORO_0000094
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/PORO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.co-ode.org/ontologies/galen#Crystal
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/GALEN
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/769069006
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/ENVO_01000845
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/ENVO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/ENVO_01000845
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/ENM
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/ENVO_01000845
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/ECTO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42901
# 	prefLabel: Crystal Dosage Form
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: SYN
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61303
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/npo#NPO_895
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/NPO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/RCD/E2730
# 	prefLabel: Repetitive rocking movements
# 	ontology: http://data.bioontology.org/ontologies/RCD
# Annotation details
# 	from: 14
# 	to: 20
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/OMIM/MTHU056681
# 	prefLabel: Rocking
# 	ontology: http://data.bioontology.org/ontologies/OMIM
# Annotation details
# 	from: 14
# 	to: 20
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/F-93467
# 	prefLabel: Rocking
# 	ontology: http://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 14
# 	to: 20
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/Curve
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/Curve
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.opengis.net/ont/gml#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/GEOSPARQL
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C70828
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.opengis.net/ont/sf#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/GEOSPARQL
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://loki.cae.drexel.edu/~wbs/ontology/2004/09/ogc-gml#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/GML
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SIO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/BIOMO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/GENEPIO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/ORTH
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.jp/bio/4/id/200906052998480295
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/IOBC
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ecoinformatics.org/oboe/oboe.1.0/oboe-spatial.owl#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/OBOE-SBC
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sweetontology.net/reprSpaceGeometry/Curve
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SWEET
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/AGRO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/NIFDYS
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/VDOT
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/OBA
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/PLANP
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/FOODON
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/ENVO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/PATO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/NIFSTD
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/XPO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/MS
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/CMPO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/FLOPO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/ZP
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/ONTONEO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/UPHENO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/ENM
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/BAO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/103355008
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/HAO_0002375
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/HAO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/LNC/MTHU004958
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/LOINC
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://uri.neuinfo.org/nif/nifstd/sao888175480
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/NIFSTD
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://radlex.org/RID/RID39144
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/RADLEX
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/SIO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/BIOMO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/ORTH
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.dataone.org/odo/ECSO_00001254
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/ECSO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/Width
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/Width
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/HAO_0002308
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/HAO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/G-A220
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#C0487742
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/LNC/LP18016-3
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/LOINC
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/ID_0000057
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/BCTEO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C25345
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.jp/bio/10/mpo#MPO_00127
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/MPO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#37259
# 	prefLabel: 37259
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.org/obo/owl/PATO#PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/BIOMODELS
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.org/obo/owl/PATO#PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/HUPSON
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.org/obo/owl/PATO#PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/NPO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ifomis.org/acgt/1.0#Width
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/ACGT-MO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ccdb.ucsd.edu/SAO/1.2#sao888175480
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/SAO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#13220
# 	prefLabel: 13220
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 1
# 	to: 4
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://sbmi.uth.tmc.edu/ontology/ochv#CHV_Concept
# 			prefLabel: CHV_Concept
# 			ontology: http://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2004/02/skos/core#Concept
# 			prefLabel: Concept
# 			ontology: http://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 2
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C49899
# 	prefLabel: Crystal Device
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C49755
# 			prefLabel: Device Component or Accessory
# 			ontology: http://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C19238
# 			prefLabel: Diagnostic, Therapeutic, or Research Equipment
# 			ontology: http://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C97325
# 			prefLabel: Manufactured Object
# 			ontology: http://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#33786
# 	prefLabel: 33786
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://sbmi.uth.tmc.edu/ontology/ochv#CHV_Concept
# 			prefLabel: CHV_Concept
# 			ontology: http://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2004/02/skos/core#Concept
# 			prefLabel: Concept
# 			ontology: http://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 2
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#35446
# 	prefLabel: crystal structure
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://sbmi.uth.tmc.edu/ontology/ochv#CHV_Concept
# 			prefLabel: CHV_Concept
# 			ontology: http://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.w3.org/2004/02/skos/core#Concept
# 			prefLabel: Concept
# 			ontology: http://data.bioontology.org/ontologies/OCHV
# 			distance from originally annotated class: 2
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/FOODON_03430143
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/FOODON
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/FOODON_03430151
# 			prefLabel: food (solid)
# 			ontology: http://data.bioontology.org/ontologies/FOODON
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/FOODON_00002454
# 			prefLabel: food product by quality
# 			ontology: http://data.bioontology.org/ontologies/FOODON
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/FOODON_00001002
# 			prefLabel: foodon product type
# 			ontology: http://data.bioontology.org/ontologies/FOODON
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/X-21301
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/X-00000
# 			prefLabel: LIST OF PHARMACEUTICAL COMPANIES
# 			ontology: http://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 1
#
#
#
# Class details
# 	id: http://scai.fraunhofer.de/CSEO#CSEO_00000085
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/CSEO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://scai.fraunhofer.de/CSEO#CSEO_00000017
# 			prefLabel: Non Neoplastic Morphologies
# 			ontology: http://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://scai.fraunhofer.de/CSEO#Morphology
# 			prefLabel: Morphology
# 			ontology: http://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://scai.fraunhofer.de/CSEO#CSEO_03000020
# 			prefLabel: Finding
# 			ontology: http://data.bioontology.org/ontologies/CSEO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PORO_0000094
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/PORO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/UBERON_0000476
# 			prefLabel: acellular anatomical structure
# 			ontology: http://data.bioontology.org/ontologies/PORO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/UBERON_0000061
# 			prefLabel: anatomical structure
# 			ontology: http://data.bioontology.org/ontologies/PORO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/UBERON_0000465
# 			prefLabel: material anatomical entity
# 			ontology: http://data.bioontology.org/ontologies/PORO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://www.co-ode.org/ontologies/galen#Crystal
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/GALEN
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#NAMEDnonBodyStructure
# 			prefLabel: NAMEDnonBodyStructure
# 			ontology: http://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#InertSolidStructure
# 			prefLabel: InertSolidStructure
# 			ontology: http://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://www.co-ode.org/ontologies/galen#SolidStructure
# 			prefLabel: SolidStructure
# 			ontology: http://data.bioontology.org/ontologies/GALEN
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/769069006
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNOMEDCT/78910004
# 			prefLabel: Solid substance
# 			ontology: http://data.bioontology.org/ontologies/SNOMEDCT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNOMEDCT/115669006
# 			prefLabel: Substance categorized by physical state
# 			ontology: http://data.bioontology.org/ontologies/SNOMEDCT
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNOMEDCT/105590001
# 			prefLabel: Substance
# 			ontology: http://data.bioontology.org/ontologies/SNOMEDCT
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/ENVO_01000845
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/ENVO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/ENVO_01000814
# 			prefLabel: solid environmental material
# 			ontology: http://data.bioontology.org/ontologies/ENVO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/ENVO_01001125
# 			prefLabel: ice
# 			ontology: http://data.bioontology.org/ontologies/ENVO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/ENVO_00010483
# 			prefLabel: environmental material
# 			ontology: http://data.bioontology.org/ontologies/ENVO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000040
# 			prefLabel: material entity
# 			ontology: http://data.bioontology.org/ontologies/ENVO
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000024
# 			prefLabel: fiat object part
# 			ontology: http://data.bioontology.org/ontologies/ENVO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/ENVO_01000845
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/ENM
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/ENVO_01000814
# 			prefLabel: solid environmental material
# 			ontology: http://data.bioontology.org/ontologies/ENM
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/ENVO_01001125
# 			prefLabel: ice
# 			ontology: http://data.bioontology.org/ontologies/ENM
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/ENVO_00010483
# 			prefLabel: environmental material
# 			ontology: http://data.bioontology.org/ontologies/ENM
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/ENVO_01000845
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/ECTO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/ENVO_01000814
# 			prefLabel: solid environmental material
# 			ontology: http://data.bioontology.org/ontologies/ECTO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/ENVO_01001125
# 			prefLabel: ice
# 			ontology: http://data.bioontology.org/ontologies/ECTO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/ENVO_00010483
# 			prefLabel: environmental material
# 			ontology: http://data.bioontology.org/ontologies/ECTO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000024
# 			prefLabel: fiat object part
# 			ontology: http://data.bioontology.org/ontologies/ECTO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42901
# 	prefLabel: Crystal Dosage Form
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C45235
# 			prefLabel: Solid Dosage Form
# 			ontology: http://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C87836
# 			prefLabel: Dosage Form by Physical Form
# 			ontology: http://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42636
# 			prefLabel: Pharmaceutical Dosage Form
# 			ontology: http://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61303
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C45300
# 			prefLabel: Solid
# 			ontology: http://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C45306
# 			prefLabel: Substance
# 			ontology: http://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C48187
# 			prefLabel: Material
# 			ontology: http://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/npo#NPO_895
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/NPO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/npo#NPO_834
# 			prefLabel: solid
# 			ontology: http://data.bioontology.org/ontologies/NPO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/npo#NPO_1500
# 			prefLabel: chemical substance by physical state
# 			ontology: http://data.bioontology.org/ontologies/NPO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/npo#NPO_1973
# 			prefLabel: chemical substance
# 			ontology: http://data.bioontology.org/ontologies/NPO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/RCD/E2730
# 	prefLabel: Repetitive rocking movements
# 	ontology: http://data.bioontology.org/ontologies/RCD
# Annotation details
# 	from: 14
# 	to: 20
# 	match type: SYN
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/RCD/E273.
# 			prefLabel: Repetitive routines
# 			ontology: http://data.bioontology.org/ontologies/RCD
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/RCD/X7638
# 			prefLabel: Motor function behaviour
# 			ontology: http://data.bioontology.org/ontologies/RCD
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/RCD/X75Wn
# 			prefLabel: Behaviours and observations relating to behaviour
# 			ontology: http://data.bioontology.org/ontologies/RCD
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/OMIM/MTHU056681
# 	prefLabel: Rocking
# 	ontology: http://data.bioontology.org/ontologies/OMIM
# Annotation details
# 	from: 14
# 	to: 20
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/OMIM/MTHU000243
# 			prefLabel: Behavioral/psychiatric manifestations
# 			ontology: http://data.bioontology.org/ontologies/OMIM
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/OMIM/MTHU000057
# 			prefLabel: NEUROLOGIC
# 			ontology: http://data.bioontology.org/ontologies/OMIM
# 			distance from originally annotated class: 2
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/F-93467
# 	prefLabel: Rocking
# 	ontology: http://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 14
# 	to: 20
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/F-93300
# 			prefLabel: Motor behavior, NOS
# 			ontology: http://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/F-93000
# 			prefLabel: Behavior, NOS
# 			ontology: http://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.bioontology.org/ontology/SNMI/F-90000
# 			prefLabel: Mental state, NOS
# 			ontology: http://data.bioontology.org/ontologies/SNMI
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/Curve
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/GeometricEntity
# 			prefLabel: geometric entity
# 			ontology: http://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/InformationContentEntity
# 			prefLabel: information content entity
# 			ontology: http://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://semanticscience.org/resource/Object
# 			prefLabel: object
# 			ontology: http://data.bioontology.org/ontologies/CHEAR
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/Curve
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/GeometricEntity
# 			prefLabel: geometric entity
# 			ontology: http://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/InformationContentEntity
# 			prefLabel: information content entity
# 			ontology: http://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://semanticscience.org/resource/Object
# 			prefLabel: object
# 			ontology: http://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://www.opengis.net/ont/gml#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/GEOSPARQL
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.opengis.net/ont/gml#AbstractGeometricPrimitive
# 			prefLabel: Abstract Geometric Primitive
# 			ontology: http://data.bioontology.org/ontologies/GEOSPARQL
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.opengis.net/ont/gml#OrientableCurve
# 			prefLabel: Orientable Curve
# 			ontology: http://data.bioontology.org/ontologies/GEOSPARQL
# 			distance from originally annotated class: 1
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C70828
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C20181
# 			prefLabel: Conceptual Entity
# 			ontology: http://data.bioontology.org/ontologies/NCIT
# 			distance from originally annotated class: 1
#
#
#
# Class details
# 	id: http://www.opengis.net/ont/sf#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/GEOSPARQL
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://www.opengis.net/ont/sf#Geometry
# 			prefLabel: Geometry
# 			ontology: http://data.bioontology.org/ontologies/GEOSPARQL
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://www.opengis.net/ont/geosparql#Geometry
# 			prefLabel: Geometry
# 			ontology: http://data.bioontology.org/ontologies/GEOSPARQL
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://www.opengis.net/ont/geosparql#SpatialObject
# 			prefLabel: SpatialObject
# 			ontology: http://data.bioontology.org/ontologies/GEOSPARQL
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://loki.cae.drexel.edu/~wbs/ontology/2004/09/ogc-gml#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/GML
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://loki.cae.drexel.edu/~wbs/ontology/2004/09/ogc-gml#_Curve
# 			prefLabel: _Curve
# 			ontology: http://data.bioontology.org/ontologies/GML
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://loki.cae.drexel.edu/~wbs/ontology/2004/09/ogc-gml#_GeometricPrimitive
# 			prefLabel: _GeometricPrimitive
# 			ontology: http://data.bioontology.org/ontologies/GML
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://loki.cae.drexel.edu/~wbs/ontology/2004/09/ogc-gml#_Geometry
# 			prefLabel: _Geometry
# 			ontology: http://data.bioontology.org/ontologies/GML
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SIO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000506
# 			prefLabel: geometric entity
# 			ontology: http://data.bioontology.org/ontologies/SIO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000015
# 			prefLabel: information content entity
# 			ontology: http://data.bioontology.org/ontologies/SIO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000776
# 			prefLabel: object
# 			ontology: http://data.bioontology.org/ontologies/SIO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/BIOMO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000506
# 			prefLabel: geometric entity
# 			ontology: http://data.bioontology.org/ontologies/BIOMO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000015
# 			prefLabel: information content entity
# 			ontology: http://data.bioontology.org/ontologies/BIOMO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000776
# 			prefLabel: object
# 			ontology: http://data.bioontology.org/ontologies/BIOMO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000506
# 			prefLabel: geometric entity
# 			ontology: http://data.bioontology.org/ontologies/HASCO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000015
# 			prefLabel: information content entity
# 			ontology: http://data.bioontology.org/ontologies/HASCO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000776
# 			prefLabel: object
# 			ontology: http://data.bioontology.org/ontologies/HASCO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000506
# 			prefLabel: geometric entity
# 			ontology: http://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000015
# 			prefLabel: information content entity
# 			ontology: http://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000776
# 			prefLabel: object
# 			ontology: http://data.bioontology.org/ontologies/HHEAR
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/GENEPIO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/GENEPIO_0001884
# 			prefLabel: n-dimensional entity
# 			ontology: http://data.bioontology.org/ontologies/GENEPIO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/GENEPIO_0001859
# 			prefLabel: n-dimensional concept
# 			ontology: http://data.bioontology.org/ontologies/GENEPIO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/BFO_0000141
# 			prefLabel: immaterial entity
# 			ontology: http://data.bioontology.org/ontologies/GENEPIO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/ORTH
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000506
# 			prefLabel: geometric entity
# 			ontology: http://data.bioontology.org/ontologies/ORTH
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000015
# 			prefLabel: information content entity
# 			ontology: http://data.bioontology.org/ontologies/ORTH
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000776
# 			prefLabel: object
# 			ontology: http://data.bioontology.org/ontologies/ORTH
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000506
# 			prefLabel: geometric entity
# 			ontology: http://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000015
# 			prefLabel: information content entity
# 			ontology: http://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://semanticscience.org/resource/SIO_000776
# 			prefLabel: object
# 			ontology: http://data.bioontology.org/ontologies/SCO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.jp/bio/4/id/200906052998480295
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/IOBC
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.jp/bio/4/subject/IA04
# 			prefLabel: Geometrical volume, shapes, and locations
# 			ontology: http://data.bioontology.org/ontologies/IOBC
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.jp/bio/4/id/200906067060073884
# 			prefLabel: property (Life science)
# 			ontology: http://data.bioontology.org/ontologies/IOBC
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.jp/bio/4/subject/LS_ur_c/OWLClass_00000000000000000665
# 			prefLabel: Terms related to life science
# 			ontology: http://data.bioontology.org/ontologies/IOBC
# 			distance from originally annotated class: 3
# 		Class details
# 			id: http://purl.jp/bio/4/subject/IA08
# 			prefLabel: Properties
# 			ontology: http://data.bioontology.org/ontologies/IOBC
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://ecoinformatics.org/oboe/oboe.1.0/oboe-spatial.owl#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/OBOE-SBC
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://ecoinformatics.org/oboe/oboe.1.0/oboe-spatial.owl#SpatialCurve
# 			prefLabel: Spatial Curve
# 			ontology: http://data.bioontology.org/ontologies/OBOE-SBC
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://ecoinformatics.org/oboe/oboe.1.0/oboe-spatial.owl#SpatialGeometricPrimitive
# 			prefLabel: Spatial Geometric Primitive
# 			ontology: http://data.bioontology.org/ontologies/OBOE-SBC
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://ecoinformatics.org/oboe/oboe.1.0/oboe-spatial.owl#SpatialGeometry
# 			prefLabel: Spatial Geometry
# 			ontology: http://data.bioontology.org/ontologies/OBOE-SBC
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://sweetontology.net/reprSpaceGeometry/Curve
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SWEET
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://sweetontology.net/reprSpaceGeometry/GeometricalObject_1D
# 			prefLabel: geometrical object 1d
# 			ontology: http://data.bioontology.org/ontologies/SWEET
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://sweetontology.net/repr/D
# 			prefLabel: D
# 			ontology: http://data.bioontology.org/ontologies/SWEET
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://sweetontology.net/reprSpaceGeometry/GeometricalObject
# 			prefLabel: geometrical object
# 			ontology: http://data.bioontology.org/ontologies/SWEET
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://sweetontology.net/reprMath/NumericalEntity
# 			prefLabel: numerical entity
# 			ontology: http://data.bioontology.org/ontologies/SWEET
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/AGRO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001708
# 			prefLabel: 1-D extent
# 			ontology: http://data.bioontology.org/ontologies/AGRO
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000117
# 			prefLabel: size
# 			ontology: http://data.bioontology.org/ontologies/AGRO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: http://data.bioontology.org/ontologies/AGRO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/NIFDYS
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001708
# 			prefLabel: 1-D extent
# 			ontology: http://data.bioontology.org/ontologies/NIFDYS
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000117
# 			prefLabel: size
# 			ontology: http://data.bioontology.org/ontologies/NIFDYS
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000051
# 			prefLabel: morphology
# 			ontology: http://data.bioontology.org/ontologies/NIFDYS
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/VDOT
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001708
# 			prefLabel: 1-D size
# 			ontology: http://data.bioontology.org/ontologies/VDOT
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000117
# 			prefLabel: size
# 			ontology: http://data.bioontology.org/ontologies/VDOT
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0002016
# 			prefLabel: magnitude
# 			ontology: http://data.bioontology.org/ontologies/VDOT
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/OBA
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
# 	Hierarchy annotations
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0001708
# 			prefLabel: 1-D extent
# 			ontology: http://data.bioontology.org/ontologies/OBA
# 			distance from originally annotated class: 1
# 		Class details
# 			id: http://purl.obolibrary.org/obo/PATO_0000117
# 			prefLabel: size
# 			ontology: http://data.bioontology.org/ontologies/OBA
# 			distance from originally annotated class: 2
# 		Class details
# ...
# 			id: http://www.ifomis.org/bfo/1.0/snap#Quality
# 			prefLabel: quality
# 			ontology: http://data.bioontology.org/ontologies/SAO
# 			distance from originally annotated class: 2
# 		Class details
# 			id: http://www.ifomis.org/bfo/1.0/snap#DependentContinuant
# 			prefLabel: dependent_continuant
# 			ontology: http://data.bioontology.org/ontologies/SAO
# 			distance from originally annotated class: 3
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#13220
# 	prefLabel: 13220
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 1
# 	to: 4
# 	match type: SYN
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C49899
# 	prefLabel: Crystal Device
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: SYN
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#33786
# 	prefLabel: 33786
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/FOODON_03430143
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/FOODON
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/X-21301
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://scai.fraunhofer.de/CSEO#CSEO_00000085
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/CSEO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PORO_0000094
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/PORO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.co-ode.org/ontologies/galen#Crystal
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/GALEN
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/769069006
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/ENVO_01000845
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/ENVO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/ENVO_01000845
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/ENM
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/ENVO_01000845
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/ECTO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C42901
# 	prefLabel: Crystal Dosage Form
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: SYN
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C61303
# 	prefLabel: Crystal
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/npo#NPO_895
# 	prefLabel: crystal
# 	ontology: http://data.bioontology.org/ontologies/NPO
# Annotation details
# 	from: 6
# 	to: 12
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/RCD/E2730
# 	prefLabel: Repetitive rocking movements
# 	ontology: http://data.bioontology.org/ontologies/RCD
# Annotation details
# 	from: 14
# 	to: 20
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/OMIM/MTHU056681
# 	prefLabel: Rocking
# 	ontology: http://data.bioontology.org/ontologies/OMIM
# Annotation details
# 	from: 14
# 	to: 20
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/F-93467
# 	prefLabel: Rocking
# 	ontology: http://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 14
# 	to: 20
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/Curve
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/Curve
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.opengis.net/ont/gml#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/GEOSPARQL
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C70828
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.opengis.net/ont/sf#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/GEOSPARQL
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://loki.cae.drexel.edu/~wbs/ontology/2004/09/ogc-gml#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/GML
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SIO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/BIOMO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/GENEPIO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/ORTH
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000608
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.jp/bio/4/id/200906052998480295
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/IOBC
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ecoinformatics.org/oboe/oboe.1.0/oboe-spatial.owl#Curve
# 	prefLabel: Curve
# 	ontology: http://data.bioontology.org/ontologies/OBOE-SBC
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sweetontology.net/reprSpaceGeometry/Curve
# 	prefLabel: curve
# 	ontology: http://data.bioontology.org/ontologies/SWEET
# Annotation details
# 	from: 22
# 	to: 26
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/AGRO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/NIFDYS
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/VDOT
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/OBA
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/PLANP
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/FOODON
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/ENVO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/PATO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/NIFSTD
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/XPO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/MS
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/CMPO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/FLOPO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/ZP
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/ONTONEO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/UPHENO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/ENM
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/BAO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNOMEDCT/103355008
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/SNOMEDCT
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/HAO_0002375
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/HAO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/LNC/MTHU004958
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/LOINC
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://uri.neuinfo.org/nif/nifstd/sao888175480
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/NIFSTD
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://radlex.org/RID/RID39144
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/RADLEX
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/SIO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/BIOMO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/HASCO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/HHEAR
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/ORTH
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/SIO_000042
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.dataone.org/odo/ECSO_00001254
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/ECSO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/Width
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/CHEAR
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://semanticscience.org/resource/Width
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/SCO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/HAO_0002308
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/HAO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/SNMI/G-A220
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/SNMI
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#C0487742
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.bioontology.org/ontology/LNC/LP18016-3
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/LOINC
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.obolibrary.org/obo/ID_0000057
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/BCTEO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C25345
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/NCIT
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.jp/bio/10/mpo#MPO_00127
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/MPO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://sbmi.uth.tmc.edu/ontology/ochv#37259
# 	prefLabel: 37259
# 	ontology: http://data.bioontology.org/ontologies/OCHV
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: SYN
#
#
#
# Class details
# 	id: http://purl.org/obo/owl/PATO#PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/BIOMODELS
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.org/obo/owl/PATO#PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/HUPSON
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://purl.org/obo/owl/PATO#PATO_0000921
# 	prefLabel: width
# 	ontology: http://data.bioontology.org/ontologies/NPO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://www.ifomis.org/acgt/1.0#Width
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/ACGT-MO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF
#
#
#
# Class details
# 	id: http://ccdb.ucsd.edu/SAO/1.2#sao888175480
# 	prefLabel: Width
# 	ontology: http://data.bioontology.org/ontologies/SAO
# Annotation details
# 	from: 28
# 	to: 32
# 	match type: PREF

# %% [markdown]
# ## classes_search.py

# %%
myterms = ['energy', 'temperature', 'experimenter']

# %%
import urllib.request, urllib.error, urllib.parse
import json
import os
from pprint import pprint

REST_URL = "http://data.bioontology.org"
#API_KEY = ""

def get_json(url):
    opener = urllib.request.build_opener()
    opener.addheaders = [('Authorization', 'apikey token=' + API_KEY)]
    return json.loads(opener.open(url).read())

#fails - no __file__  # comment out this block
# Get list of search terms
#path = os.path.join(os.path.dirname(__file__), 'classes_search_terms.txt')
#terms_file = open(path, "r")
#terms = []
#for line in terms_file:
#    terms.append(line)

#spc mod
terms = myterms
    
# Do a search for every term
search_results = []
for term in terms:
    search_results.append(get_json(REST_URL + "/search?q=" + term)["collection"])

# Print the results
for result in search_results:
    pprint(result)
# Out:
# [{'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'cui': 'http://data.bioontology.org/metadata/umlscui',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel',
#                'semanticType': 'http://data.bioontology.org/metadata/umlssemanticType',
#                'synonym': 'http://data.bioontology.org/metadata/skossynonym'},
#   '@id': 'http://purl.bioontology.org/ontology/RCD/X76Ah',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'cui': ['C0424589'],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX76Ah/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX76Ah/children',
#             'descendants': 'http://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX76Ah/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX76Ah/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX76Ah/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX76Ah/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/RCD',
#             'parents': 'http://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX76Ah/parents',
#             'self': 'http://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX76Ah',
#             'tree': 'http://data.bioontology.org/ontologies/RCD/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX76Ah/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/RCD?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2FRCD%2FX76Ah'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'Energy',
#   'provisional': False,
#   'semanticType': ['T033'],
#   'synonym': ['Vitality']},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'definition': 'http://data.bioontology.org/metadata/skosdefinition',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel',
#                'synonym': 'http://data.bioontology.org/metadata/skossynonym'},
#   '@id': 'http://ncicb.nci.nih.gov/xml/owl/EVS/Thesaurus.owl#C48058',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'definition': ['The capacity of a physical system to do work.'],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C48058/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C48058/children',
#             'descendants': 'http://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C48058/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C48058/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C48058/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C48058/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/NCIT',
#             'parents': 'http://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C48058/parents',
#             'self': 'http://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C48058',
#             'tree': 'http://data.bioontology.org/ontologies/NCIT/classes/http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C48058/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/NCIT?p=classes&conceptid=http%3A%2F%2Fncicb.nci.nih.gov%2Fxml%2Fowl%2FEVS%2FThesaurus.owl%23C48058'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'Energy',
#   'provisional': False,
#   'synonym': ['Energy']},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'definition': 'http://data.bioontology.org/metadata/skosdefinition',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://purl.obolibrary.org/obo/ENVO_2000015',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'definition': ['Consider replacing with PATO class; note that PATO class is '
#                  'not a disposition'],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/ENVO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FENVO_2000015/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/ENVO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FENVO_2000015/children',
#             'descendants': 'http://data.bioontology.org/ontologies/ENVO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FENVO_2000015/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/ENVO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FENVO_2000015/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/ENVO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FENVO_2000015/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/ENVO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FENVO_2000015/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/ENVO',
#             'parents': 'http://data.bioontology.org/ontologies/ENVO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FENVO_2000015/parents',
#             'self': 'http://data.bioontology.org/ontologies/ENVO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FENVO_2000015',
#             'tree': 'http://data.bioontology.org/ontologies/ENVO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FENVO_2000015/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/ENVO?p=classes&conceptid=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FENVO_2000015'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel',
#                'synonym': 'http://data.bioontology.org/metadata/skossynonym'},
#   '@id': 'http://purl.jp/bio/4/id/200906096927590763',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/IOBC/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F4%2Fid%2F200906096927590763/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/IOBC/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F4%2Fid%2F200906096927590763/children',
#             'descendants': 'http://data.bioontology.org/ontologies/IOBC/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F4%2Fid%2F200906096927590763/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/IOBC/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F4%2Fid%2F200906096927590763/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/IOBC/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F4%2Fid%2F200906096927590763/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/IOBC/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F4%2Fid%2F200906096927590763/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/IOBC',
#             'parents': 'http://data.bioontology.org/ontologies/IOBC/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F4%2Fid%2F200906096927590763/parents',
#             'self': 'http://data.bioontology.org/ontologies/IOBC/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F4%2Fid%2F200906096927590763',
#             'tree': 'http://data.bioontology.org/ontologies/IOBC/classes/http%3A%2F%2Fpurl.jp%2Fbio%2F4%2Fid%2F200906096927590763/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/IOBC?p=classes&conceptid=http%3A%2F%2Fpurl.jp%2Fbio%2F4%2Fid%2F200906096927590763'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'energy',
#   'provisional': False,
#   'synonym': ['エナジー', 'エネルギー', 'energy']},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://sweetontology.net/propEnergy/Energy',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/SWEET/classes/http%3A%2F%2Fsweetontology.net%2FpropEnergy%2FEnergy/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/SWEET/classes/http%3A%2F%2Fsweetontology.net%2FpropEnergy%2FEnergy/children',
#             'descendants': 'http://data.bioontology.org/ontologies/SWEET/classes/http%3A%2F%2Fsweetontology.net%2FpropEnergy%2FEnergy/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/SWEET/classes/http%3A%2F%2Fsweetontology.net%2FpropEnergy%2FEnergy/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/SWEET/classes/http%3A%2F%2Fsweetontology.net%2FpropEnergy%2FEnergy/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/SWEET/classes/http%3A%2F%2Fsweetontology.net%2FpropEnergy%2FEnergy/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/SWEET',
#             'parents': 'http://data.bioontology.org/ontologies/SWEET/classes/http%3A%2F%2Fsweetontology.net%2FpropEnergy%2FEnergy/parents',
#             'self': 'http://data.bioontology.org/ontologies/SWEET/classes/http%3A%2F%2Fsweetontology.net%2FpropEnergy%2FEnergy',
#             'tree': 'http://data.bioontology.org/ontologies/SWEET/classes/http%3A%2F%2Fsweetontology.net%2FpropEnergy%2FEnergy/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/SWEET?p=classes&conceptid=http%3A%2F%2Fsweetontology.net%2FpropEnergy%2FEnergy'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://sbmi.uth.tmc.edu/ontology/ochv#C0424589',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%23C0424589/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%23C0424589/children',
#             'descendants': 'http://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%23C0424589/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%23C0424589/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%23C0424589/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%23C0424589/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/OCHV',
#             'parents': 'http://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%23C0424589/parents',
#             'self': 'http://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%23C0424589',
#             'tree': 'http://data.bioontology.org/ontologies/OCHV/classes/http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%23C0424589/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/OCHV?p=classes&conceptid=http%3A%2F%2Fsbmi.uth.tmc.edu%2Fontology%2Fochv%23C0424589'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'definition': 'http://data.bioontology.org/metadata/skosdefinition',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://purl.obolibrary.org/obo/PATO_0001021',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'definition': ['A physical quality inhering in a bearer by virtue of the '
#                  "bearer's capacity to do work."],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/PATO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/PATO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/children',
#             'descendants': 'http://data.bioontology.org/ontologies/PATO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/PATO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/PATO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/PATO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/PATO',
#             'parents': 'http://data.bioontology.org/ontologies/PATO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/parents',
#             'self': 'http://data.bioontology.org/ontologies/PATO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021',
#             'tree': 'http://data.bioontology.org/ontologies/PATO/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/PATO?p=classes&conceptid=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'definition': 'http://data.bioontology.org/metadata/skosdefinition',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://purl.obolibrary.org/obo/PATO_0001021',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'definition': ['A physical quality inhering in a bearer by virtue of the '
#                  "bearer's capacity to do work."],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/NIFSTD/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/NIFSTD/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/children',
#             'descendants': 'http://data.bioontology.org/ontologies/NIFSTD/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/NIFSTD/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/NIFSTD/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/NIFSTD/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/NIFSTD',
#             'parents': 'http://data.bioontology.org/ontologies/NIFSTD/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/parents',
#             'self': 'http://data.bioontology.org/ontologies/NIFSTD/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021',
#             'tree': 'http://data.bioontology.org/ontologies/NIFSTD/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/NIFSTD?p=classes&conceptid=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://purl.org/obo/owl/PATO#PATO_0001021',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/BIOMODELS/classes/http%3A%2F%2Fpurl.org%2Fobo%2Fowl%2FPATO%23PATO_0001021/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/BIOMODELS/classes/http%3A%2F%2Fpurl.org%2Fobo%2Fowl%2FPATO%23PATO_0001021/children',
#             'descendants': 'http://data.bioontology.org/ontologies/BIOMODELS/classes/http%3A%2F%2Fpurl.org%2Fobo%2Fowl%2FPATO%23PATO_0001021/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/BIOMODELS/classes/http%3A%2F%2Fpurl.org%2Fobo%2Fowl%2FPATO%23PATO_0001021/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/BIOMODELS/classes/http%3A%2F%2Fpurl.org%2Fobo%2Fowl%2FPATO%23PATO_0001021/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/BIOMODELS/classes/http%3A%2F%2Fpurl.org%2Fobo%2Fowl%2FPATO%23PATO_0001021/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/BIOMODELS',
#             'parents': 'http://data.bioontology.org/ontologies/BIOMODELS/classes/http%3A%2F%2Fpurl.org%2Fobo%2Fowl%2FPATO%23PATO_0001021/parents',
#             'self': 'http://data.bioontology.org/ontologies/BIOMODELS/classes/http%3A%2F%2Fpurl.org%2Fobo%2Fowl%2FPATO%23PATO_0001021',
#             'tree': 'http://data.bioontology.org/ontologies/BIOMODELS/classes/http%3A%2F%2Fpurl.org%2Fobo%2Fowl%2FPATO%23PATO_0001021/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/BIOMODELS?p=classes&conceptid=http%3A%2F%2Fpurl.org%2Fobo%2Fowl%2FPATO%23PATO_0001021'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'definition': 'http://data.bioontology.org/metadata/skosdefinition',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://bhi.washington.edu/OPB#OPB_01494',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'definition': ['Primitive physical entity that is capacity to do physical '
#                  'work.'],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/OPB/classes/http%3A%2F%2Fbhi.washington.edu%2FOPB%23OPB_01494/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/OPB/classes/http%3A%2F%2Fbhi.washington.edu%2FOPB%23OPB_01494/children',
#             'descendants': 'http://data.bioontology.org/ontologies/OPB/classes/http%3A%2F%2Fbhi.washington.edu%2FOPB%23OPB_01494/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/OPB/classes/http%3A%2F%2Fbhi.washington.edu%2FOPB%23OPB_01494/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/OPB/classes/http%3A%2F%2Fbhi.washington.edu%2FOPB%23OPB_01494/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/OPB/classes/http%3A%2F%2Fbhi.washington.edu%2FOPB%23OPB_01494/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/OPB',
#             'parents': 'http://data.bioontology.org/ontologies/OPB/classes/http%3A%2F%2Fbhi.washington.edu%2FOPB%23OPB_01494/parents',
#             'self': 'http://data.bioontology.org/ontologies/OPB/classes/http%3A%2F%2Fbhi.washington.edu%2FOPB%23OPB_01494',
#             'tree': 'http://data.bioontology.org/ontologies/OPB/classes/http%3A%2F%2Fbhi.washington.edu%2FOPB%23OPB_01494/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/OPB?p=classes&conceptid=http%3A%2F%2Fbhi.washington.edu%2FOPB%23OPB_01494'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'Energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'definition': 'http://data.bioontology.org/metadata/skosdefinition',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://purl.obolibrary.org/obo/PATO_0001021',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'definition': ['A physical quality inhering in a bearer by virtue of the '
#                  "bearer's capacity to do work."],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/MS/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/MS/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/children',
#             'descendants': 'http://data.bioontology.org/ontologies/MS/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/MS/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/MS/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/MS/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/MS',
#             'parents': 'http://data.bioontology.org/ontologies/MS/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/parents',
#             'self': 'http://data.bioontology.org/ontologies/MS/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021',
#             'tree': 'http://data.bioontology.org/ontologies/MS/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/MS?p=classes&conceptid=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://purl.obolibrary.org/obo/PATO_0001021',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/CHEAR/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/CHEAR/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/children',
#             'descendants': 'http://data.bioontology.org/ontologies/CHEAR/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/CHEAR/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/CHEAR/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/CHEAR/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/CHEAR',
#             'parents': 'http://data.bioontology.org/ontologies/CHEAR/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/parents',
#             'self': 'http://data.bioontology.org/ontologies/CHEAR/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021',
#             'tree': 'http://data.bioontology.org/ontologies/CHEAR/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/CHEAR?p=classes&conceptid=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://www.co-ode.org/ontologies/galen#Energy',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/GALEN/classes/http%3A%2F%2Fwww.co-ode.org%2Fontologies%2Fgalen%23Energy/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/GALEN/classes/http%3A%2F%2Fwww.co-ode.org%2Fontologies%2Fgalen%23Energy/children',
#             'descendants': 'http://data.bioontology.org/ontologies/GALEN/classes/http%3A%2F%2Fwww.co-ode.org%2Fontologies%2Fgalen%23Energy/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/GALEN/classes/http%3A%2F%2Fwww.co-ode.org%2Fontologies%2Fgalen%23Energy/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/GALEN/classes/http%3A%2F%2Fwww.co-ode.org%2Fontologies%2Fgalen%23Energy/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/GALEN/classes/http%3A%2F%2Fwww.co-ode.org%2Fontologies%2Fgalen%23Energy/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/GALEN',
#             'parents': 'http://data.bioontology.org/ontologies/GALEN/classes/http%3A%2F%2Fwww.co-ode.org%2Fontologies%2Fgalen%23Energy/parents',
#             'self': 'http://data.bioontology.org/ontologies/GALEN/classes/http%3A%2F%2Fwww.co-ode.org%2Fontologies%2Fgalen%23Energy',
#             'tree': 'http://data.bioontology.org/ontologies/GALEN/classes/http%3A%2F%2Fwww.co-ode.org%2Fontologies%2Fgalen%23Energy/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/GALEN?p=classes&conceptid=http%3A%2F%2Fwww.co-ode.org%2Fontologies%2Fgalen%23Energy'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'Energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'definition': 'http://data.bioontology.org/metadata/skosdefinition',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://purl.bioontology.org/ontology/npo#NPO_1745',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'definition': ['<ncicp:ComplexDefinition '
#                  'xmlns:ncicp="http://ncicb.nci.nih.gov/xml/owl/EVS/ComplexProperties.xsd#"><ncicp:def-definition>A '
#                  'realizable entity which is the capacity to do work or to '
#                  'exert force over a '
#                  'distance.</ncicp:def-definition><ncicp:Definition_Review_Date>100608</ncicp:Definition_Review_Date><ncicp:def-source>NPO</ncicp:def-source><ncicp:Definition_Reviewer_Name>Dennis '
#                  'Thomas</ncicp:Definition_Reviewer_Name></ncicp:ComplexDefinition>'],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/NPO/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2Fnpo%23NPO_1745/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/NPO/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2Fnpo%23NPO_1745/children',
#             'descendants': 'http://data.bioontology.org/ontologies/NPO/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2Fnpo%23NPO_1745/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/NPO/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2Fnpo%23NPO_1745/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/NPO/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2Fnpo%23NPO_1745/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/NPO/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2Fnpo%23NPO_1745/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/NPO',
#             'parents': 'http://data.bioontology.org/ontologies/NPO/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2Fnpo%23NPO_1745/parents',
#             'self': 'http://data.bioontology.org/ontologies/NPO/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2Fnpo%23NPO_1745',
#             'tree': 'http://data.bioontology.org/ontologies/NPO/classes/http%3A%2F%2Fpurl.bioontology.org%2Fontology%2Fnpo%23NPO_1745/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/NPO?p=classes&conceptid=http%3A%2F%2Fpurl.bioontology.org%2Fontology%2Fnpo%23NPO_1745'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://purl.obolibrary.org/obo/PATO_0001021',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/OBA/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/OBA/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/children',
#             'descendants': 'http://data.bioontology.org/ontologies/OBA/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/OBA/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/OBA/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/OBA/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/OBA',
#             'parents': 'http://data.bioontology.org/ontologies/OBA/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/parents',
#             'self': 'http://data.bioontology.org/ontologies/OBA/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021',
#             'tree': 'http://data.bioontology.org/ontologies/OBA/classes/http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/OBA?p=classes&conceptid=http%3A%2F%2Fpurl.obolibrary.org%2Fobo%2FPATO_0001021'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://www.icn.ch/icnp#Energy',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/ICNP/classes/http%3A%2F%2Fwww.icn.ch%2Ficnp%23Energy/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/ICNP/classes/http%3A%2F%2Fwww.icn.ch%2Ficnp%23Energy/children',
#             'descendants': 'http://data.bioontology.org/ontologies/ICNP/classes/http%3A%2F%2Fwww.icn.ch%2Ficnp%23Energy/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/ICNP/classes/http%3A%2F%2Fwww.icn.ch%2Ficnp%23Energy/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/ICNP/classes/http%3A%2F%2Fwww.icn.ch%2Ficnp%23Energy/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/ICNP/classes/http%3A%2F%2Fwww.icn.ch%2Ficnp%23Energy/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/ICNP',
#             'parents': 'http://data.bioontology.org/ontologies/ICNP/classes/http%3A%2F%2Fwww.icn.ch%2Ficnp%23Energy/parents',
#             'self': 'http://data.bioontology.org/ontologies/ICNP/classes/http%3A%2F%2Fwww.icn.ch%2Ficnp%23Energy',
#             'tree': 'http://data.bioontology.org/ontologies/ICNP/classes/http%3A%2F%2Fwww.icn.ch%2Ficnp%23Energy/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/ICNP?p=classes&conceptid=http%3A%2F%2Fwww.icn.ch%2Ficnp%23Energy'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'Energy',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://www.ifomis.org/acgt/1.0#Energy',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
# ...
#                  'and has its responsibility.'],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23Experimenter/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23Experimenter/children',
#             'descendants': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23Experimenter/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23Experimenter/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23Experimenter/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23Experimenter/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/REPRODUCE-ME',
#             'parents': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23Experimenter/parents',
#             'self': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23Experimenter',
#             'tree': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23Experimenter/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/REPRODUCE-ME?p=classes&conceptid=https%3A%2F%2Fw3id.org%2Freproduceme%23Experimenter'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'Experimenter',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://bioontology.org/projects/ontologies/birnlex#birnlex_2074',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/BIRNLEX/classes/http%3A%2F%2Fbioontology.org%2Fprojects%2Fontologies%2Fbirnlex%23birnlex_2074/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/BIRNLEX/classes/http%3A%2F%2Fbioontology.org%2Fprojects%2Fontologies%2Fbirnlex%23birnlex_2074/children',
#             'descendants': 'http://data.bioontology.org/ontologies/BIRNLEX/classes/http%3A%2F%2Fbioontology.org%2Fprojects%2Fontologies%2Fbirnlex%23birnlex_2074/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/BIRNLEX/classes/http%3A%2F%2Fbioontology.org%2Fprojects%2Fontologies%2Fbirnlex%23birnlex_2074/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/BIRNLEX/classes/http%3A%2F%2Fbioontology.org%2Fprojects%2Fontologies%2Fbirnlex%23birnlex_2074/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/BIRNLEX/classes/http%3A%2F%2Fbioontology.org%2Fprojects%2Fontologies%2Fbirnlex%23birnlex_2074/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/BIRNLEX',
#             'parents': 'http://data.bioontology.org/ontologies/BIRNLEX/classes/http%3A%2F%2Fbioontology.org%2Fprojects%2Fontologies%2Fbirnlex%23birnlex_2074/parents',
#             'self': 'http://data.bioontology.org/ontologies/BIRNLEX/classes/http%3A%2F%2Fbioontology.org%2Fprojects%2Fontologies%2Fbirnlex%23birnlex_2074',
#             'tree': 'http://data.bioontology.org/ontologies/BIRNLEX/classes/http%3A%2F%2Fbioontology.org%2Fprojects%2Fontologies%2Fbirnlex%23birnlex_2074/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/BIRNLEX?p=classes&conceptid=http%3A%2F%2Fbioontology.org%2Fprojects%2Fontologies%2Fbirnlex%23birnlex_2074'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'Experimenter',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'definition': 'http://data.bioontology.org/metadata/skosdefinition',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://ontology.apa.org/apaonto/termsonlyOUT%20(5).owl#Experimenter_Expectations',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'definition': ['Results from experimentation which are anticipated\n'
#                  'or desired by the researcher in order to confirm a\n'
#                  'hypothesis and which may serve as a potential\n'
#                  'factor in experimenter bias.'],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Expectations/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Expectations/children',
#             'descendants': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Expectations/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Expectations/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Expectations/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Expectations/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/APAONTO',
#             'parents': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Expectations/parents',
#             'self': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Expectations',
#             'tree': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Expectations/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/APAONTO?p=classes&conceptid=http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Expectations'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'Experimenter Expectations',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'definition': 'http://data.bioontology.org/metadata/skosdefinition',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'http://ontology.apa.org/apaonto/termsonlyOUT%20(5).owl#Experimenter_Bias',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'definition': ['Potential and unintentional influence on\n'
#                  'experimental outcomes caused by the experimenter.'],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Bias/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Bias/children',
#             'descendants': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Bias/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Bias/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Bias/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Bias/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/APAONTO',
#             'parents': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Bias/parents',
#             'self': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Bias',
#             'tree': 'http://data.bioontology.org/ontologies/APAONTO/classes/http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Bias/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/APAONTO?p=classes&conceptid=http%3A%2F%2Fontology.apa.org%2Fapaonto%2FtermsonlyOUT%2520%285%29.owl%23Experimenter_Bias'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'Experimenter Bias',
#   'provisional': False},
#  {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#                'definition': 'http://data.bioontology.org/metadata/skosdefinition',
#                'obsolete': 'http://data.bioontology.org/metadata/owlobsolete',
#                'prefLabel': 'http://data.bioontology.org/metadata/skosprefLabel'},
#   '@id': 'https://w3id.org/reproduceme#ExperimenterGroupConfig',
#   '@type': 'http://www.w3.org/2002/07/owl#Class',
#   'definition': ['Configuration of an experimenter group.'],
#   'links': {'@context': {'ancestors': 'http://www.w3.org/2002/07/owl#Class',
#                          'children': 'http://www.w3.org/2002/07/owl#Class',
#                          'descendants': 'http://www.w3.org/2002/07/owl#Class',
#                          'instances': 'http://data.bioontology.org/metadata/Instance',
#                          'mappings': 'http://data.bioontology.org/metadata/Mapping',
#                          'notes': 'http://data.bioontology.org/metadata/Note',
#                          'ontology': 'http://data.bioontology.org/metadata/Ontology',
#                          'parents': 'http://www.w3.org/2002/07/owl#Class',
#                          'self': 'http://www.w3.org/2002/07/owl#Class',
#                          'tree': 'http://www.w3.org/2002/07/owl#Class',
#                          'ui': 'http://www.w3.org/2002/07/owl#Class'},
#             'ancestors': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23ExperimenterGroupConfig/ancestors',
#             'children': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23ExperimenterGroupConfig/children',
#             'descendants': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23ExperimenterGroupConfig/descendants',
#             'instances': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23ExperimenterGroupConfig/instances',
#             'mappings': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23ExperimenterGroupConfig/mappings',
#             'notes': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23ExperimenterGroupConfig/notes',
#             'ontology': 'http://data.bioontology.org/ontologies/REPRODUCE-ME',
#             'parents': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23ExperimenterGroupConfig/parents',
#             'self': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23ExperimenterGroupConfig',
#             'tree': 'http://data.bioontology.org/ontologies/REPRODUCE-ME/classes/https%3A%2F%2Fw3id.org%2Freproduceme%23ExperimenterGroupConfig/tree',
#             'ui': 'http://bioportal.bioontology.org/ontologies/REPRODUCE-ME?p=classes&conceptid=https%3A%2F%2Fw3id.org%2Freproduceme%23ExperimenterGroupConfig'},
#   'matchType': 'prefLabel',
#   'obsolete': False,
#   'ontologyType': 'ONTOLOGY',
#   'prefLabel': 'Experimenter Group Config',
#   'provisional': False}]

# %% [markdown]
# ## get_labels.py

# %%
import urllib.request, urllib.error, urllib.parse
import json

REST_URL = "http://data.bioontology.org"
#API_KEY = ""


def get_json(url):
    opener = urllib.request.build_opener()
    opener.addheaders = [('Authorization', 'apikey token=' + API_KEY)]
    return json.loads(opener.open(url).read())

# Get all ontologies from the REST service and parse the JSON
ontologies = get_json(REST_URL+"/ontologies")

# Iterate looking for ontology with acronym BRO
bro = None
for ontology in ontologies:
    if ontology["acronym"] == "BRO":
        bro = ontology

labels = []

# Using the hypermedia link called `classes`, get the first page
page = get_json(bro["links"]["classes"])

# Iterate over the available pages adding labels from all classes
# When we hit the last page, the while loop will exit
next_page = page
while next_page:
    next_page = page["links"]["nextPage"]
    for bro_class in page["collection"]:
        labels.append(bro_class["prefLabel"])
    if next_page:
        page = get_json(next_page)

# Output the labels
for label in labels:
    print(label)
# Out:
# Ontology Development and Management
# Modular Component
# Stimulator
# Cell Culture Facility
# Exploratory Data Analysis
# Clinical Research Data
# Private Funding Resource
# Human Embryonic Stem Cell Resource
# Outcomes Research
# Software Distribution
# Named Entity Normalization
# Data Editor
# Pass Through License
# Structured Data
# Finite Element Model
# Volume Model Scene Data
# Searching Sorting and Indexing
# Technical Support
# PDE Solver
# Social Networking
# Graph Analysis
# Graphical Integration
# Processing Pipeline
# Version Source Control System
# White Paper
# Document Retrieval
# Training
# Health Services
# Immunohistochemistry Facility
# Model with Closed Form Solutions
# Multibody Dynamics
# Narrative Resource
# Resource Inventory
# Analysis of Gel-Electrophoresis
# Biomolecular Interaction Facility
# Structure-Based Protein Classification
# Statistical Package
# Hosting
# Information Retrieval
# Web Service
# Support
# PCR Instrument
# Cortical Modeling
# Fast Fourier Transform
# Research Lab Management
# Convolution
# Genomics Facility
# Protein Expression
# Integration and Interoperability Tools
# Funding Resource
# Website
# Aggregate Human Data
# Software Development Environment
# X-Ray Crystallography Facility
# NMR Facility
# Signal Processing
# Optimizer
# Material Storage Service
# Network Characterization
# Nonhuman Data
# Continuing Medical Education
# Pressure Regulator
# Molecular Trajectories
# Model Fitting Algorithm
# Genomics
# Source Code
# Report
# Novel Therapeutics
# Monoclonal Antibody Facility
# Microscopy Facility
# Graph Alignment
# Immune Monitoring Facility
# Vibrotome
# Computational Hosting
# RNA Model
# Patent
# Human Studies Compliance Resource
# Text Mining
# Interactive Tools
# Pediatrics
# Document
# Web Posting
# Symbolic and Analytic Model
# Pathology
# Pattern and Motif Inference
# Hyperbolic Graph
# Pharmacokinetics Pharmacodynamics
# Biostatistics
# Animal Care Facility
# Biomaterial Manufacture
# Mechanical Simulation
# Unstructured Knowledge Resource
# Data Acquisition Software
# Gene Therapy
# Inference From Data
# Regulatory Compliance
# Grid Computing
# Three D Image
# Heterogeneous Funding Resource
# Amplifier
# Signaling Network Reconstruction
# Pharmacokinetics Pharmacodynamics Expertise
# Online Course
# Statistical Text Analysis
# Environmental Health and Safety Resource
# Data Analysis Software
# Code Testing Framework
# Documentation Generation
# Robotic Arrayer
# Statistical Algorithm
# Training Service
# Research Funding
# Scalar Data
# Three Dimensional Data
# Inhomogeneity Correction
# Network and Communication
# Individual Human Data
# Data Transform
# XML Data
# Physico-Chemical Model
# Conference Proceeding
# Mailing List
# Toxicology
# Behavioral Analysis Service
# Biosafety Level Facility
# Molecular Interaction
# Wavelet Model
# Fabrication Facility
# Portal
# Next Generation Sequencer
# Graph Viewers
# Numerical Methods
# Metabolomics Facility
# Cross-Language Wrapping
# Course Material
# License and Terms for Use
# Averaging and Aglomeration
# Structured Knowledge Resource
# Clinical Chart
# Chamber
# Ontology Development
# Graph Algorithm
# Software
# PET Scanner
# Data Transfer and Communication
# Expertise
# Knowledgebase
# Dynamic Model
# Animal Models Facility
# Authentication
# Compiler
# Thesis
# Government Publication
# Linear Algebra Tool
# Non Computational Service
# Tutorial
# Skull Stripping
# Instrument Manufacture
# Area of Research
# Root Finder
# Feature Analysis
# Oscillograph
# Certificate Program
# Heath Services
# Standard Specification
# Paper
# Spectral Transform
# Hypothesis Testing Algorithm
# Prediction of Side-Chain Conformations
# Material Resource
# Network Interaction Model
# Cell Processing Clean Room Facility
# EDA
# News
# Manifold Viewers
# Mesh Model
# Interactive Web-Based Tool
# IRB
# Imaging Facility
# Outlier Detection and Removal
# Stochastic Data
# Vector Data
# Molecular Dynamics
# Molecular Trajectory Data
# Data Storage Repository
# Micromanipulator
# Nursing
# Clinical Trial Data
# Stem Cell Therapy Facility
# Pattern Recognition
# Service Resource
# Image Algorithm
# Sleep Study Facility
# Communication and Collaborative Work
# Computational Geometry
# Numerical Calculation of Electrostatic Potential
# Online Support
# Deprecated Activity
# Material Service
# Research Animals Facility
# Document Structure Parsing
# Community Structure Analysis
# Drug Delivery Device
# Phenotypic Measurement
# Backup Archive Service
# Phenotype Management
# Protein Model
# Provenance
# NMR Instrument
# Lexical Analysis
# Application Programming Interface
# Numerical Integrators
# Cross-Sectional Viewer
# Visualization
# Communication Interface
# Material Analysis Service
# Disaster Recovery Service
# Cardiovascular Facility
# Time Series Analysis
# Faraday Cage
# Physioloigcal Model
# Medical Device
# Centrality Analsysis
# Metabolomics
# Sequence Visualization
# Manifold Viewer
# Proteomics
# Imaging
# Four Dimensional Data
# Sequence Similarity Searching
# Clinical Care Data
# Behavioral Science
# Flow Cytometry Cell Sorting Facility
# Regulatory Compliance Resource
# Bug Reporting
# Concept
# Seminar Series
# Interaction Network
# Numerical Integrator
# Controllers
# Computer-Instrumentation Interface
# Activity
# Assessment Material Resource
# Data Repository
# Connectivity Matrix
# Cross-Platform Tool
# Data Normalization
# Automated Natural Language Output
# List
# Data Exploration
# Data Computation Service
# Biositemaps Information Model
# Pre-Processing
# Resource
# Molecular Modeling and Classification
# Therapeutics
# Molecular Force Field Calculator
# Genomic Phenotypic Analysis
# Rack
# Pathology Laboratory Screening
# Semantic Network
# Data Mining and Inference
# Pipeline Manager
# High Dimensional Data
# Linear Algebra Tools
# Hierarchical Tree
# Ontology Visualization
# Electrode Puller
# Data Storage
# Micro Dissection Facility
# Named Entity Recognition
# Source Control
# Statistical Analysis
# Microtome
# Discrete Data
# Molecular and Cellular Data
# Software Engineering Tool
# Database Software
# Neurological Facility
# Biomaterial Analysis Service
# Training Resource
# Data Storage Service
# Data Resource
# Laboratory Supply Resource
# Conflict of Interest Resource
# Facility Core
# Dissemination Vehicle
# Code Profiler
# Feature Request
# Two D Image
# Data Service
# Cell Biology Facility
# Biobank Facility
# Website Hosting
# Metabolism Facility
# Mapper
# Knowledge Environment
# Cell Model
# Knowledge Extraction
# Toolkit
# Resource Description
# Tissue Organ Facility
# Deprecated Area of Research
# Exercise Study Facility
# Network Model
# Free Text
# Relational Database
# Version Information
# Biospecimen Management
# Random Number Simulation
# Semi-Structured Knowledge Resource
# Bibliographic Resource
# Medical Device Development
# Structural Model
# Clinical Data
# Homology Modeling
# Filtering
# Data Compression
# Summarization
# Computational Model
# Numerical Method
# Network model
# Concept Scheme
# Protocol Development Expertise
# Microarray Scanner
# Shape Analysis
# Atlas
# Biomedical Supply Resource
# Power Conditioning Unit
# physico chemical models
# Mass Spectrometer
# Deep Parsing
# People Resource
# Ordered Collection
# Industry Partnership Expertise
# Programmatic Access
# License
# Ontology
# Calendar Schedule and Resource Management
# Integrated Hosting
# Binary Executable
# Experimental Measurement
# Natural Language Processing
# Gene Expression
# Journal Article
# License and Terms for Redistribution
# Interaction Modeling
# Temperature Control Unit
# Tutorials
# Vibration Isolation Table
# Interactive Tool
# Biochemical Supply Resource
# Book
# Reagent Resource
# Experimental Protocol
# Atlas Generation
# Data Transforms
# Network Editor
# Data Annotation
# Computational Service
# Calorimeter
# Protein-Protein Interaction
# Oscilloscope
# Graph Viewer
# Continuum Method Simulation
# Fourier Transform
# Algorithm
# Federal Funding Resource
# Animal Compliance Resource
# Workbench
# Knowledge Mining and Capturing
# Clinical Charts
# Epidemiology
# Biomaterial Supply Resource
# Object Database
# Software Development Resource
# Phlebotomy Facility
# Radioisotopes Facility
# Backup Archives and Disaster Recovery
# Cardiovascular Model
# State Funding Resource
# Computational Biology
# PCR Facility
# Registration
# Image Processing
# Delimited Table
# Antibody Production
# Reagent Manufacture
# Regulatory Policy Resource
# Wavelet Transform
# Software development
# Electron Microscope
# Centrality Analysis
# Toxicology Expertise
# Graphical Processing Workflow Environments
# Ontology Diff and Alignment
# Deprecated Data Resource
# Nutrition Facility
# Grant Preparation Expertise
# Bioinformatics
# Partial Parsing
# Contact Modeling
# Server
# CT Scanner
# Small Molecule
# Segmentation
# Image
# Microscope
# Meshing
# Provenance and Intellectual Property
# Continuous Data
# Interactive Network Analysis
# Mass Spectra Identification
# Molecular Visualization
# Sequence Annotation
# Deprecated Resource
# Collection
# Regularization and Smoothing
# Testing Tools
# Calculation of Solvent Accessible Area
# Molecular Model
# Document Generation
# Outreach Program
# Psychometrics
# Structured File
# Clinical Studies
# Pattern Inference Algorithm
# Physiology Facility
# Anatomic Atlas
# Sequence Alignment
# Numerical Model
# Monte Carlo Simulation
# Data Distribution
# Database Hosting
# Data Visualization
# Approximate Graph Alignment
# Integration
# Web Access
# Protein Interaction Modeling
# Averaging and Agglomeration
# Software Technology Protocol
# Language Summarization
# Molecular Biology Facility
# Community Engagement
# Flatfile Distribution
# Sentence Splitting
# Publication
# Scripting Language and Environment
# Light Microscope
# Portlet Component
# Matrix
# Regulatory Signaling Network Reconstruction
# Resource Integration Component
# Education
# Parsing
# Authorization
# Unstructured Data
# Software Development Tool
# Software Documentation
# Image Reconstruction
# Integration and Interoperability Tool
# Research Supplies
# Research IT
# Instrument
# Gene Therapy Facility
# Neuromuscular Model
# Standalone Application
# Preclinical
# Identity Management
# ExternalResource
# Proteomics Facility
# Heat Map
# RDF Data
# Information Resource
# Surgical Procedure
# MRI Scanner
# Data Object
# Data Processing Software
# Personal Communication
# Psychometrics Expertise
# Graphical Composition
# Physiology
# Intellectual Property Resource
# XML Database
# Software Development
# Modeling and Simulation
# Electrode Holder
# Database

# %% [markdown]
# ## list_ontologies.py

# %%
import urllib.request, urllib.error, urllib.parse
import json
import os
from pprint import pprint

REST_URL = "http://data.bioontology.org"
#API_KEY = ""

def get_json(url):
    opener = urllib.request.build_opener()
    opener.addheaders = [('Authorization', 'apikey token=' + API_KEY)]
    return json.loads(opener.open(url).read())

# Get the available resources
resources = get_json(REST_URL + "/")

# Get the ontologies from the `ontologies` link
ontologies = get_json(resources["links"]["ontologies"])

# Get the name and ontology id from the returned list
ontology_output = []
for ontology in ontologies:
    ontology_output.append(f"{ontology['name']}\n{ontology['@id']}\n")

# Print the first ontology in the list
pprint(ontologies[0])

# Print the names and ids
print("\n\n")
for ont in ontology_output:
    print(ont)
# Out:
# {'@context': {'@vocab': 'http://data.bioontology.org/metadata/',
#               'acronym': 'http://data.bioontology.org/metadata/omvacronym',
#               'administeredBy': {'@id': 'http://data.bioontology.org/metadata/User',
#                                  '@type': '@id'},
#               'name': 'http://data.bioontology.org/metadata/omvname',
#               'ontologyType': {'@id': 'http://data.bioontology.org/metadata/OntologyType',
#                                '@type': '@id'}},
#  '@id': 'http://data.bioontology.org/ontologies/ICO',
#  '@type': 'http://data.bioontology.org/metadata/Ontology',
#  'acronym': 'ICO',
#  'administeredBy': ['http://data.bioontology.org/users/linikujp',
#                     'http://data.bioontology.org/users/yongqunh%40med.umich.edu'],
#  'flat': None,
#  'links': {'@context': {'analytics': 'http://data.bioontology.org/metadata/Analytics',
#                         'categories': 'http://data.bioontology.org/metadata/Category',
#                         'classes': 'http://www.w3.org/2002/07/owl#Class',
#                         'download': 'http://data.bioontology.org/metadata/Ontology',
#                         'groups': 'http://data.bioontology.org/metadata/Group',
#                         'instances': 'http://data.bioontology.org/metadata/Instance',
#                         'latest_submission': 'http://data.bioontology.org/metadata/OntologySubmission',
#                         'metrics': 'http://data.bioontology.org/metadata/Metrics',
#                         'notes': 'http://data.bioontology.org/metadata/Note',
#                         'projects': 'http://data.bioontology.org/metadata/Project',
#                         'properties': 'http://data.bioontology.org/metadata/Property',
#                         'reviews': 'http://data.bioontology.org/metadata/Review',
#                         'roots': 'http://www.w3.org/2002/07/owl#Class',
#                         'single_class': 'http://www.w3.org/2002/07/owl#Class',
#                         'submissions': 'http://data.bioontology.org/metadata/OntologySubmission',
#                         'ui': 'http://data.bioontology.org/metadata/Ontology',
#                         'views': 'http://data.bioontology.org/metadata/Ontology'},
#            'analytics': 'http://data.bioontology.org/ontologies/ICO/analytics',
#            'categories': 'http://data.bioontology.org/ontologies/ICO/categories',
#            'classes': 'http://data.bioontology.org/ontologies/ICO/classes',
#            'download': 'http://data.bioontology.org/ontologies/ICO/download',
#            'groups': 'http://data.bioontology.org/ontologies/ICO/groups',
#            'instances': 'http://data.bioontology.org/ontologies/ICO/instances',
#            'latest_submission': 'http://data.bioontology.org/ontologies/ICO/latest_submission',
#            'metrics': 'http://data.bioontology.org/ontologies/ICO/metrics',
#            'notes': 'http://data.bioontology.org/ontologies/ICO/notes',
#            'projects': 'http://data.bioontology.org/ontologies/ICO/projects',
#            'properties': 'http://data.bioontology.org/ontologies/ICO/properties',
#            'reviews': 'http://data.bioontology.org/ontologies/ICO/reviews',
#            'roots': 'http://data.bioontology.org/ontologies/ICO/classes/roots',
#            'single_class': 'http://data.bioontology.org/ontologies/ICO/classes/{class_id}',
#            'submissions': 'http://data.bioontology.org/ontologies/ICO/submissions',
#            'ui': 'http://bioportal.bioontology.org/ontologies/ICO',
#            'views': 'http://data.bioontology.org/ontologies/ICO/views'},
#  'name': 'Informed Consent Ontology',
#  'ontologyType': 'http://data.bioontology.org/ontology_types/ONTOLOGY',
#  'summaryOnly': False}
#
#
#
# Informed Consent Ontology
# http://data.bioontology.org/ontologies/ICO
#
# GeoSpecies Ontology
# http://data.bioontology.org/ontologies/GEOSPECIES
#
# Time Event Ontology
# http://data.bioontology.org/ontologies/TEO
#
# Ontology Metadata Vocabulary
# http://data.bioontology.org/ontologies/OMV
#
# Translational Medicine Ontology
# http://data.bioontology.org/ontologies/TMO
#
# Ontology of Precision Medicine and Investigation
# http://data.bioontology.org/ontologies/OPMI
#
# Open Predictive Microbiology Ontology
# http://data.bioontology.org/ontologies/OFSMR
#
# Molgula occulta Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/MOOCCUADO
#
# Life Ontology
# http://data.bioontology.org/ontologies/LIFO
#
# Material Compound
# http://data.bioontology.org/ontologies/MATRCOMPOUND
#
# AGRonomy Ontology
# http://data.bioontology.org/ontologies/AGRO
#
# Cancer Staging Terms
# http://data.bioontology.org/ontologies/CST
#
# Regional Healthcare System Interoperability and Information Exchange Measurement Ontology
# http://data.bioontology.org/ontologies/HEIO
#
# Radiology Gamuts Ontology
# http://data.bioontology.org/ontologies/GAMUTS
#
# Epigenome Ontology
# http://data.bioontology.org/ontologies/EGO
#
# ISO 19115 Role Codes
# http://data.bioontology.org/ontologies/ISO19115ROLES
#
# Infectious Disease Ontology
# http://data.bioontology.org/ontologies/IDO
#
# MARC Code List for Relators
# http://data.bioontology.org/ontologies/MARC-RELATORS
#
# Chronic Disease Patient Education Ontology
# http://data.bioontology.org/ontologies/CDPEO
#
# FlyBase Controlled Vocabulary
# http://data.bioontology.org/ontologies/FB-CV
#
# Illness and Injury
# http://data.bioontology.org/ontologies/ILLNESSINJURY
#
# Neuroscience Information Framework (NIF) Dysfunction Ontlogy
# http://data.bioontology.org/ontologies/NIFDYS
#
# Read Clinical Terminology Version 2
# http://data.bioontology.org/ontologies/RCTV2
#
# Mouse gross anatomy and development, timed
# http://data.bioontology.org/ontologies/EMAPA
#
# Farmaci
# http://data.bioontology.org/ontologies/FARMACI
#
# Bilingual Ontology of Alzheimer's Disease and Related Diseases
# http://data.bioontology.org/ontologies/ONTOAD
#
# Tissue Microarray Ontology
# http://data.bioontology.org/ontologies/TMA
#
# HIVMutation
# http://data.bioontology.org/ontologies/HIVMT
#
# HIVOntologymain.owl
# http://data.bioontology.org/ontologies/HIVO004
#
# Semanticscience Integrated Ontology
# http://data.bioontology.org/ontologies/SIO
#
# Protein Modification Ontology
# http://data.bioontology.org/ontologies/PSIMOD
#
# Resource of Asian Primary Immunodeficiency Diseases (RAPID) Phenotype Ontology
# http://data.bioontology.org/ontologies/RPO
#
# ICD-O-3-M International Classification of Diseases for Oncology Morphology
# http://data.bioontology.org/ontologies/ICD-O-3-M
#
# Biomedical Informatics Research Network Project Lexicon
# http://data.bioontology.org/ontologies/BIRNLEX
#
# Children's Health Exposure Analysis Resource
# http://data.bioontology.org/ontologies/CHEAR
#
# Pathway Ontology
# http://data.bioontology.org/ontologies/PW
#
# Data Collection Ontology
# http://data.bioontology.org/ontologies/GDCO
#
# HPO - ORDO Ontological Module
# http://data.bioontology.org/ontologies/HOOM
#
# Bacterial interlocked Process ONtology
# http://data.bioontology.org/ontologies/BIPON
#
# Molecular Interactions
# http://data.bioontology.org/ontologies/MI
#
# Ctenophore Ontology
# http://data.bioontology.org/ontologies/CTENO
#
# Glioblastoma
# http://data.bioontology.org/ontologies/GBM
#
# Ontology for Genetic Susceptibility Factor
# http://data.bioontology.org/ontologies/OGSF
#
# Relations Ontology
# http://data.bioontology.org/ontologies/OBOREL
#
# antiviral
# http://data.bioontology.org/ontologies/AVIR
#
# Radiomics Ontology
# http://data.bioontology.org/ontologies/RO
#
# Non-coding RNA Ontology
# http://data.bioontology.org/ontologies/NCRO
#
# Molgula occidentalis Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/MOOCCIADO
#
# PhenomeBLAST Ontology
# http://data.bioontology.org/ontologies/PHENOMEBLAST
#
# Ontology for Parasite LifeCycle
# http://data.bioontology.org/ontologies/OPL
#
# Ontology for Breath Sample Processes
# http://data.bioontology.org/ontologies/BSP
#
# BioPortal Metadata Ontology
# http://data.bioontology.org/ontologies/BP-METADATA
#
# vps windows
# http://data.bioontology.org/ontologies/VPS
#
# EDDA Study Designs Taxonomy
# http://data.bioontology.org/ontologies/EDDA
#
# KB_Bio_101
# http://data.bioontology.org/ontologies/AURA
#
# General Formal Ontology for Biology
# http://data.bioontology.org/ontologies/GFO-BIO
#
# Family Health History Ontology
# http://data.bioontology.org/ontologies/FHHO
#
# Ontology of Data Mining Investigations
# http://data.bioontology.org/ontologies/ONTODM-KDD
#
# Friend of a Friend Vocabulary
# http://data.bioontology.org/ontologies/FOAF
#
# rrr
# http://data.bioontology.org/ontologies/RRR
#
# Web Annotation Ontology
# http://data.bioontology.org/ontologies/OA
#
# Ontology for General Medical Science
# http://data.bioontology.org/ontologies/OGMS
#
# Mental Health Management Ontology
# http://data.bioontology.org/ontologies/MHMO
#
# Drug Abuse Ontology
# http://data.bioontology.org/ontologies/DAO
#
# Biomedical Resource Ontology
# http://data.bioontology.org/ontologies/BRO
#
# Neurologic Examination Ontology
# http://data.bioontology.org/ontologies/NEO
#
# Psychology Ontology
# http://data.bioontology.org/ontologies/APAONTO
#
# Hypersensitivity pneumonitis ontology
# http://data.bioontology.org/ontologies/HP_O
#
# ISO 19110 Methodology for Feature Cataloguing
# http://data.bioontology.org/ontologies/ISO19110
#
# Surgical and Medical Procedures
# http://data.bioontology.org/ontologies/CTCAE5-C143189
#
# Contributor Role Ontology
# http://data.bioontology.org/ontologies/CRO
#
# Social Prescribing Ontology
# http://data.bioontology.org/ontologies/SOCPRES
#
# SNOMED PRUEBA
# http://data.bioontology.org/ontologies/SNOMED_PRUEBA
#
# Nurse Transitional
# http://data.bioontology.org/ontologies/TRANS
#
# Plant Trait Ontology
# http://data.bioontology.org/ontologies/PTO
#
# Molecular Process Ontology
# http://data.bioontology.org/ontologies/MOP
#
# Presence Ontology
# http://data.bioontology.org/ontologies/PREO
#
# Bioentities
# http://data.bioontology.org/ontologies/BE
#
# Mouse Experimental Design Ontology
# http://data.bioontology.org/ontologies/MEDO
#
# Ontology of Arthropod Circulatory Systems
# http://data.bioontology.org/ontologies/OARCS
#
# Biological interlocked Process Ontology for metabolism
# http://data.bioontology.org/ontologies/BIPOM
#
# Timebank Ontology
# http://data.bioontology.org/ontologies/TIMEBANK
#
# Pre-eclampsia Ontology
# http://data.bioontology.org/ontologies/PE-O
#
# Cognitive Atlas Ontology
# http://data.bioontology.org/ontologies/COGAT
#
# Health Level Seven Reference Implementation Model, Version 3
# http://data.bioontology.org/ontologies/HL7
#
# Doremus List of Keys
# http://data.bioontology.org/ontologies/DOREMUS-KEYS
#
# Cognitive Paradigm Ontology
# http://data.bioontology.org/ontologies/COGPO
#
# CIO1
# http://data.bioontology.org/ontologies/CIO1
#
# Feature Annotation Location Description Ontology
# http://data.bioontology.org/ontologies/FALDO
#
# Upper-Level Cancer Ontology
# http://data.bioontology.org/ontologies/CANONT
#
# Cell Culture Ontology
# http://data.bioontology.org/ontologies/CCONT
#
# Ontological Knowledge Base Model for Cystic Fibrosis
# http://data.bioontology.org/ontologies/ONTOKBCF
#
# Platynereis Developmental Stages
# http://data.bioontology.org/ontologies/PDUMDV
#
# ISO 19115 Constraints Information
# http://data.bioontology.org/ontologies/ISO19115CON
#
# Interlinking Ontology for Biological Concepts
# http://data.bioontology.org/ontologies/IOBC
#
# Epilepsy Ontology
# http://data.bioontology.org/ontologies/EPILONT
#
# Experimental Factor Ontology
# http://data.bioontology.org/ontologies/EFO
#
# Traditional Medicine Other Factors Value Set
# http://data.bioontology.org/ontologies/TM-OTHER-FACTORS
#
# RegenBase ontology
# http://data.bioontology.org/ontologies/RB
#
# FAST (Faceted Access of Subject Terminology) Chronological Facet
# http://data.bioontology.org/ontologies/FAST-CHRONO
#
# Epilepsy Semiology
# http://data.bioontology.org/ontologies/EPISEM
#
# Disorders cluster
# http://data.bioontology.org/ontologies/APADISORDERS
#
# Knowledge Object Reference Ontology
# http://data.bioontology.org/ontologies/KORO
#
# Viral Disease Ontology Trunk
# http://data.bioontology.org/ontologies/VDOT
#
# Genomic Clinical Decision Support Ontology
# http://data.bioontology.org/ontologies/GENE-CDS
#
# PatientSafetyOntology
# http://data.bioontology.org/ontologies/PSO
#
# Social Inset Behavior Ontology
# http://data.bioontology.org/ontologies/SIBO
#
# International Classification of Functioning, Disability and Health
# http://data.bioontology.org/ontologies/ICF
#
# Loggerhead Nesting Ontology
# http://data.bioontology.org/ontologies/LHN
#
# Parasite Experiment Ontology
# http://data.bioontology.org/ontologies/PEO
#
# Global Ingredient Archival System
# http://data.bioontology.org/ontologies/GINAS
#
# Food Matrix for Predictive Microbiology
# http://data.bioontology.org/ontologies/FMPM
#
# International Journal for Modern Trends in Science and Technology
# http://data.bioontology.org/ontologies/IJMTST
#
# Genetic Test
# http://data.bioontology.org/ontologies/GTO
#
# MHC Restriction Ontology
# http://data.bioontology.org/ontologies/MHCRO
#
# The Prescription of Drugs Ontology
# http://data.bioontology.org/ontologies/PDRO
#
# Variation Ontology
# http://data.bioontology.org/ontologies/VARIO
#
# Semantic Sensor Network Ontology
# http://data.bioontology.org/ontologies/SSN
#
# Ontology of Glucose Metabolism Disorder
# http://data.bioontology.org/ontologies/OGMD
#
# FRBR-aligned Bibliographic Ontology
# http://data.bioontology.org/ontologies/FABIO
#
# Ontology of Clinical Research
# http://data.bioontology.org/ontologies/OCRE
#
# The Extensible Observation Ontology
# http://data.bioontology.org/ontologies/OBOE
#
# ISO-15926-2_2003_annotations
# http://data.bioontology.org/ontologies/ISO-ANNOTATIONS
#
# FAST (Faceted Application of Subject Terminology) FormGenre facet
# http://data.bioontology.org/ontologies/FAST-FORMGENRE
#
# Traditional Medicine Signs and Symptoms Value Set
# http://data.bioontology.org/ontologies/TM-SIGNS-AND-SYMPTS
#
# Clinical MetaData Ontology
# http://data.bioontology.org/ontologies/CMDO
#
# Phylogenetics Ontology
# http://data.bioontology.org/ontologies/PHAGE
#
# ONTO_TEST_1
# http://data.bioontology.org/ontologies/ONTO_TEST_1
#
# apalegal
# http://data.bioontology.org/ontologies/LEGALAPATEST2
#
# Diabetes Mellitus Treatment Ontology
# http://data.bioontology.org/ontologies/DMTO
#
# Fire Ontology
# http://data.bioontology.org/ontologies/FIRE
#
# Prokaryotic Phenotypic and Metabolic Characters
# http://data.bioontology.org/ontologies/MICRO
#
# Neglected Tropical Disease Ontology
# http://data.bioontology.org/ontologies/NTDO
#
# Phallusia mammillata Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/PHMAMMADO
#
# Ontology for Geography Markup Language (GML3.0)
# http://data.bioontology.org/ontologies/GML
#
# Adherence and Integrated Care
# http://data.bioontology.org/ontologies/ADHER_INTCARE_EN
#
# Library of Congress Subject Schemes
# http://data.bioontology.org/ontologies/LC-SUBJSCHEMES
#
# Glycomics Ontology
# http://data.bioontology.org/ontologies/GLYCO
#
# Schema.org core and all extension vocabularies
# http://data.bioontology.org/ontologies/SCHEMA
#
# Randomized Controlled Trials Ontology
# http://data.bioontology.org/ontologies/RCTONT
#
# Ontology of Physics for Biology
# http://data.bioontology.org/ontologies/OPB
#
# Plant Anatomy
# http://data.bioontology.org/ontologies/PAE
#
# HIV ontology
# http://data.bioontology.org/ontologies/HIV
#
# Medical Web Lifestyle Aggregator
# http://data.bioontology.org/ontologies/MWLA
#
# Ontology of Craniofacial Development and Malformation
# http://data.bioontology.org/ontologies/OCDM
#
# ISO 639-2: Codes for the Representation of Names of Languages
# http://data.bioontology.org/ontologies/ISO639-2
#
# Precision Medicine Ontology
# http://data.bioontology.org/ontologies/PREMEDONTO
#
# Fernald Community Cohort N
# http://data.bioontology.org/ontologies/FCC1
#
# APA Statistical Cluster
# http://data.bioontology.org/ontologies/APASTATISTICAL
#
# Material Rock
# http://data.bioontology.org/ontologies/MATRROCK
#
# Drug Database for Inborn Errors of Metabolism (DDIEM) Ontology
# http://data.bioontology.org/ontologies/DDIEM
#
# Control de Cacao
# http://data.bioontology.org/ontologies/AGROMOP
#
# Quantities, Units, Dimensions and Types (QUDT) Schema - Version 2.0
# http://data.bioontology.org/ontologies/QUDT2
#
# Spider Anatomy Ontology
# http://data.bioontology.org/ontologies/SPD
#
# Cancer Chemoprevention Ontology
# http://data.bioontology.org/ontologies/CANCO
#
# Ontology of Medically Related Social Entities
# http://data.bioontology.org/ontologies/OMRSE
#
# Ontology of Biological Attributes
# http://data.bioontology.org/ontologies/OBA
#
# Taxonomy for Rehabilitation of Knee Conditions
# http://data.bioontology.org/ontologies/TRAK
#
# Ontology for Drug Discovery Investigations
# http://data.bioontology.org/ontologies/DDI
#
# Medical Dictionary for Regulatory Activities Terminology (MedDRA)
# http://data.bioontology.org/ontologies/MEDDRA
#
#  Core Ontology for Biology and Biomedicine
# http://data.bioontology.org/ontologies/COB
#
# ISO 19115 Metadata Information
# http://data.bioontology.org/ontologies/ISO19115MI
#
# GoMapMan
# http://data.bioontology.org/ontologies/GMM
#
# Visualized Emotion Ontology
# http://data.bioontology.org/ontologies/VEO
#
# Situation-Based Access Control Ontology
# http://data.bioontology.org/ontologies/SITBAC
#
# Physico-Chemical Process
# http://data.bioontology.org/ontologies/REX
#
# NMR-Controlled Vocabulary
# http://data.bioontology.org/ontologies/NMR
#
# MyOntoServiceFull_FallDetection
# http://data.bioontology.org/ontologies/FALL
#
# OntoPsychia, social module
# http://data.bioontology.org/ontologies/ONTOPSYCHIA
#
# Zebrafish Developmental Stages
# http://data.bioontology.org/ontologies/ZFS
#
# Menelas Project Top-Level Ontology
# http://data.bioontology.org/ontologies/TOP-MENELAS
#
# FOBI (Food-Biomarker Ontology)
# http://data.bioontology.org/ontologies/FOBI
#
# Tony Tran
# http://data.bioontology.org/ontologies/TT476
#
# Comparative Data Analysis Ontology
# http://data.bioontology.org/ontologies/CDAO
#
# Biologie Hors Nomenclature
# http://data.bioontology.org/ontologies/BHN
#
# STO
# http://data.bioontology.org/ontologies/CVAO
#
# Planarian Phenotype Ontology
# http://data.bioontology.org/ontologies/PLANP
#
# ISO 19115 Codelists
# http://data.bioontology.org/ontologies/ISO19115PR
#
# Mosquito Gross Anatomy Ontology
# http://data.bioontology.org/ontologies/TGMA
#
# Phallusia fumigata Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/PHFUMIADO
#
# Confidence Information Ontology
# http://data.bioontology.org/ontologies/CIO
#
# Radiation Oncology Ontology
# http://data.bioontology.org/ontologies/ROO
#
# NIH NLM Value Sets
# http://data.bioontology.org/ontologies/NLMVS
#
# Interaction Ontology
# http://data.bioontology.org/ontologies/IXNO
#
# Ontology of Nuclear Toxicity
# http://data.bioontology.org/ontologies/ONTOTOXNUC
#
# Ontology of Amyotrophic Lateral Sclerosis, all modules
# http://data.bioontology.org/ontologies/ONTOPARON
#
# National Drug Data File
# http://data.bioontology.org/ontologies/NDDF
#
# Cell Ontology for Human Lung Maturation
# http://data.bioontology.org/ontologies/LUNGMAP_H_CELL
#
# Influenza Ontology
# http://data.bioontology.org/ontologies/FLU
#
# Metagenome and Microbes Environmental Ontology
# http://data.bioontology.org/ontologies/MEO
#
# International Classification of Diseases, Version 9 - Clinical Modification
# http://data.bioontology.org/ontologies/ICD9CM
#
# Venom Ontology
# http://data.bioontology.org/ontologies/CU-VO
#
# Cerrado concepts and plant community dynamics
# http://data.bioontology.org/ontologies/CCON
#
# Halocynthia roretzi Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/HAROREADO
#
# International Classification for Nursing Practice
# http://data.bioontology.org/ontologies/ICNP
#
# PMO Playing Speed Vocabulary
# http://data.bioontology.org/ontologies/PMO-SPEED
#
# Protein Ontology
# http://data.bioontology.org/ontologies/PR
#
# Scientific Evidence Based Genetic Testing Ontology
# http://data.bioontology.org/ontologies/IGTO
#
# The Ontology for Biomedical Investigation based Inner Ear Electrophysiology
# http://data.bioontology.org/ontologies/OBI_IEE
#
# Ciona savignyi Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/CISAVIADO
#
# IAML Medium of Performance Vocabulary
# http://data.bioontology.org/ontologies/IAML-MOP
#
# BioModels Ontology
# http://data.bioontology.org/ontologies/BIOMODELS
#
# Bone Dysplasia Ontology
# http://data.bioontology.org/ontologies/BDO
#
# G Protein-Coupled Receptor BioAssays Ontology
# http://data.bioontology.org/ontologies/BAO-GPCR
#
# RRB
# http://data.bioontology.org/ontologies/SSC
#
# National Institutes of Health Stroke Scale Ontology
# http://data.bioontology.org/ontologies/NIHSS
#
# Histological Ontology
# http://data.bioontology.org/ontologies/HO
#
# Bioinformatics Web Service Ontology
# http://data.bioontology.org/ontologies/OBIWS
#
# Anatomical Therapeutic Chemical Classification
# http://data.bioontology.org/ontologies/ATC
#
# adverse event repoting system
# http://data.bioontology.org/ontologies/AERS
#
# Ontology of amyotrophic  lateral sclerosis, social module
# http://data.bioontology.org/ontologies/ONTOPARON_SOCIAL
#
# FAST (Faceted Application of Subject Terminology) Event Facet
# http://data.bioontology.org/ontologies/FAST-EVENT-SKOS
#
# OWL-Time
# http://data.bioontology.org/ontologies/TIME
#
# Ontology of RNA Sequencing
# http://data.bioontology.org/ontologies/ORNASEQ
#
# GeoSPARQL
# http://data.bioontology.org/ontologies/GEOSPARQL
#
# Minimal Anatomical Terminology
# http://data.bioontology.org/ontologies/MAT
#
# Minimal Standard Terminology of Digestive Endoscopy, French
# http://data.bioontology.org/ontologies/MSTDE-FRE
#
# Traditional Medicine Constitution Value Set
# http://data.bioontology.org/ontologies/TM-CONST
#
# Physical Medicine and Rehabilitation
# http://data.bioontology.org/ontologies/PMR
#
# Surgical Secondary Events
# http://data.bioontology.org/ontologies/SSE
#
# Chemical Entities of Biological Interest Ontology
# http://data.bioontology.org/ontologies/CHEBI
#
# IDG gene list
# http://data.bioontology.org/ontologies/IDG_GL
#
# FuTRES Ontology of Vertebrate Traits
# http://data.bioontology.org/ontologies/FOVT
#
# Biomedical Topics
# http://data.bioontology.org/ontologies/BMT
#
# Ontology for Biobanking
# http://data.bioontology.org/ontologies/OBIB
#
# GlycoConjugate Ontology
# http://data.bioontology.org/ontologies/GLYCOCOO
#
# ISO 19115 Extent Information
# http://data.bioontology.org/ontologies/ISO19115EX
#
# Genotype Ontology
# http://data.bioontology.org/ontologies/GENO
#
# Ontology for Nutritional Epidemiology
# http://data.bioontology.org/ontologies/ONE
#
# Fungal Gross Anatomy Ontology
# http://data.bioontology.org/ontologies/FAO
#
# Sequence Ontology
# http://data.bioontology.org/ontologies/SEQ
#
# Nanbyo Disease Ontology
# http://data.bioontology.org/ontologies/NANDO
#
# Behaviour Change Technique Taxonomy
# http://data.bioontology.org/ontologies/BCTT
#
# Quantities, Units, Dimensions, and Types Ontology
# http://data.bioontology.org/ontologies/QUDT
#
# Ontology of Core Data Mining Entities
# http://data.bioontology.org/ontologies/ONTODM-CORE
#
# NOMEN - A nomenclatural ontology for biological names
# http://data.bioontology.org/ontologies/NOMEN
#
# RNRMU
# http://data.bioontology.org/ontologies/RNRMU
#
# Ontology of Host-Pathogen Interactions
# http://data.bioontology.org/ontologies/OHPI
#
# Biological Collections Ontology
# http://data.bioontology.org/ontologies/BCO
#
# Measurement Method Ontology
# http://data.bioontology.org/ontologies/MMO
#
# mass spectrometry cross-linking and derivatization reagents
# http://data.bioontology.org/ontologies/XLMOD
#
# Tick Gross Anatomy Ontology
# http://data.bioontology.org/ontologies/TADS
#
# DICOM Controlled Terminology
# http://data.bioontology.org/ontologies/DCM
#
# Anatomic Pathology Lexicon
# http://data.bioontology.org/ontologies/PATHLEX
#
# Xenopus Anatomy Ontology
# http://data.bioontology.org/ontologies/XAO
#
# Guideline Provenance
# http://data.bioontology.org/ontologies/G-PROV
#
# Eagle-I Research Resource Ontology
# http://data.bioontology.org/ontologies/ERO
#
# C. elegans Phenotype Vocabulary
# http://data.bioontology.org/ontologies/WB-PHENOTYPE
#
# Persian Medicine Diseases Ontology
# http://data.bioontology.org/ontologies/PMD
#
# EDAM bioinformatics operations, types of data, data formats, identifiers, and topics
# http://data.bioontology.org/ontologies/EDAM
#
# Gene Expression Ontology
# http://data.bioontology.org/ontologies/GEXO
#
# Computational Neuroscience Ontology
# http://data.bioontology.org/ontologies/CNO
#
# Chronic Kidney Disease Ontology
# http://data.bioontology.org/ontologies/CKDO
#
# Autism Spectrum Disorder Phenotype Ontology
# http://data.bioontology.org/ontologies/ASDPTO
#
# The FoodOn Food Ontology
# http://data.bioontology.org/ontologies/FOODON
#
# Microbial Typing Ontology
# http://data.bioontology.org/ontologies/TYPON
#
# Chemical Information Ontology
# http://data.bioontology.org/ontologies/CHEMINF
#
# Pulmonary Embolism Ontology
# http://data.bioontology.org/ontologies/PE
#
# Digital Forensic
# http://data.bioontology.org/ontologies/SK
#
# General Formal Ontology
# http://data.bioontology.org/ontologies/GFO
#
# Biological Imaging Methods Ontology
# http://data.bioontology.org/ontologies/FBbi
#
# The Oral Health and Disease Ontology
# http://data.bioontology.org/ontologies/OHD
#
# Rat Strain Ontology
# http://data.bioontology.org/ontologies/RS
#
# Human Disease Ontology
# http://data.bioontology.org/ontologies/DOID
#
# Clusters of Orthologous Groups (COG) Analysis Ontology
# http://data.bioontology.org/ontologies/CAO
#
# Human Developmental Anatomy Ontology, timed version
# http://data.bioontology.org/ontologies/EHDA
#
# Ontology of chemically concrete, composable DNA, RNA, and protein residue and crosslinks
# http://data.bioontology.org/ontologies/BPFORMS
#
# HGeneCodonOntology
# http://data.bioontology.org/ontologies/HCODONONT
#
# Simulation Delivery and Documentation Deviations
# http://data.bioontology.org/ontologies/SD3
#
# Congenital Heart Defects Ontology
# http://data.bioontology.org/ontologies/CHD
#
# NGS ontology
# http://data.bioontology.org/ontologies/NGSONTO
#
# Minimal Information about any Sequence (MIxS) Controlled Vocabularies
# http://data.bioontology.org/ontologies/MIXSCV
#
# Pathogen Host Interaction Phenotype Ontology
# http://data.bioontology.org/ontologies/PHIPO
#
# Ontology of Adverse Events
# http://data.bioontology.org/ontologies/OAE
#
# International Classification of Primary Care - 2 PLUS
# http://data.bioontology.org/ontologies/ICPC2P
#
# Radiation Oncology Structures Ontology
# http://data.bioontology.org/ontologies/ROS
#
# EDDA Publication Types Taxonomy
# http://data.bioontology.org/ontologies/EDDA_PT
#
# Dublin Core
# http://data.bioontology.org/ontologies/DC
#
# Reference Sequence Annotation
# http://data.bioontology.org/ontologies/RSA
#
# Neuropsychological Integrative Ontology
# http://data.bioontology.org/ontologies/NIO
#
# PharmGKB Ontology
# http://data.bioontology.org/ontologies/PHARMGKB
#
# Cardiovascular Magnetic Resonance Quality Assessment Ontology
# http://data.bioontology.org/ontologies/CMR-QA
#
# RDL
# http://data.bioontology.org/ontologies/RDL
#
# AdaLab ontology
# http://data.bioontology.org/ontologies/ADALAB
#
# Pharmacogenomic Relationships Ontology
# http://data.bioontology.org/ontologies/PHARE
#
# Educational Cluster
# http://data.bioontology.org/ontologies/APAEDUCLUSTER
#
# ISO 19115 Distribution Information
# http://data.bioontology.org/ontologies/ISO19115DI
#
# XEML Environment Ontology
# http://data.bioontology.org/ontologies/XEO
#
# Robert Hoehndorf Version of MeSH
# http://data.bioontology.org/ontologies/RH-MESH
#
# Patient Generated Health Data
# http://data.bioontology.org/ontologies/PGHD
#
# Tribolium Ontology
# http://data.bioontology.org/ontologies/TRON
#
# COVID-19 Surveillance Ontology
# http://data.bioontology.org/ontologies/COVID19
#
# Functional Therapeutic Chemical Classification System
# http://data.bioontology.org/ontologies/FTC
#
# Cereal Plant Gross Anatomy Ontology
# http://data.bioontology.org/ontologies/GRO-CPGA
#
# Human Genome Organization Gene Symbols
# http://data.bioontology.org/ontologies/HUGO
#
# Amino Acid Ontology
# http://data.bioontology.org/ontologies/AMINO-ACID
#
# EmpowerBP
# http://data.bioontology.org/ontologies/EBP
#
# Solanaceae Phenotype Ontology
# http://data.bioontology.org/ontologies/SPTO
#
# World Health Organization (WHO) Adverse Reaction Terminology
# http://data.bioontology.org/ontologies/WHO-ART
#
# NUBC Hospital Revenue Codes
# http://data.bioontology.org/ontologies/NUBC
#
# Whole-cell modeling ontology
# http://data.bioontology.org/ontologies/WC
#
# DebugIT Core Ontology
# http://data.bioontology.org/ontologies/DCO-DEBUGIT
#
# FAST (Faceted Application of Subject Terminology) Title Facet
# http://data.bioontology.org/ontologies/FAST-TITLE
#
# Bleeding History Phenotype Ontology
# http://data.bioontology.org/ontologies/BHO
#
# Mammalian Phenotype Ontology
# http://data.bioontology.org/ontologies/MP
#
# Mammalian Feeding Muscle Ontology
# http://data.bioontology.org/ontologies/MFMO
#
# Defen
# http://data.bioontology.org/ontologies/MRO
#
# Nurse Administrator
# http://data.bioontology.org/ontologies/ADMIN
#
# CYTOKINE
# http://data.bioontology.org/ontologies/CYTO
#
# CIDOC Conceptual Reference Model
# http://data.bioontology.org/ontologies/CIDOC-CRM
#
# BioPAX Ontology of Biological Pathways
# http://data.bioontology.org/ontologies/BP
#
# Intelligence Task Ontology
# http://data.bioontology.org/ontologies/ITO
#
# Microbial Culture Collection Vocabulary
# http://data.bioontology.org/ontologies/MCCV
#
# National Cancer Institute Thesaurus
# http://data.bioontology.org/ontologies/NCIT
#
# ISO 19115
# http://data.bioontology.org/ontologies/ISO19115
#
# Artificial Intelligence Rheumatology Consultant System Ontology
# http://data.bioontology.org/ontologies/AI-RHEUM
#
# Scientific Evidence and Provenance Information Ontology
# http://data.bioontology.org/ontologies/SEPIO
#
# Nurse Surgical
# http://data.bioontology.org/ontologies/SURGICAL
#
# Master Drug Data Base Clinical Drugs
# http://data.bioontology.org/ontologies/MDDB
#
# Livestock Product Trait Ontology
# http://data.bioontology.org/ontologies/LPT
#
# Environment Ontology for Livestock
# http://data.bioontology.org/ontologies/EOL
#
# OPTImAL: An ontology for patient adherence modeling in physical activity domain
# http://data.bioontology.org/ontologies/OPTIMAL
#
# Coding Symbols for a Thesaurus of Adverse Reaction Terms
# http://data.bioontology.org/ontologies/COSTART
#
# Microbial Conditions Ontology
# http://data.bioontology.org/ontologies/MCO
#
# Asthma Ontology
# http://data.bioontology.org/ontologies/AO
#
# Skin Physiology Ontology
# http://data.bioontology.org/ontologies/SPO
#
# Plant Experimental Assay Ontology
# http://data.bioontology.org/ontologies/PEAO
#
# Microarray and Gene Expression Data Ontology
# http://data.bioontology.org/ontologies/MO
#
# Non-Randomized Controlled Trials Ontology
# http://data.bioontology.org/ontologies/NONRCTO
#
# WHO COVID-19 Rapid Version CRF semantic data model
# http://data.bioontology.org/ontologies/COVIDCRFRAPID
#
# Medical image simulation
# http://data.bioontology.org/ontologies/OntoVIP
#
# The Amphioxus Development and Anatomy Ontology
# http://data.bioontology.org/ontologies/AMPHX
#
# Library of Congress Content Types Scheme
# http://data.bioontology.org/ontologies/LC-CONTENT
#
# Alzheimer's disease ontology
# http://data.bioontology.org/ontologies/ADO
#
# CARRE Risk Factor ontology
# http://data.bioontology.org/ontologies/CARRE
#
# HIVCompoundRels
# http://data.bioontology.org/ontologies/HIVCRS
#
# Regulation of Gene Expression Ontolology
# http://data.bioontology.org/ontologies/REXO
#
# Bone and Cartilage Tissue Engineering Ontology
# http://data.bioontology.org/ontologies/BCTEO
#
# Dengue Fever Ontology
# http://data.bioontology.org/ontologies/IDODEN
#
# Medaka Developmental Stages
# http://data.bioontology.org/ontologies/OLATDV
#
# Logical Observation Identifier Names and Codes
# http://data.bioontology.org/ontologies/LOINC
#
# Ontology for Genetic Disease Investigations
# http://data.bioontology.org/ontologies/OGDI
#
# Drosophila Phenotype Ontology
# http://data.bioontology.org/ontologies/DPO
#
# Ontology of Drug Adverse Events
# http://data.bioontology.org/ontologies/ODAE
#
# Study Cohort Ontology
# http://data.bioontology.org/ontologies/SCO
#
# HUGO Gene Nomenclature
# http://data.bioontology.org/ontologies/HGNC
#
# Pseudogene
# http://data.bioontology.org/ontologies/pseudo
#
# CEDAR Value Sets
# http://data.bioontology.org/ontologies/CEDARVS
#
# NeuroMorpho.Org brain region ontologies
# http://data.bioontology.org/ontologies/NMOBR
#
# Mouse Pathology Ontology
# http://data.bioontology.org/ontologies/MPATH
#
# Human Physiology Simulation Ontology
# http://data.bioontology.org/ontologies/HUPSON
#
# Immunogenetics Ontology
# http://data.bioontology.org/ontologies/IMGT-ONTOLOGY
#
# Ontology of Laboratory Animal Medicine
# http://data.bioontology.org/ontologies/OLAM
#
# Patient ontology
# http://data.bioontology.org/ontologies/PATIENTPERSONAL
#
# Doori
# http://data.bioontology.org/ontologies/DO
#
# Immune Disorder Ontology
# http://data.bioontology.org/ontologies/IMMDIS
#
# Ontology for MicroRNA Target
# http://data.bioontology.org/ontologies/OMIT
#
# vCard Ontology - for describing People and Organizations
# http://data.bioontology.org/ontologies/VCARD
#
# Medical Subject Headings
# http://data.bioontology.org/ontologies/MESH
#
# Diabetes Mellitus Diagnosis Ontology
# http://data.bioontology.org/ontologies/DDO
#
# AdaLab-meta ontology
# http://data.bioontology.org/ontologies/ADALAB-META
#
# Biological Observation Matrix Ontology
# http://data.bioontology.org/ontologies/BIOMO
#
# Ontologized MIABIS
# http://data.bioontology.org/ontologies/OMIABIS
#
# RNA Ontology
# http://data.bioontology.org/ontologies/RNAO
#
# Vaccine Ontology
# http://data.bioontology.org/ontologies/VO
#
# Semantic DICOM Ontology
# http://data.bioontology.org/ontologies/SEDI
#
# MIAPA Ontology
# http://data.bioontology.org/ontologies/MIAPA
#
# Experimental Ontology
# http://data.bioontology.org/ontologies/EXON
#
# Cell Line Ontology
# http://data.bioontology.org/ontologies/CLO
#
# Homelessness and Clinical Data Recording
# http://data.bioontology.org/ontologies/HCDR
#
# Cell Line Ontology [by Mahadevan]
# http://data.bioontology.org/ontologies/MCCL
#
# Ontology of Geographical Region
# http://data.bioontology.org/ontologies/OGR
#
# Zebrafish Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/ZFA
#
# Healthcare Common Procedure Coding System
# http://data.bioontology.org/ontologies/HCPCS
#
# International Classification of Diseases, Version 10 - Clinical Modification
# http://data.bioontology.org/ontologies/ICD10CM
#
# Ontology of Organizational Structures of Trauma centers and Trauma systems
# http://data.bioontology.org/ontologies/OOSTT
#
# Drug Interaction and Evidence Ontology
# http://data.bioontology.org/ontologies/DIDEO
#
# Physico-Chemical Methods and Properties
# http://data.bioontology.org/ontologies/FIX
#
# Drosophila Development Ontology
# http://data.bioontology.org/ontologies/FB-DV
#
# GlycoRDF
# http://data.bioontology.org/ontologies/GLYCORDF
#
# Hymenoptera Anatomy Ontology
# http://data.bioontology.org/ontologies/HAO
#
# International Classification of Diseases, Version 10 - Procedure Coding System
# http://data.bioontology.org/ontologies/ICD10PCS
#
# Binu
# http://data.bioontology.org/ontologies/TESTINGEDB
#
# Plant Structure Development Stage
# http://data.bioontology.org/ontologies/PSDS
#
# Lipid Ontology
# http://data.bioontology.org/ontologies/LIPRO
#
# Placental Genetic Variance
# http://data.bioontology.org/ontologies/PATGV
#
# Clinical Measurement Ontology
# http://data.bioontology.org/ontologies/CMO
#
# Ontology of Vaccine Adverse Events
# http://data.bioontology.org/ontologies/OVAE
#
# Metagenome Sample Vocabulary
# http://data.bioontology.org/ontologies/MSV
#
# alexandre
# http://data.bioontology.org/ontologies/QUITOPLAN
#
# International Classification of Diseases, Version 10
# http://data.bioontology.org/ontologies/ICD10
#
# Library of Congress Media Types Scheme
# http://data.bioontology.org/ontologies/LC-MEDIA
#
# Brain Tumour Ontology
# http://data.bioontology.org/ontologies/BTO_ONTOLOGY
#
# Environment Ontology
# http://data.bioontology.org/ontologies/ENVO
#
# Pregnancy Ontology
# http://data.bioontology.org/ontologies/PREGONTO
#
# RxNORM
# http://data.bioontology.org/ontologies/RXNORM
#
# Computer Retrieval of Information on Scientific Projects Thesaurus
# http://data.bioontology.org/ontologies/CRISP
#
# OBO Metadata Ontology
# http://data.bioontology.org/ontologies/OMO
#
# hydroxtreme7
# http://data.bioontology.org/ontologies/HYDROMAX
#
# ISO 19115 Topic Categories
# http://data.bioontology.org/ontologies/ISO19115TCC
#
# BRENDA Tissue and Enzyme Source Ontology
# http://data.bioontology.org/ontologies/BTO
#
# Clinical smell and taste disorders
# http://data.bioontology.org/ontologies/CSTD
#
# Minimum PDDI Information Ontology
# http://data.bioontology.org/ontologies/MPIO
#
# binu
# http://data.bioontology.org/ontologies/BINUELDB
#
# Patient personal ontology
# http://data.bioontology.org/ontologies/PATIENT2
#
# Gene Regulation Ontology
# http://data.bioontology.org/ontologies/GRO
#
# Toxic Process Ontology
# http://data.bioontology.org/ontologies/TXPO
#
# Modern Science Ontology
# http://data.bioontology.org/ontologies/MODSCI
#
# Halocynthia aurantium Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/HAAURAADO
#
# Ciona intestinalis Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/CIINTEADO
#
# Medical Error Ontology
# http://data.bioontology.org/ontologies/MEDEON
#
# Malaria Ontology
# http://data.bioontology.org/ontologies/IDOMAL
#
# Cell Ontology
# http://data.bioontology.org/ontologies/CL
#
# Teleost Taxonomy Ontology
# http://data.bioontology.org/ontologies/TTO
#
# Holistic Ontology of Rare Diseases
# http://data.bioontology.org/ontologies/HORD
#
# Pediatric Consultation and Monitoring Ontology
# http://data.bioontology.org/ontologies/PCMO
#
# Control y Monitoreo de afecciones en los cultivos
# http://data.bioontology.org/ontologies/AGROCYMAC
#
# CPTAC Proteomics Pipeline Infrastructure Ontology
# http://data.bioontology.org/ontologies/CPTAC
#
# Human Interaction Network Ontology
# http://data.bioontology.org/ontologies/HINO
#
# Taxonomic Rank Vocabulary
# http://data.bioontology.org/ontologies/TAXRANK
#
# Vertebrate Homologous Organ Group Ontology
# http://data.bioontology.org/ontologies/VHOG
#
# Metadata Authority Description Schema in RDF
# http://data.bioontology.org/ontologies/MADS-RDF
#
# Cancer Care: Treatment Outcome Ontology
# http://data.bioontology.org/ontologies/CCTOO
#
# ISO-15926-2_2003_entityMembership
# http://data.bioontology.org/ontologies/ENTITY
#
# deleteme1
# http://data.bioontology.org/ontologies/DELME1
#
# Computer Assisted Brain Injury Rehabilitation Ontology
# http://data.bioontology.org/ontologies/CABRO
#
# Web-Service Interaction Ontology
# http://data.bioontology.org/ontologies/WSIO
#
#  clinical LABoratory Ontology
# http://data.bioontology.org/ontologies/LABO
#
# Disease core ontology applied to Rare Diseases
# http://data.bioontology.org/ontologies/HRDO
#
# Phenotypic Quality Ontology
# http://data.bioontology.org/ontologies/PATO
#
# Norwegian national quality registries- Variabelbibliotek for medisinske kvalitetsregistre
# http://data.bioontology.org/ontologies/NORREG
#
# Common Terminology Criteria for Adverse Events
# http://data.bioontology.org/ontologies/CTCAE
#
# Ascomycete Phenotype Ontology
# http://data.bioontology.org/ontologies/APO
#
# National Center for Biotechnology Information (NCBI) Organismal Classification
# http://data.bioontology.org/ontologies/NCBITAXON
#
# Microbial Phenotype Ontology
# http://data.bioontology.org/ontologies/MPO
#
# Neuroscience Information Framework (NIF) Subcellular Ontology
# http://data.bioontology.org/ontologies/NIFSUBCELL
#
# RDA Mode of Issuance
# http://data.bioontology.org/ontologies/RDA-ISSUANCE
#
# FISH Archaeological Sciences Thesaurus
# http://data.bioontology.org/ontologies/FISH-AST
#
# Health Surveillance Ontology
# http://data.bioontology.org/ontologies/HSO
#
# Funding, Research Administration and Projects Ontology
# http://data.bioontology.org/ontologies/FRAPO
#
# Data harmonization ontology for cross border malaria surveillance
# http://data.bioontology.org/ontologies/IRDG
#
# Brain Region & Cell Type terminology
# http://data.bioontology.org/ontologies/BRCT
#
# Nurse triage
# http://data.bioontology.org/ontologies/TRIAGE
#
# WikiPathways
# http://data.bioontology.org/ontologies/WIKIPATHWAYS
#
# Alzheimer Disease Map Ontology
# http://data.bioontology.org/ontologies/ADMO
#
# MEDRA
# http://data.bioontology.org/ontologies/MEDRA
#
# Inherited Retinal Dystrophies
# http://data.bioontology.org/ontologies/IRD
#
# Minimal Standard Terminology of Digestive Endoscopy
# http://data.bioontology.org/ontologies/MSTDE
#
# SNOMED CT
# http://data.bioontology.org/ontologies/SNOMEDCT
#
# Heart Failure Ontology
# http://data.bioontology.org/ontologies/HFO
#
# Breast Cancer Staging - 7th Edition
# http://data.bioontology.org/ontologies/BCS7
#
# Chemical Process
# http://data.bioontology.org/ontologies/PROCCHEMICAL
#
# Ontology of Datatypes
# http://data.bioontology.org/ontologies/ONTODT
#
# Neuroscience Information Framework (NIF) Standard Ontology
# http://data.bioontology.org/ontologies/NIFSTD
#
# COviD-19 Ontology for Cases and Patient information
# http://data.bioontology.org/ontologies/CODO
#
# Soy Ontology
# http://data.bioontology.org/ontologies/SOY
#
# Ontology of Language Disorder in Autism
# http://data.bioontology.org/ontologies/LDA
#
# Library of Congress Genre/Form Thesaurus for Library and Archival Materials
# http://data.bioontology.org/ontologies/LCGFT
#
# ontoutcomeseith
# http://data.bioontology.org/ontologies/EITHO
#
# Placental Cell Type
# http://data.bioontology.org/ontologies/PATCT
#
# Apollo Structured Vocabulary
# http://data.bioontology.org/ontologies/APOLLO-SV
#
# Neural Motor Recovery Ontology
# http://data.bioontology.org/ontologies/NEUMORE
#
# Human-Aware Science Ontology
# http://data.bioontology.org/ontologies/HASCO
#
# Software Ontology
# http://data.bioontology.org/ontologies/SWO
#
# Ontology of Biological and Clinical Statistics
# http://data.bioontology.org/ontologies/OBCS
#
# Mobile Genetic Element Ontology
# http://data.bioontology.org/ontologies/MEGO
#
# FAST (Faceted Application of Subject Terminology) Topical Facet
# http://data.bioontology.org/ontologies/FAST-TOPICAL
#
# MicroRNA Ontology
# http://data.bioontology.org/ontologies/MIRNAO
#
# Bro_Name
# http://data.bioontology.org/ontologies/BRO_ACRONYM
#
# Fly Taxonomy
# http://data.bioontology.org/ontologies/FB-SP
#
# Radiology Lexicon
# http://data.bioontology.org/ontologies/RADLEX
#
# Image and Data Quality Assessment Ontology
# http://data.bioontology.org/ontologies/IDQA
#
# Dublin Core Collection Description Frequency Vocabulary
# http://data.bioontology.org/ontologies/DCCDFV
#
# Galen Ontology
# http://data.bioontology.org/ontologies/GALEN
#
# Gvanos
# http://data.bioontology.org/ontologies/GVANOS
#
# NHS Quality Indicators
# http://data.bioontology.org/ontologies/NHSQI2009
#
# Ontology of Genes and Genomes
# http://data.bioontology.org/ontologies/OGG
#
# Biomedical Research Integrated Domain Group Model
# http://data.bioontology.org/ontologies/BRIDG
#
# Body System Terms from ICD11
# http://data.bioontology.org/ontologies/ICD11-BODYSYSTEM
#
# test
# http://data.bioontology.org/ontologies/TEST
#
# VIVO Ontology for Researcher Discovery
# http://data.bioontology.org/ontologies/VIVO
#
# Adverse Event Reporting Ontology
# http://data.bioontology.org/ontologies/AERO
#
# CHEBI Integrated Role Ontology
# http://data.bioontology.org/ontologies/CHIRO
#
# Breast Cancer Staging - 8th Edition
# http://data.bioontology.org/ontologies/BCS8
#
# Systems Biology Ontology
# http://data.bioontology.org/ontologies/SBO
#
# Human Developmental Anatomy Ontology, abstract version 1
# http://data.bioontology.org/ontologies/EHDAA
#
# Ciona robusta Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/CIROBUADO
#
# Cell Cycle Ontology
# http://data.bioontology.org/ontologies/CCO
#
# Animal Health Ontology for Livestock
# http://data.bioontology.org/ontologies/AHOL
#
# MFO Mental Disease Ontology
# http://data.bioontology.org/ontologies/MFOMD
#
# Ontology of Liver for Radiology
# http://data.bioontology.org/ontologies/ONLIRA
#
# NLighten Ontology
# http://data.bioontology.org/ontologies/NLN
#
# Gazetteer
# http://data.bioontology.org/ontologies/GAZ
#
# Vertebrate Trait Ontology
# http://data.bioontology.org/ontologies/VT
#
# The Ecosystem Ontology
# http://data.bioontology.org/ontologies/ECSO
#
# Maize Gross Anatomy Ontology
# http://data.bioontology.org/ontologies/ZEA
#
# SMASH Ontology
# http://data.bioontology.org/ontologies/SMASH
#
# Protein-ligand interaction ontology
# http://data.bioontology.org/ontologies/PLIO
#
# Ontology for Genetic Interval
# http://data.bioontology.org/ontologies/OGI
#
# Crop Ontology
# http://data.bioontology.org/ontologies/CO
#
# International Classification of  External Causes of Injuries
# http://data.bioontology.org/ontologies/ICECI
#
# Ontology of Pneumology
# http://data.bioontology.org/ontologies/ONTOPNEUMO
#
# Provenance Ontology
# http://data.bioontology.org/ontologies/PROVO
#
# NIDM-Results
# http://data.bioontology.org/ontologies/NIDM-RESULTS
#
# clinical metadata ontology
# http://data.bioontology.org/ontologies/CDO
#
# Read Codes, Clinical Terms Version 3 (CTV3)
# http://data.bioontology.org/ontologies/RCD
#
# Epigenetic Entity
# http://data.bioontology.org/ontologies/EPIE
#
# Units of Measurement Ontology
# http://data.bioontology.org/ontologies/UO
#
# FlyGlycoDB
# http://data.bioontology.org/ontologies/FLYGLYCODB
#
# MARC List for Languages
# http://data.bioontology.org/ontologies/MARC-LANGUAGES
#
# Parkinson's Disease Ontology
# http://data.bioontology.org/ontologies/PDON
#
# Breast Cancer Grading Ontology
# http://data.bioontology.org/ontologies/BCGO
#
# CranioMaxilloFacial Ontology
# http://data.bioontology.org/ontologies/CMF
#
# Neomark Oral Cancer Ontology, version 3
# http://data.bioontology.org/ontologies/NEOMARK3
#
# OWL_XML_Tool5
# http://data.bioontology.org/ontologies/FDSAJFAHSJK
#
# Classy-Fire
# http://data.bioontology.org/ontologies/CLASSY-FIRE
#
# Autism DSM-ADI-R ontology
# http://data.bioontology.org/ontologies/ADAR
#
# Material
# http://data.bioontology.org/ontologies/MATR
#
# PubMed
# http://data.bioontology.org/ontologies/PM
#
# Brucellosis Ontology
# http://data.bioontology.org/ontologies/IDOBRU
#
# Breast Tissue Cell Lines Ontology
# http://data.bioontology.org/ontologies/MCBCC
#
# Dictyostelium Discoideum Phenotype Ontology
# http://data.bioontology.org/ontologies/DDPHENO
#
# Xenopus Phenotype Ontology
# http://data.bioontology.org/ontologies/XPO
#
# Charlotte
# http://data.bioontology.org/ontologies/GENEVIEVE
#
# Fern Ontology
# http://data.bioontology.org/ontologies/FO
#
# outcomes
# http://data.bioontology.org/ontologies/EIT
#
# HNS_Ontolgoy
# http://data.bioontology.org/ontologies/HNS
#
# Role Ontology
# http://data.bioontology.org/ontologies/ROLEO
#
# Magnetic Resonance Dataset Acquisition Ontology
# http://data.bioontology.org/ontologies/ONL-MR-DA
#
# Dermatology Lexicon
# http://data.bioontology.org/ontologies/DERMLEX
#
# Kidney Tissue Atlas Ontology
# http://data.bioontology.org/ontologies/KTAO
#
# Ontology of Drug Neuropathy Adverse Events
# http://data.bioontology.org/ontologies/ODNAE
#
# InterNano Nanomanufacturing Taxonomy
# http://data.bioontology.org/ontologies/InterNano
#
# Material Organic Compound
# http://data.bioontology.org/ontologies/MOC
#
# Bathmate
# http://data.bioontology.org/ontologies/BIOHYDROMAX
#
# Semantic Types Ontology
# http://data.bioontology.org/ontologies/STY
#
# BioTop Ontology
# http://data.bioontology.org/ontologies/BT
#
# Placental Pathology Lesion Classification
# http://data.bioontology.org/ontologies/PPLC
#
# Ontology of Alternative Medicine, French
# http://data.bioontology.org/ontologies/ONTOMA
#
# FAST (Faceted Application of Subject Terminology) Event
# http://data.bioontology.org/ontologies/FAST-EVENT
#
# ICD-O-3-T International Classification of Diseases for Oncology Topography
# http://data.bioontology.org/ontologies/ICD-O-3-T
#
# The Biblioteko Ontology
# http://data.bioontology.org/ontologies/BIBLIOTEK-O
#
# Mouse Gross Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/EMAP
#
# Cigarette Smoke Exposure Ontology
# http://data.bioontology.org/ontologies/CSEO
#
# Human Health Exposure Analysis Resource
# http://data.bioontology.org/ontologies/HHEAR
#
# Mass Spectrometry Ontology
# http://data.bioontology.org/ontologies/MS
#
# Tunicate GO Slim
# http://data.bioontology.org/ontologies/TUNIGO-SLIM
#
# Stuff Ontology
# http://data.bioontology.org/ontologies/STUFF
#
# Drug Interaction Knowledge Base Ontology
# http://data.bioontology.org/ontologies/DIKB
#
# Sickle Cell Disease Ontology
# http://data.bioontology.org/ontologies/SCDO
#
# Neuroscience Domain Insight Graph
# http://data.bioontology.org/ontologies/NEUDIGS
#
# Performed Music Ontology
# http://data.bioontology.org/ontologies/PMO
#
# Molecular Imaging and Contrast Agent Database
# http://data.bioontology.org/ontologies/MICAD
#
# COPD Ontology
# http://data.bioontology.org/ontologies/COPDO
#
# Ontology of Consumer Health Vocabulary
# http://data.bioontology.org/ontologies/OCHV
#
# Fission Yeast Phenotype Ontology
# http://data.bioontology.org/ontologies/FYPO
#
# Ontology of Host-Microbe Interactions
# http://data.bioontology.org/ontologies/OHMI
#
# Cellular microscopy phenotype ontology
# http://data.bioontology.org/ontologies/CMPO
#
# Enzyme Mechanism Ontology
# http://data.bioontology.org/ontologies/EMO
#
# Consumer Wearable Device
# http://data.bioontology.org/ontologies/CWD
#
# Student Health Record Ontology
# http://data.bioontology.org/ontologies/SHR
#
# Ontology for Newborn Screening Follow-up and Translational Research
# http://data.bioontology.org/ontologies/ONSTR
#
# ...
# Statistics Ontology
# http://data.bioontology.org/ontologies/STATO
#
# Pathway Terminology System
# http://data.bioontology.org/ontologies/PTS
#
# Chemical Methods Ontology
# http://data.bioontology.org/ontologies/CHMO
#
# FAST (Faceted Access of Subject Terminology) GenreForm
# http://data.bioontology.org/ontologies/FAST-GENREFORM
#
# Evidence and Conclusion Ontology
# http://data.bioontology.org/ontologies/ECO
#
# Body in Numbers project terminology
# http://data.bioontology.org/ontologies/BIN
#
# ISO 19115 Common Classes
# http://data.bioontology.org/ontologies/ISO19115CC
#
# Epigenetic Process
# http://data.bioontology.org/ontologies/EPIP
#
# alzhaimer dessiese main factors
# http://data.bioontology.org/ontologies/ADMF
#
# Ethnicity Ontoloy
# http://data.bioontology.org/ontologies/EO
#
# Pathogenic Disease Ontology
# http://data.bioontology.org/ontologies/PDO
#
# CNO_NAME
# http://data.bioontology.org/ontologies/CNO_ACRONYM
#
# eith-outcomes
# http://data.bioontology.org/ontologies/EIT-OUTCOMES
#
# Diagnosis Ontology of Clinical Care Classification
# http://data.bioontology.org/ontologies/DOCCC
#
# Current Procedural Terminology
# http://data.bioontology.org/ontologies/CPT
#
# Dataset processing
# http://data.bioontology.org/ontologies/ONL-DP
#
# APA Tests and Testing cluster
# http://data.bioontology.org/ontologies/APATANDT
#
# Sage Bionetworks Synapse Ontology
# http://data.bioontology.org/ontologies/SYN
#
# Ontology of Chinese Medicine for Rheumatism
# http://data.bioontology.org/ontologies/OCMR
#
# legalapa
# http://data.bioontology.org/ontologies/LEGALAPA
#
# Sample Processing and Separation Techniques Ontology
# http://data.bioontology.org/ontologies/SEP
#
# APA Occupational and Employment cluster
# http://data.bioontology.org/ontologies/APAOCUEMPLOY
#
# Human Developmental Anatomy Ontology, abstract version 2
# http://data.bioontology.org/ontologies/EHDAA2
#
# Anatomical Entity Ontology
# http://data.bioontology.org/ontologies/AEO
#
# Enzyme Reaction Ontology for annotating Partial Information of chemical transformation
# http://data.bioontology.org/ontologies/PIERO
#
# Ontologia de Saúde Mental
# http://data.bioontology.org/ontologies/OSM
#
# Material Rock Igneouus
# http://data.bioontology.org/ontologies/MATRROCKIGNEOUS
#
# Orphanet Rare Disease Ontology
# http://data.bioontology.org/ontologies/ORDO
#
# Orthology Ontology
# http://data.bioontology.org/ontologies/ORTH
#
# Visual Resources Association Core Ontology
# http://data.bioontology.org/ontologies/VRACORE
#
# Regulation of Transcription Ontology
# http://data.bioontology.org/ontologies/RETO
#
# Neuro-degenerative path codes
# http://data.bioontology.org/ontologies/NEURODEGENPATH
#
# Situs Pencari Hotel
# http://data.bioontology.org/ontologies/SPH
#
# jeuxserveurprivé
# http://data.bioontology.org/ontologies/JEUXSERVEURPRIVE
#
# Livestock Breed Ontology
# http://data.bioontology.org/ontologies/LBO
#
# Geographical Entity Ontology
# http://data.bioontology.org/ontologies/GEO
#
# EDAM Bioimaging Ontology
# http://data.bioontology.org/ontologies/EDAM-BIOIMAGING
#
# Collembola Anatomy Ontology
# http://data.bioontology.org/ontologies/COLL
#
# Information Artifact Ontology
# http://data.bioontology.org/ontologies/IAO
#
# Animal Natural History and Life History Ontology
# http://data.bioontology.org/ontologies/ADW
#
# Ontology of Physical Exercises
# http://data.bioontology.org/ontologies/OPE
#
# Kinetic Simulation Algorithm Ontology
# http://data.bioontology.org/ontologies/KISAO
#
# The Drug-Drug Interactions Ontology
# http://data.bioontology.org/ontologies/DINTO
#
# Devices, Experimental scaffolds and Biomaterials Ontology
# http://data.bioontology.org/ontologies/DEB
#
# NanoParticle Ontology
# http://data.bioontology.org/ontologies/NPO
#
# Pharmacovigilance Ontology
# http://data.bioontology.org/ontologies/PVONTO
#
# Human Phenotype Ontology
# http://data.bioontology.org/ontologies/HP
#
# Cerebrotendinous Xanthomatosis Ontology
# http://data.bioontology.org/ontologies/CTX
#
# PLOS Thesaurus
# http://data.bioontology.org/ontologies/PLOSTHES
#
# Name Reaction Ontology
# http://data.bioontology.org/ontologies/RXNO
#
# Spatial Ontology
# http://data.bioontology.org/ontologies/BSPO
#
# An ontology of core ecological entities
# http://data.bioontology.org/ontologies/ECOCORE
#
# Allen Brain Atlas (ABA) Adult Mouse Brain Ontology
# http://data.bioontology.org/ontologies/ABA-AMB
#
# ISO 19115 Reference Systems
# http://data.bioontology.org/ontologies/ISO19115SRS
#
# Mosquito Insecticide Resistance
# http://data.bioontology.org/ontologies/MIRO
#
# Anatomic Ontology for Mouse Lung Maturation
# http://data.bioontology.org/ontologies/LUNGMAP-MOUSE
#
# Ontology for Process-Based Modeling of Dynamical Systems (OntoPBM)
# http://data.bioontology.org/ontologies/ONTOPBM
#
# Bionutrition Ontology
# http://data.bioontology.org/ontologies/BNO
#
# Performance Summary Display Ontology
# http://data.bioontology.org/ontologies/PSDO
#
# Cereal Plant Development Ontology
# http://data.bioontology.org/ontologies/GRO-CPD
#
# Library of Congress Genre/Form Terms (SKOS)
# http://data.bioontology.org/ontologies/LCGFT_SKOS
#
# Traditional Medicine Meridian Value Sets
# http://data.bioontology.org/ontologies/TM-MER
#
# Animal Health Surveillance Ontology
# http://data.bioontology.org/ontologies/AHSO
#
# Wheat Trait Ontology
# http://data.bioontology.org/ontologies/CO-WHEAT
#
# Nursing Interventions Classification
# http://data.bioontology.org/ontologies/NIC
#
# eNanoMapper
# http://data.bioontology.org/ontologies/ENM
#
# OntoFood
# http://data.bioontology.org/ontologies/OF
#
# Cardiovascular Disease Ontology
# http://data.bioontology.org/ontologies/CVDO
#
# Growth Medium Ontology
# http://data.bioontology.org/ontologies/GMO
#
# COMODI
# http://data.bioontology.org/ontologies/COMODI
#
# PRIDE Controlled Vocabulary
# http://data.bioontology.org/ontologies/PRIDE
#
# ISO 19115 Identification Information
# http://data.bioontology.org/ontologies/ISO19115ID
#
# RRB Group D
# http://data.bioontology.org/ontologies/RGD
#
# Fish Ontology
# http://data.bioontology.org/ontologies/FISHO
#
# Integrative and Conjugative Element Ontology
# http://data.bioontology.org/ontologies/ICEO
#
# Diagnostic Ontology
# http://data.bioontology.org/ontologies/DIAGONT
#
# Orthologous Group Ontology
# http://data.bioontology.org/ontologies/OGROUP
#
# Semantic Web for Earth and Environment Technology Ontology
# http://data.bioontology.org/ontologies/SWEET
#
# Adherence and Integrated Care in Spanish
# http://data.bioontology.org/ontologies/ADHER_INTCARE_SP
#
# Single-Nucleotide Polymorphism (SNP) Ontology
# http://data.bioontology.org/ontologies/SNPO
#
# Epoch Clinical Trial Ontology
# http://data.bioontology.org/ontologies/CTONT
#
# Plant Phenology Ontology
# http://data.bioontology.org/ontologies/PPO
#
# Animal Trait Ontology for Livestock
# http://data.bioontology.org/ontologies/ATOL
#
# Porifera Ontology
# http://data.bioontology.org/ontologies/PORO
#
# Foundational Model of Anatomy
# http://data.bioontology.org/ontologies/FMA
#
# Symptom Ontology
# http://data.bioontology.org/ontologies/SYMP
#
# Cell Behavior Ontology
# http://data.bioontology.org/ontologies/CBO
#
# NeuroMorpho.Org species ontology
# http://data.bioontology.org/ontologies/NMOSP
#
# Library of Congress Carriers Scheme
# http://data.bioontology.org/ontologies/LC-CARRIERS
#
# FamPlex
# http://data.bioontology.org/ontologies/FPLX
#
# Terminology for the Description of Dynamics
# http://data.bioontology.org/ontologies/TEDDY
#
# LC BIBFRAME 2.0 Vocabulary Extension
# http://data.bioontology.org/ontologies/BFLC
#
# mini fast test
# http://data.bioontology.org/ontologies/MINI-FAST-1
#
# Brain-Computer Interaction (BCI) Ontology
# http://data.bioontology.org/ontologies/BCI-O
#
# Exposure Ontology
# http://data.bioontology.org/ontologies/EXO
#
# Early Pregnancy Ontology
# http://data.bioontology.org/ontologies/EPO
#
# Content Archive Resource Exchange Lexicon
# http://data.bioontology.org/ontologies/CARELEX
#
# Host Pathogen Interactions Ontology
# http://data.bioontology.org/ontologies/HPIO
#
# BioAssay Ontology
# http://data.bioontology.org/ontologies/BAO
#
# Mouse Adult Gross Anatomy Ontology
# http://data.bioontology.org/ontologies/MA
#
# Molecular Interaction Map
# http://data.bioontology.org/ontologies/MIM
#
# Research Network and Patient Registry Inventory Ontology
# http://data.bioontology.org/ontologies/RNPRIO
#
# Computer-Based Patient Record Ontology
# http://data.bioontology.org/ontologies/CPRO
#
# Human Ancestry Ontology
# http://data.bioontology.org/ontologies/HANCESTRO
#
# go-plus
# http://data.bioontology.org/ontologies/GO-PLUS
#
# International Classification for Patient Safety
# http://data.bioontology.org/ontologies/ICPS
#
# suicideonto
# http://data.bioontology.org/ontologies/suicideo
#
# Neuroscience Information Framework (NIF) Cell Ontology
# http://data.bioontology.org/ontologies/NIFCELL
#
# Pipeline Patterns Ontology
# http://data.bioontology.org/ontologies/PP
#
# Graphical Pathway Markup Language
# http://data.bioontology.org/ontologies/GPML
#
# Systems Chemical Biology and Chemogenomics Ontology
# http://data.bioontology.org/ontologies/CHEMBIO
#
# Molgula oculata Anatomy and Development Ontology
# http://data.bioontology.org/ontologies/MOOCULADO
#
# An ontology for experimental actions
# http://data.bioontology.org/ontologies/EXACT
#
# Spinal Cord Injury Ontology
# http://data.bioontology.org/ontologies/SCIO
#
# Antibiotic Resistance Ontology
# http://data.bioontology.org/ontologies/ARO
#
# Proteasix Ontology
# http://data.bioontology.org/ontologies/PXO
#
# Clytia hemisphaerica Development and Anatomy Ontology
# http://data.bioontology.org/ontologies/CLYH
#
# Teleost Anatomy Ontology
# http://data.bioontology.org/ontologies/TAO
#
# Coronavirus Infectious Disease Ontology
# http://data.bioontology.org/ontologies/CIDO
#
# International Classification of Wellness
# http://data.bioontology.org/ontologies/ICW
#
# Vertebrate Skeletal Anatomy Ontology
# http://data.bioontology.org/ontologies/VSAO
#
# Placental Maternal Health Conditions
# http://data.bioontology.org/ontologies/PATMHC
#
# Beta Cell Genomics Ontology
# http://data.bioontology.org/ontologies/OBI_BCGO
#
# CRediT
# http://data.bioontology.org/ontologies/CREDIT
#
# SMART Protocols
# http://data.bioontology.org/ontologies/SP
#
# Electronic Care Plan
# http://data.bioontology.org/ontologies/ECP
#
# ISO-15926-2_2003_inverseRoles
# http://data.bioontology.org/ontologies/INVERSEROLES
#
# Clinical Study Ontology
# http://data.bioontology.org/ontologies/CSO
#
# Zebrafish Experimental Conditions Ontology
# http://data.bioontology.org/ontologies/ZECO
#
# C. elegans Development Vocabulary
# http://data.bioontology.org/ontologies/WB-LS
#
# Library of Congress Demographic Group Terms
# http://data.bioontology.org/ontologies/LCDGT
#
# ISO-15926-2_2003_oil
# http://data.bioontology.org/ontologies/ISO-15926-2_2003
#
# REPRODUCE-ME
# http://data.bioontology.org/ontologies/REPRODUCE-ME
#
# Epilepsy Syndrome Seizure Ontology
# http://data.bioontology.org/ontologies/ESSO
#
# DCMI Terms
# http://data.bioontology.org/ontologies/DCMI
#
# Dispedia Core Ontology
# http://data.bioontology.org/ontologies/DCO
#
# Proteomics Data and Process Provenance Ontology
# http://data.bioontology.org/ontologies/PROPREO
#
# Population and Community Ontology
# http://data.bioontology.org/ontologies/PCO
#
# Adverse Event by System Organ Class
# http://data.bioontology.org/ontologies/AESOC
#
# Data Science Education Ontology
# http://data.bioontology.org/ontologies/DSEO
#
# Suggested Ontology for Pharmacogenomics
# http://data.bioontology.org/ontologies/SOPHARM
#
# MedlinePlus Health Topics
# http://data.bioontology.org/ontologies/MEDLINEPLUS
#
# Ontology of Homology and Related Concepts in Biology
# http://data.bioontology.org/ontologies/HOM
#
# National Drug File - Reference Terminology
# http://data.bioontology.org/ontologies/NDFRT
#
# Clinical Trials Ontology
# http://data.bioontology.org/ontologies/CTO
#
# Ontology of Experimental Variables and Values
# http://data.bioontology.org/ontologies/OOEVV
#
# gregr
# http://data.bioontology.org/ontologies/GREG
#
# Neurodegenerative Disease Data Ontology
# http://data.bioontology.org/ontologies/NDDO
#
# Nursing Care Coordination Ontology
# http://data.bioontology.org/ontologies/NCCO
#
# PAV Provenance, Authoring and Versioning
# http://data.bioontology.org/ontologies/PAV
#
# Enzyme Structure Function Ontology
# http://data.bioontology.org/ontologies/ESFO
#
# RBMS Controlled Vocabularies
# http://data.bioontology.org/ontologies/RBMS
#
# Phylogenetic Ontology
# http://data.bioontology.org/ontologies/PHYLONT
#
# Gene Ontology Extension
# http://data.bioontology.org/ontologies/GO-EXT
#
# Medical Technology Innovation in healthcare centers
# http://data.bioontology.org/ontologies/ITEMAS
#
# Quantitative Imaging Biomarker Ontology
# http://data.bioontology.org/ontologies/QIBO
#
# Sequence Types and Features Ontology
# http://data.bioontology.org/ontologies/SO
#
# Ontology for Biomedical Investigations
# http://data.bioontology.org/ontologies/OBI
#
# Mouse Developmental Stages
# http://data.bioontology.org/ontologies/MMUSDV
#
# Genome Component Ontology
# http://data.bioontology.org/ontologies/GCO
#
# APA Neuro Cluster
# http://data.bioontology.org/ontologies/APANEUROCLUSTER
#
# Vaccine Investigation Ontology
# http://data.bioontology.org/ontologies/VIO
#
# Ontology for Nutritional Studies
# http://data.bioontology.org/ontologies/ONS
#
# Ontology of Microbial Phenotypes
# http://data.bioontology.org/ontologies/OMP
#
# Physician Data Query
# http://data.bioontology.org/ontologies/PDQ
#
# Drosophila Gross Anatomy Ontology
# http://data.bioontology.org/ontologies/FB-BT
#
# Fanconi Anemia Ontology
# http://data.bioontology.org/ontologies/IFAR
#
# Gene Ontology
# http://data.bioontology.org/ontologies/GO
#
# COVID-19 Ontology
# http://data.bioontology.org/ontologies/COVID-19
#
# Basic Formal Ontology
# http://data.bioontology.org/ontologies/BFO
#
# Major Histocompatibility Complex Ontology
# http://data.bioontology.org/ontologies/MHC
#
# The RDF Schema vocabulary
# http://data.bioontology.org/ontologies/RDFS
#
# BioLink Model
# http://data.bioontology.org/ontologies/BLM
#
# Dependency Layered Ontology for Radiation Oncology
# http://data.bioontology.org/ontologies/DLORO
#
# Plant Diversity Ontology
# http://data.bioontology.org/ontologies/PDO_CAS
#
# The Drug Ontology
# http://data.bioontology.org/ontologies/DRON
#
# The Stroke Ontology
# http://data.bioontology.org/ontologies/STO-DRAFT
#
# ISO 19108 Temporal Objects
# http://data.bioontology.org/ontologies/ISO19108TO
#
# Human Developmental Stages Ontology
# http://data.bioontology.org/ontologies/HSAPDV
#
# Mental State Assessment
# http://data.bioontology.org/ontologies/ONL-MSA
#
# Neuropath Diagnoses Hierarchy
# http://data.bioontology.org/ontologies/NDH
#
# VIVO-Integrated Semantic Framework
# http://data.bioontology.org/ontologies/VIVO-ISF
#
# Biodiversity Ontology
# http://data.bioontology.org/ontologies/BOF
#
# Sleep Domain Ontology
# http://data.bioontology.org/ontologies/SDO
#
# Natural Products Ontology
# http://data.bioontology.org/ontologies/NATPRO
#
# International Classification of Primary Care
# http://data.bioontology.org/ontologies/ICPC
#
# Neuro Behavior Ontology
# http://data.bioontology.org/ontologies/NBO
#
# RDA Content type
# http://data.bioontology.org/ontologies/RDA-CONTENT
#
# Gender, Sex, and Sexual Orientation Ontology
# http://data.bioontology.org/ontologies/GSSO
#
# Pediatric Terminology
# http://data.bioontology.org/ontologies/PEDTERM
#
# Allergy Detector II
# http://data.bioontology.org/ontologies/ALLERGYDETECTOR
#
# insectH
# http://data.bioontology.org/ontologies/INSECTH
#
# Dictyostelium Discoideum Anatomy Ontology
# http://data.bioontology.org/ontologies/DDANAT
#
# Just Enough Results Model Ontology
# http://data.bioontology.org/ontologies/JERM
#
# Plant Experimental Conditions Ontology
# http://data.bioontology.org/ontologies/PECO
#
# Prostate Cancer Ontology
# http://data.bioontology.org/ontologies/PCAO
#
# Ontology of Cardiovascular Drug Adverse Events
# http://data.bioontology.org/ontologies/OCVDAE
#
# Human Dermatological Disease Ontology
# http://data.bioontology.org/ontologies/DERMO
#
# NCCN EHR Oncology Categories
# http://data.bioontology.org/ontologies/NCCNEHR
#
# PhenX Phenotypic Terms
# http://data.bioontology.org/ontologies/PHENX
#
# Systematized Nomenclature of Medicine, International Version
# http://data.bioontology.org/ontologies/SNMI
#
# ISO 19115 Date Type Code
# http://data.bioontology.org/ontologies/ISO19115DTC
#
# Electrocardiography Ontology
# http://data.bioontology.org/ontologies/ECG
#
# Plant Ontology
# http://data.bioontology.org/ontologies/PO
#
# Mondo Disease Ontology
# http://data.bioontology.org/ontologies/MONDO
#
# Cephalopod Ontology
# http://data.bioontology.org/ontologies/CEPH
#
# Hypertension Ontology
# http://data.bioontology.org/ontologies/HTN
