# %%
#imports

datadir='/dls/i16/data/2018/cm19668-4/'
cifpath='/home/spc93/spc_cifs/'

import sys
sys.path
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
sys.path.append('/dls_sw/i16/software/python/crystal')

# %matplotlib nbagg
from matplotlib.pyplot import *
from numpy import *
from dlstools import dataloader
d=dataloader.dlsloader(datadir+'%i.dat')
p=dataloader.tiffloader(d, lambda obj: datadir+obj.pilatus2m_path_template)

import TensorScatteringClass as ten
import Crystal as Cr
# Out:
# === Importing dlstools package
# /dls_sw/apps/scisoftpy/2.7/scisoftpy/_external/tifffile.py:284: UserWarning: ImportError: No module named '_tifffile'. Loading of some compressed images will be very slow. Tifffile.c can be obtained at http://www.lfd.uci.edu/~gohlke/
#   "ImportError: No module named '_tifffile'. "
# Could not import plotting routines
# No module named py4j.java_gateway
# === Need to obtain specfilewrapper.py and compatible specfile.so from ERSF PyMCA package in order to load spec files

# %% [raw]
# Activities
# (Reflection list calculatiopn doesn't work!)
#
# Find 0012 Bragg peak and refine UB matrix
# Find 009 Magnetic peak ... very weak!
# Magrot scan
# Temperature dependence
#
# Optional
# Polarization analysis: 006, 009
# Resonance: E2E2 T>TN

# %%
ciffile=cifpath+'CoCO3_icsd_61066.cif'


#mc = Cr.Crystal()
#mc.load_cif(ciffile)
#refs=mc.reflection_list(7.11)

t=ten.TensorScatteringClassMagrotExtension(CIFfile=ciffile, Site='Co1');
t.PlotIntensityInPolarizationChannelsVsMagrot('NonResmag', lam=12.4/7, hkl=np.array([0,0,9]), hkln=np.array([1,0,0]), psideg=0, lk=np.array([0,0,0]), sk=np.array([1,0,0]), sigmapi='sigma')
#t.PlotIntensityInPolarizationChannelsVsMagrot('E1E1mag', lam=12.4/7, hkl=np.array([0,0,9]), hkln=np.array([1,0,0]), psideg=0, mk=np.array([1,0,0]), sigmapi='sigma')
#t.PlotIntensityInPolarizationChannels('E2E2', lam=1, hkl=np.array([0,0,9]), hkln=np.array([1,0,0]), K=4, Time=1, Parity=1, sigmapi='sigma')
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/CoCO3_icsd_61066.cif
#                      Lattice:  4.662 4.662 14.963 90.00 90.00 120.00
#                    All sites:  Co1, C1, O1
#                Site selected:  Co1
#                  Site vector:  0.000 0.000 0.000
#        No. of spacegroup ops:  36
#       No. of sym ops at site:  6
#  No. of equiv. sites in cell:  6
#    No. of pg ops for crystal:  12
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
figure(); 
for scan in range(711968, 711979+1):
    d(scan)
    temp=d.Ta * np.ones(d.eta.shape)
    gca(projection='3d').plot(d.eta, temp, d.vscroi_maxval)
title('Atten=20')


figure(); 
for scan in range(711987, 711996+1):
    d(scan)
    temp=d.Ta * np.ones(d.eta.shape)
    gca(projection='3d').plot(d.eta, temp, d.vscroi_maxval)
title('Atten=20')
#disproportionately higher background!
#sharp peak relatively weak - harmonic peak?
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">
# <img src="data:image/png;base64,..." width="639.8333333333334">
# Text(0.5,0.92,u'Atten=20')

# %%
d.plot('eta','roi1_maxval')
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
figure();
d(712177); plot(d.eta, d.roi2_sum)
d(712178); plot(d.eta, d.roi2_sum/4)
# Out:
# <img src="data:image/png;base64,..." width="639.8333333333334">

# %%
#t.PlotIntensityInPolarizationChannels?
t.PlotIntensityInPolarizationChannels('NonResmag', 12.4/5.22, array([0,0,9]), array([1,0,0]), psideg=0, K=None, Time=None, Parity=None, mk=None, lk=array([.1,0,0]), sk=array([1,0,0]), sigmapi='sigma', savefile=None)
# Out:
# <div id='1e17a621-aaa9-4d95-b492-20eb65e24d63'></div>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-c67c0883ee0f> in <module>()
#       1 #t.PlotIntensityInPolarizationChannels?
# ----> 2 t.PlotIntensityInPolarizationChannels('NonResmag', 12.4/5.22, array([0,0,9]), array([1,0,0]), psideg=0, K=None, Time=None, Parity=None, mk=None, lk=array([.1,0,0]), sk=array([1,0,0]), sigmapi='sigma', savefile=None)
#
# /dls_sw/i16/software/python/userscripts/steve/TensorScatteringClass.pyc in PlotIntensityInPolarizationChannels(self, process, lam, hkl, hkln, psideg, K, Time, Parity, mk, lk, sk, sigmapi, savefile)
#     685         plt.plot(psideg, Ixp, 'b',label='$'+polchar+'\pi$',linewidth=2.0);
#     686         plt.legend(loc='best'); plt.ylabel('Intensity (aribtrary units)'); plt.axis('tight'); plt.xlabel('$\psi$ (degrees)'); plt.title(titlestr); plt.grid(1)
# ...

# %%
array
# Out:
# <function numpy.core.multiarray.array>
