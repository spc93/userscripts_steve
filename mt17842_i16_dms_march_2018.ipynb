# %%
datadir='/dls/i16/data/2018/mt17842-1/'

import sys
sys.path
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
# %matplotlib nbagg
from matplotlib.pyplot import *
from numpy import *
from dlstools.dataloader import vec2mat
from dlstools.quickfit import *
from dlstools.dirty_fit import fit

from dlstools import dataloader
d=dataloader.dlsloader(datadir+'%i.dat')
p=dataloader.tiffloader(d, lambda obj: datadir+obj.pilatus2m_path_template)
# Out:
# === Importing dlstools package
# /dls_sw/apps/scisoftpy/2.7/scisoftpy/_external/tifffile.py:284: UserWarning: ImportError: No module named '_tifffile'. Loading of some compressed images will be very slow. Tifffile.c can be obtained at http://www.lfd.uci.edu/~gohlke/
#   "ImportError: No module named '_tifffile'. "
# === Need to obtain specfilewrapper.py and compatible specfile.so from ERSF PyMCA package in order to load spec files

# %%
d(678179); d.plot('energy2','ic1monitor')
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">

# %%
figure(); subplot(1,2,1);
d(678181); d.plot('base_y','diode', hold=1)
d(678182); d.plot('base_y','diode', hold=1)
subplot(1,2,2);
d(678183); d.plot('Base_z','diode', hold=1)
d(678184); d.plot('Base_z','diode', hold=1)
# Out:
# <img src="data:image/png;base64,..." width="757.0999766845512">

# %%
d
# Out:
# #678183  Base_z Base_z1 Base_z2 Base_z3 Time diode kphi kap kth kmu kdelta kgam delta_axis_offset TimeSec ic1monitor rc metadata

# %%
d(678269); 
subplot(1,2,1); p(1); imshow(p.image_01,clim=(30,200)); title('#%i two energies' % d.SRSRUN)
subplot(1,2,2); p(2); imshow(p.image_01,clim=(30,200)); title('#%i' % d.SRSRUN)
p(1); p1=p.image_01; p(2); p2=p.image_01;
figure(); imshow((p1-p2),clim=(-100,100)); title('#%i' % d.SRSRUN)
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">
# <img src="data:image/png;base64,..." width="639.8499802953507">
# Text(0.5,1,u'#678269')

# %%
d(678284)
p(1); figure(); imshow(p.image_01,clim=(300,1000)); title('#%i' % d.SRSRUN)
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">
# Text(0.5,1,u'#678284')

# %%
d(678299)
subplot(1,2,1); p(1); imshow(p.image_01,clim=(750,3000)); title('#%i' % d.SRSRUN)
subplot(1,2,2); p(2); imshow(p.image_01,clim=(750,3000)); title('#%i' % d.SRSRUN)
p(1); p1=p.image_01; p(2); p2=p.image_01;
figure(); imshow((p1-p2),clim=(-200,200)); title('#%i difference' % d.SRSRUN)
# Out:
# <img src="data:image/png;base64,..." width="901.1499722484259">
# <img src="data:image/png;base64,..." width="639.8499802953507">
# Text(0.5,1,u'#678299 difference')

# %%
d(678351); d.plot('eta','sum', hold=1)
d(678401); d.plot('eta',d.sum/2, hold=1)
# Out:
# <img src="data:image/png;base64,..." width="468.9999855568016">

# %%
d(678405); d.plot('energy2',d.sum/d.ic1monitor); title('Mn K-edge fluo')
# Out:
# <img src="data:image/png;base64,..." width="494.6833180991979">
# Text(0.5,1,u'Mn K-edge fluo')

# %%
d(678284)
# Out:
# #678284  psic h k l beamOK kphi kap kth kmu kdelta kgam delta_axis_offset TimeSec ic1monitor rc count_time path maxx maxy maxval sum metadata

# %%
d.cmd
# Out:
# 'scan psic 180 0 5 hkl [5.599999999999999, 0, 0] BeamOK pil2ms 120'

# %%
d.gam
# Out:
# 107.8825

# %%
d(678269)
# Out:
# #678269  energy2 Uenergy DCMenergy kphi kap kth kmu kdelta kgam delta_axis_offset TimeSec ic1monitor rc count_time path maxx maxy maxval sum metadata

# %%
c.cmd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-5dc96975f454> in <module>()
# ----> 1 c.cmd
#
# NameError: name 'c' is not defined

# %%
d.cmd
# Out:
# 'scan energy 7.89 7.9 0.01 pil2ms 120'

# %%
d.h
# Out:
# 6.2079

# %%
h.k
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e79bcaa65ae0> in <module>()
# ----> 1 h.k
#
# NameError: name 'h' is not defined

# %%
d.h
# Out:
# 6.2079

# %%
d.k
# Out:
# 0.0

# %%
d.l
# Out:
# 0.0

# %%
d(678284)
# Out:
# #678284  psic h k l beamOK kphi kap kth kmu kdelta kgam delta_axis_offset TimeSec ic1monitor rc count_time path maxx maxy maxval sum metadata

# %%
d.h
# Out:
# array([ 5.6,  5.6,  5.6, ...,  5.6,  5.6,  5.6])

# %%
d.k
# Out:
# array([ 0.,  0.,  0., ..., -0., -0., -0.])

# %%
d.l
# Out:
# array([ 0.,  0.,  0., ...,  0.,  0., -0.])

# %%
d(678284)
p(1); figure(); imshow(p.image_01,clim=(300,1000)); title('#%i' % d.SRSRUN)
# Out:
# <img src="data:image/png;base64,..." width="921.2499716294317">
# Text(0.5,1,u'#678284')

# %%
d.azih, d.azik, d.azil
# Out:
# (0, -1, 0)

# %%
d(678417)
# Out:
# #678417  eta kphi kap kth kmu kdelta kgam delta_axis_offset TimeSec ic1monitor rc count_time path maxx maxy maxval sum roi2_maxx roi2_maxy roi2_maxval roi2_sum metadata

# %%
d.phi, d.chi, d.eta, d.delta
# Out:
# (-41.0,
#  17.94442,
#  array([ 22.4892,  22.4992,  22.5092, ...,  22.8292,  22.8392,  22.8492]),
#  44.97835)

# %%
d.plot('eta','sum')
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">

# %%
d.en
# Out:
# 6.6

# %%
d(678423)
# Out:
# #678423  eta kphi kap kth kmu kdelta kgam delta_axis_offset TimeSec ic1monitor rc count_time path maxx maxy maxval sum metadata

# %%
d.cmd
# Out:
# 'scancn eta 0.1 21 pil100ks 0.5'

# %%
d(678377)
# Out:
# #678377  x kphi kap kth kmu kdelta kgam delta_axis_offset TimeSec ic1monitor rc count_time path maxx maxy maxval sum metadata

# %%
d.h, d.k, d.l
#d.a
# Out:
# (0.3569, -2.0875, 3.3758)

# %%
d.psi
# Out:
# -179.25

# %%
d.delta
# Out:
# 0.0

# %%
d(678450)
# Out:
# #678450  eta kphi kap kth kmu kdelta kgam delta_axis_offset TimeSec ic1monitor rc count_time path maxx maxy maxval sum metadata

# %%
d.cmd
# Out:
# 'scancn eta 0.05 201 pil100ks 0.5'
