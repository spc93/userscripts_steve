# %% [markdown]
# # Test latest lmfit with new quickfit
# https://lmfit.github.io/lmfit-py/model.html

# %%
import numpy as np
from matplotlib.pyplot import *
from lmfit import Model
# %matplotlib notebook

# %%
def gaussian(x, amp, cen, wid):
   return amp * np.exp(-(x-cen)**2 / wid)

def poly2(x, p0, p1, p2):
    return p0 + p1*x + p2*x**2

# %%
#gmodel = Model(gaussian) + Model(poly2)  #bad fit!
gmodel = Model(gaussian)

# %%
gmodel.param_names
# Out:
# ['amp', 'cen', 'wid']

# %%
gmodel.independent_vars
# Out:
# ['x']

# %%
params = gmodel.make_params()

# %%
xdat = np.arange(-1,1,.01)
gdat = gaussian(xdat, 1, 0, .1)

# %%
# %matplotlib notebook
figure()
plot(xdat, gdat); grid(1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
from dlstools.pdnx import *
from matplotlib.pyplot import *
from dlstools.quickfit import *
# %matplotlib notebook 
p='/dls/i16/data/2019/mm22314-1/%i.nxs'
datadir='/dls/i16/data/2019/mm22314-1/'
# Out:
# === Importing dlstools package

# %%
fit(pv_c)
# Out:
# (Model(pvoigt) + Model(const))
#
#       area:    0.56049912053 +/- 0.00000000012
#        cen:   -0.00000000072 +/- 0.00000000008
#       fwhm:    0.52655376956 +/- 0.00000000012
#      lfrac:   -0.00000000281 +/- 0.00000000009
#          c:    0.00000000030 +/- 0.00000000009

# %%
n=pdnx(p % 759623)
n
# Out:
#      count_time   kthZebra  maxval   maxx   maxy   path  roi1_maxval  roi1_maxx  roi1_maxy  roi1_sum  roi2_maxval  roi2_maxx  roi2_maxy  roi2_sum        sum  wcroi_maxval  wcroi_maxx  wcroi_maxy  wcroi_sum
# 0           0.1  94.698573   214.0  280.0  110.0    0.0        132.0        5.0        6.0   17289.0        137.0       37.0        0.0  206691.0  8778218.0         137.0        18.0         4.0   253589.0
# 1           0.1  94.699803   213.0  280.0  110.0    1.0        138.0        4.0       12.0   16982.0        167.0       45.0       29.0  205904.0  8766416.0         150.0        27.0        25.0   252104.0
# 2           0.1  94.700783   197.0  431.0  194.0    2.0        133.0        4.0       12.0   17207.0        143.0       45.0       29.0  206415.0  8761042.0         136.0        15.0        86.0   252623.0
# 3           0.1  94.701904   209.0  427.0  193.0    3.0        126.0        9.0        9.0   17236.0        153.0       27.0        9.0  206320.0  8767800.0         153.0        17.0        34.0   252553.0
# ..          ...        ...     ...    ...    ...    ...          ...        ...        ...       ...          ...        ...        ...       ...        ...           ...         ...         ...        ...
# 97          0.1  94.795889   201.0  477.0  194.0   97.0        128.0        9.0        9.0   17372.0        144.0       45.0       29.0  204926.0  8756174.0         142.0        14.0         4.0   252875.0
# 98          0.1  94.797163   199.0  431.0  194.0   98.0        124.0        9.0        9.0   17320.0        140.0       44.0       20.0  206092.0  8754505.0         138.0        28.0        93.0   252933.0
# 99          0.1  94.798050   222.0  280.0  110.0   99.0        128.0        7.0       11.0   17322.0        146.0       45.0       29.0  206171.0  8761296.0         140.0        18.0         4.0   253153.0
# 100         0.1  94.799012   198.0  280.0  110.0  100.0        125.0       12.0        9.0   17416.0        155.0       45.0       29.0  206264.0  8778487.0         131.0         3.0        90.0   252554.0
#
# [101 rows x 19 columns]

# %%
#seem to keep having to execute this statement.
# %matplotlib notebook

# %%
n.plot('kthZebra', 'wcroi_sum')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#click on plot to do fit
fit(g_lin)
# Out:
# (Model(gauss) + Model(poly2))
#
#       area:               98 +/- 3
#        cen:         94.73812 +/- 0.00014
#       fwhm:           0.0097 +/- 0.0004
#          m:              751 +/- 2226
#          c:           181501 +/- 210891
# /dls_sw/i16/software/python/dlstools/quickfit.py:34: RuntimeWarning: invalid value encountered in sqrt
#   fwhm_sd = np.sqrt(sum((x - centre)**2*y)/sumdat) * np.sqrt(8*np.log(2))
