# %%
#%run TensorScatteringClass

# %% [markdown]
# # Forbidden reflections in Rb2ZnCl4 high-T (Pmcm) and lock-in ('3c') phase using Marc's CIF files
#
# ## Summary
#
# ### High-temp phase:
#
# 700: Spacegroup forbidden; E1E1 forbidden; E1E2 allowed
#
# ### Lock-in phase
#
# 700: Spacegroup forbidden; E1E1 allowed
#
# 701: Spacegroup forbidden; E1E1 allowed
#
# 702: Spacegroup allowed; E1E1 allowed
#
# 703: Spacegroup forbidden; E1E1 allowed

# %%
#High temperature phase Pmcn 
t=ten.TensorScatteringClass(CIFfile='/home/spc93/spc_cifs/Rb2ZnCl4_Pmcn.cif', Site='Zn1');
t.PlotIntensityInPolarizationChannels('E1E1', lam=12.4/9.659, hkl=np.array([7,0,0]), hkln=np.array([0,0,1]), K=2, Time=1, Parity=1, sigmapi='sigma')
t.PlotIntensityInPolarizationChannels('E1E2', lam=12.4/9.659, hkl=np.array([7,0,0]), hkln=np.array([0,0,1]), K=3, Time=1, Parity=-1, sigmapi='sigma')
t.print_tensors()
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/Rb2ZnCl4_Pmcn.cif
#                      Lattice:  7.278 12.736 9.233 90.00 90.00 90.00
#                    All sites:  Cl1, Cl3, Cl2, Cl4, Rb2, Zn1, Rb1
#                Site selected:  Zn1
#                  Site vector:  0.250 0.422 0.275
#        No. of spacegroup ops:  8
#       No. of sym ops at site:  2
#  No. of equiv. sites in cell:  4
#    No. of pg ops for crystal:  8
#
# Tensor properties
#
#              Required parity:  Even
#           Required time sym.:  Even
#                          hkl:  [7.0, 0.0, 0.0]
#                 Site allowed:  No
#    Structure factor for site:  -0.00+0.00i
#           Spacegroup allowed:  No
#               Tensor allowed:  Yes
#                       Parity:  Either
#                         Time:  Either
#                           PT:  Either
#               Glide or screw:  True
# Tensor properties
#
#              Required parity:  Odd
# ...

# %%
#Lock-in 3c phase 
t=ten.TensorScatteringClass(CIFfile='/home/spc93/spc_cifs/Rb2ZnCl4_100K_3c.cif', Site='Zn1');
t.PlotIntensityInPolarizationChannels('E1E1', lam=12.4/9.659, hkl=np.array([7,0,0]), hkln=np.array([0,0,1]), K=2, Time=1, Parity=1, sigmapi='sigma')
t.print_tensors()
#t.PlotIntensityInPolarizationChannels('E1E2', lam=12.4/9.659, hkl=np.array([7,0,0]), hkln=np.array([0,0,1]), K=3, Time=1, Parity=-1, sigmapi='sigma')
t.PlotIntensityInPolarizationChannels('E1E1', lam=12.4/9.659, hkl=np.array([7,0,1]), hkln=np.array([0,0,1]), K=2, Time=1, Parity=1, sigmapi='sigma')
t.print_tensors()
t.PlotIntensityInPolarizationChannels('E1E1', lam=12.4/9.659, hkl=np.array([7,0,2]), hkln=np.array([0,0,1]), K=2, Time=1, Parity=1, sigmapi='sigma')
t.print_tensors()
t.PlotIntensityInPolarizationChannels('E1E1', lam=12.4/9.659, hkl=np.array([7,0,3]), hkln=np.array([0,0,1]), K=2, Time=1, Parity=1, sigmapi='sigma')
t.print_tensors()
# Out:
# Crystal properties
#
#                     CIF file:  /home/spc93/spc_cifs/Rb2ZnCl4_100K_3c.cif
#                      Lattice:  7.242 12.627 27.505 90.00 90.00 90.00
#                    All sites:  Cl1, Cl10, Cl11, Cl12, Cl2, Cl3, Cl4, Cl5, Cl6, Cl7, Cl8, Cl9, Rb1, Rb2, Rb3, Rb4, Rb5, Rb6, Zn1, Zn2, Zn3
#                Site selected:  Zn1
#                  Site vector:  -0.250 0.422 0.073
#        No. of spacegroup ops:  4
#       No. of sym ops at site:  1
#  No. of equiv. sites in cell:  4
#    No. of pg ops for crystal:  4
#
# Tensor properties
#
#              Required parity:  Even
#           Required time sym.:  Even
#                          hkl:  [7.0, 0.0, 0.0]
#                 Site allowed:  No
#    Structure factor for site:  -0.00+0.00i
#           Spacegroup allowed:  No
#               Tensor allowed:  Yes
#                       Parity:  Either
#                         Time:  Either
#                           PT:  Either
#               Glide or screw:  True
# ...
