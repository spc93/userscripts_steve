# %%
import json

path = '/dls/science/users/spc93/data/tmp/'

with open(path + 'db-dls.json', 'r') as json_file:
        dls_json = json.load(json_file)


print("Document/Investigation:" + json.dumps(dls_json['models']['Document'], indent=2))

print("Member:" + json.dumps(dls_json['models']['Member'], indent=2))    

print("Affiliation:" + json.dumps(dls_json['models']['Affiliation'], indent=2))

print("Person:" + json.dumps(dls_json['models']['Person'], indent=2)) 

print("Dataset:" + json.dumps(dls_json['models']['Dataset'], indent=2)) 

print("Sample:" + json.dumps(dls_json['models']['Sample'], indent=2))

print("DatasetSample:" + json.dumps(dls_json['models']['DatasetSample'], indent=2))

print("Instrument:" + json.dumps(dls_json['models']['Instrument'], indent=2))

print("File:" + json.dumps(dls_json['models']['File'], indent=2))
# Out:
# Document/Investigation:{
#   "MM21716-1": {
#     "doi": "",
#     "endDate": "2019-09-17 09:00:00+01:00",
#     "id": 4706882462,
#     "isPublic": "false",
#     "license": "CC-BY-4.0",
#     "pid": "",
#     "releaseDate": "",
#     "startDate": "2019-09-15 09:00:00+01:00",
#     "summary": "Superchiral light can retrieve electronic properties of matter that are invisible with traditional, classical spectroscopies. By generating precisely sculpted optical beams, coupling to chiral properties can be enhanced dramatically [1]. Our studies show that the x-ray standing-wave field in diffraction, with circularly polarized light, is an x-ray manifestation of superchiral light [2]. Notably, the corresponding spectroscopy is found to be intimately related to Borrmann spectroscopy, where we have demonstrated very strong enhancement of quadrupole absorption (E2-E2) [3, 4]. Here, we aim to demonstrate an enhancement of E2-E2 contributions to x-ray magnetic circular dichroism (XMCD) in crystals of YIG and HoIG. A successful experiment will yield valuable data to assist the theoretical interpretation of (hard) x-ray XMCD, and provide a stimulating link to classical optics.",
#     "title": "Quadrupolar X-ray Magnetic Circular Dichroism using Superchiral X-rays",
#     "type": "proposal"
#   }
# }
# Member:{
#   "51161053860": {
#     "documentId": "MM21716-1",
#     "id": 51161053860,
#     "personId": 295,
#     "role": "CO_INVESTIGATOR"
#   },
#   "51161053881": {
#     "affiliationId": 2,
#     "documentId": "MM21716-1",
#     "id": 51161053881,
#     "personId": 3223,
#     "role": "PRINCIPAL_INVESTIGATOR"
#   },
#   "51161053888": {
#     "documentId": "MM21716-1",
#     "id": 51161053888,
#     "personId": 954358103,
#     "role": "CO_INVESTIGATOR"
#   },
#   "62653442019": {
#     "affiliationId": 4,
#     "documentId": "MM21716-1",
#     "id": 62653442019,
#     "personId": 954360224,
#     "role": "CO_INVESTIGATOR"
#   }
# }
# Affiliation:{
#   "2": {
#     "id": 2,
#     "name": "Diamond Light Source"
#   },
#   "4": {
#     "id": 4,
#     "name": "University of Bath"
#   }
# }
# Person:{
#   "295": {
#     "ORCID": "",
#     "firstName": "",
#     "fullName": "Dr Private",
#     "id": 295,
#     "lastName": ""
#   },
#   "3223": {
#     "ORCID": "https://orcid.org/0000-0001-5120-0764",
#     "firstName": "Steve",
#     "fullName": "Prof Steve Collins",
#     "id": 3223,
#     "lastName": "Collins"
#   },
#   "954358103": {
#     "ORCID": "",
#     "firstName": "",
#     "fullName": "Dr Private",
#     "id": 954358103,
#     "lastName": ""
#   },
#   "954360224": {
#     "ORCID": "",
#     "firstName": "Joel",
#     "fullName": "Mr Joel Collins",
#     "id": 954360224,
#     "lastName": "Collins"
#   }
# }
# Dataset:{
#   "2875960843": {
#     "creationDate": "2019-09-19 13:29:13.803000+01:00",
#     "documentId": "MM21716-1",
#     "id": 2875960843,
#     "instrumentId": 29,
#     "isPublic": "false",
#     "pid": "",
#     "title": "topdir"
#   },
#   "2875979698": {
#     "creationDate": "2019-09-19 13:29:53.624000+01:00",
#     "documentId": "MM21716-1",
#     "id": 2875979698,
#     "instrumentId": 29,
#     "isPublic": "false",
#     "pid": "",
#     "title": "789525-pilatus3_100k-files"
#   },
#   "2875983470": {
#     "creationDate": "2019-09-19 13:30:04.148000+01:00",
#     "documentId": "MM21716-1",
#     "id": 2875983470,
#     "instrumentId": 29,
#     "isPublic": "false",
#     "pid": "",
#     "title": "789526-pilatus3_100k-files"
#   }
# }
# Sample:{
#   "718662": {
#     "id": 718662,
#     "name": "Holmium iron garnet",
#     "pid": ""
#   },
#   "718663": {
#     "id": 718663,
#     "name": "Yttrium iron garnet",
#     "pid": ""
#   }
# }
# DatasetSample:{
#   "1": {
#     "datasetId": 2875983470,
#     "id": 1,
#     "sampleId": 718662
#   },
#   "2": {
#     "datasetId": 2875983470,
#     "id": 2,
#     "sampleId": 718663
#   },
#   "3": {
#     "datasetId": 2875979698,
#     "id": 3,
#     "sampleId": 718662
#   },
#   "4": {
#     "datasetId": 2875979698,
#     "id": 4,
#     "sampleId": 718663
#   },
#   "5": {
#     "datasetId": 2875960843,
#     "id": 5,
#     "sampleId": 718662
#   },
#   "6": {
#     "datasetId": 2875960843,
#     "id": 6,
#     "sampleId": 718663
#   }
# }
# Instrument:{
#   "29": {
#     "facility": "DLS",
#     "id": 29,
#     "name": "i16",
#     "pid": ""
#   }
# }
# File:{
#   "2875979768": {
#     "datasetId": 2875979698,
#     "id": 2875979768,
#     "name": "789525-pilatus3_100k-files/00003.tif",
#     "path": "/dls/i16/data/2019/mm21716-1/789525-pilatus3_100k-files/00003.tif",
#     "size": 383956
#   },
#   "2875979769": {
#     "datasetId": 2875979698,
#     "id": 2875979769,
#     "name": "789525-pilatus3_100k-files/00001.tif",
#     "path": "/dls/i16/data/2019/mm21716-1/789525-pilatus3_100k-files/00001.tif",
#     "size": 383956
#   },
#   "2875979775": {
#     "datasetId": 2875979698,
#     "id": 2875979775,
#     "name": "789525-pilatus3_100k-files/00004.tif",
#     "path": "/dls/i16/data/2019/mm21716-1/789525-pilatus3_100k-files/00004.tif",
#     "size": 383956
#   },
#   "2875979779": {
#     "datasetId": 2875979698,
#     "id": 2875979779,
#     "name": "789525-pilatus3_100k-files/00002.tif",
#     "path": "/dls/i16/data/2019/mm21716-1/789525-pilatus3_100k-files/00002.tif",
#     "size": 383956
#   },
#   "2875985303": {
#     "datasetId": 2875983470,
#     "id": 2875985303,
#     "name": "789526-pilatus3_100k-files/00001.tif",
#     "path": "/dls/i16/data/2019/mm21716-1/789526-pilatus3_100k-files/00001.tif",
#     "size": 383956
#   },
#   "2875985329": {
#     "datasetId": 2875983470,
#     "id": 2875985329,
#     "name": "789526-pilatus3_100k-files/00017.tif",
#     "path": "/dls/i16/data/2019/mm21716-1/789526-pilatus3_100k-files/00017.tif",
#     "size": 383956
#   },
#   "2875985352": {
#     "datasetId": 2875983470,
#     "id": 2875985352,
#     "name": "789526-pilatus3_100k-files/00007.tif",
#     "path": "/dls/i16/data/2019/mm21716-1/789526-pilatus3_100k-files/00007.tif",
#     "size": 383956
#   },
#   "2875985424": {
#     "datasetId": 2875983470,
#     "id": 2875985424,
#     "name": "789526-pilatus3_100k-files/00022.tif",
#     "path": "/dls/i16/data/2019/mm21716-1/789526-pilatus3_100k-files/00022.tif",
#     "size": 383956
#   },
#   "2875986620": {
#     "datasetId": 2875960843,
#     "id": 2875986620,
#     "name": "789525.nxs",
#     "path": "/dls/i16/data/2019/mm21716-1/789525.nxs",
#     "size": 445472
#   },
#   "2875986629": {
#     "datasetId": 2875960843,
#     "id": 2875986629,
#     "name": "789526.nxs",
#     "path": "/dls/i16/data/2019/mm21716-1/789526.nxs",
#     "size": 519992
#   },
#   "2875986641": {
#     "datasetId": 2875960843,
#     "id": 2875986641,
#     "name": "789525.dat",
#     "path": "/dls/i16/data/2019/mm21716-1/789525.dat",
#     "size": 6075
#   },
#   "2875986657": {
#     "datasetId": 2875960843,
#     "id": 2875986657,
#     "name": "789526.dat",
#     "path": "/dls/i16/data/2019/mm21716-1/789526.dat",
#     "size": 34055
#   }
# }
