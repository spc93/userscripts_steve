# %%
datadir='/dls/i16/data/2018/mt18934-1/'

import sys
sys.path
sys.path.append('/dls_sw/apps/scisoftpy/2.7')
sys.path.append('/dls_sw/i16/software/python')
# %matplotlib nbagg
from matplotlib.pyplot import *
from numpy import *
from dlstools.dataloader import vec2mat
#from dlstools.quickfit import *
#from dlstools.dirty_fit import fit
from dlstools import dataloader
d=dataloader.dlsloader(datadir+'%i.dat')
p=dataloader.tiffloader(d, lambda obj: datadir+obj.pilatus2m_path_template)
psnap=dataloader.tiffloader(datadir+'snapped-data/pilatus2M/'+'%05i.tif')

# %%
d(695293)
mx, my, mz = vec2mat(d.sx, d.sy, d.sum);
#figure(); gca(projection='3d').plot(en, fcy, mpsum)
#figure();  pcolor(mx, my, mz)
#figure(figsize=(8, 6)); 
figure(); gca(projection='3d').plot_surface(mx, my, mz, cmap=cm.hot); xlabel('sx'); ylabel('sy')
figure(); imshow(mz, cmap=cm.hot); xlabel('sx'); ylabel('sy')
# Out:
# <img src="data:image/png;base64,..." width="639.8499802953507">
# <img src="data:image/png;base64,..." width="639.8499802953507">
# Text(0,0.5,u'sy')
