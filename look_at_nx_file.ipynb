# %% [markdown]
# NeXpy v0.13.3 has just been released, and the underlying nexusformat API has been updated to v0.6.1. It is available on PyPI and conda-forge. Both packages require Python v3.6 or later. It fixes issues caused by the recent release of Matplotlib v3.4.0 and adds support for new features in LMfit v1.0.2.
# To update NeXpy, type  $ pip install -U nexpy

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 
p='/dls/i16/data/2019/cm22970-1/%i.nxs'

n=pdnx(p % 734847)
# Out:
# Traceback (most recent call last):
#   File "/dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.8/lib/python3.8/site-packages/matplotlib/backends/backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "/dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.8/lib/python3.8/site-packages/matplotlib/_pylab_helpers.py", line 53, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list

# %%
n.find('features')
# Out:
# .nx.entry1.features : 	 [                   3                    6 -4539647395532570642]

# %%
n.nx.entry1.features.nxclass
# Out:
# 'NXfield'

# %%
n.find('date')

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   entry1:NXentry
#     before_scan:NXcollection
#       alpha:NXcollection
#         alpha = 4.126144034564215
#       beamline_slits:NXcollection
#         s1xcentre = -0.002
#         s1xgap = 2.498
#         s1ycentre = 0.0025
#         s1ygap = 1.001
#         s2xcentre = -2.49999999999e-05
#         s2xgap = 20.0015
#         s2ycentre = 3.20175
#         s2ygap = 20.0005
#         s3xcentre = 4.4575
#         s3xgap = 24.998
#         s3ycentre = -0.69
#         s3ygap = 20.091
#         s4xcentre = -6.01275
#         s4xgap = 31.9469
#         s4ycentre = -0.115
#         s4ygap = 25.213
#         shtr3x = 11.925
#         shtr3y = 4.24
#       beta:NXcollection
#         beta = 4.13088604572623
#       delta_offset:NXcollection
#         delta_offset = 0.0
#       dettrans:NXcollection
#         dettrans = 0.0
#       diffractometer_sample:NXcollection
#         chi = 8.26358815991
#         delta = 60.1198887888
#         delta_axis_offset = 8.8
# ...

# %%
n.plt('eta','sum')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
n.nx.entry1.title
# Out:
# NXfield('scan eta 30.039944394422584 30.079944394422583 0.001 pil3_100k 0.5')

# %%
#print n.nx.tree
n.find('transformations')
print('-----Detector------')
print(n.nx.entry1.instrument.transformations.tree)
print('-----Sample------')
print(n.nx.entry1.sample.transformations.tree)
# Out:
# .nx.entry1.instrument.pil3_100k.transformations : 	 transformations
# .nx.entry1.instrument.transformations : 	 transformations
# .nx.entry1.sample.transformations : 	 transformations
# -----Detector------
# transformations:NXtransformations
#   delta = float64(41)
#     @axis = '1'
#     @depends_on = 'entry1/instrument/transformations/gamma'
#     @local_name = 'kdelta.kdelta'
#     @target = '/entry1/instrument/transformations/delta'
#     @transformation_type = 'rotation'
#     @units = 'deg'
#     @vector = [0. 1. 0.]
#   gamma = float64(41)
#     @axis = '1'
#     @depends_on = '.'
#     @local_name = 'kgam.kgam'
#     @target = '/entry1/instrument/transformations/gamma'
#     @transformation_type = 'rotation'
#     @units = 'deg'
#     @vector = [1. 0. 0.]
#   offsetdelta = float64(41)
#     @axis = '1'
#     @depends_on = 'entry1/instrument/transformations/delta'
#     @local_name = 'delta_axis_offset.delta_axis_offset'
# ...

# %%
print(n.nx.entry1.instrument.tree)
# Out:
# instrument:NXinstrument
#   atime:NXpositioner
#     TimeSec = float64(41)
#       @local_name = 'atime.TimeSec'
#       @target = '/entry1/instrument/atime/TimeSec'
#   atimetwo:NXpositioner
#     TimeFromEpoch = float64(41)
#       @local_name = 'atimetwo.TimeFromEpoch'
#       @target = '/entry1/instrument/atimetwo/TimeFromEpoch'
#   attenuator:NXattenuator
#     attenuator_transmission = 1.88549719139e-06
#   eta:NXpositioner
#     eta = float64(41)
#       @axis = '1'
#       @label = '1'
#       @local_name = 'eta.eta'
#       @primary = '1'
#       @target = '/entry1/instrument/eta/eta'
#     soft_limit_max = 115.0
#     soft_limit_min = -22.0
#   ic1monitor:NXpositioner
#     ic1monitor = float64(41)
#       @local_name = 'ic1monitor.ic1monitor'
#       @target = '/entry1/instrument/ic1monitor/ic1monitor'
#   name = i16
#   pil3_100k:NXdetector
#     calibration_date = 2018-07-11 11:15:52
#     calibration_scan_number = 705061
#     count_time = float64(41)
# ...

# %%
n.find('title')
# Out:
# .nx.entry1.title : 	 scan eta 30.039944394422584 30.079944394422583 0.001 pil3_100k 0.5

# %%
print(n.nx.entry1.tree)
# Out:
# entry1:NXentry
#   before_scan:NXcollection
#     alpha:NXcollection
#       alpha = 4.126144034564215
#     beamline_slits:NXcollection
#       s1xcentre = -0.002
#       s1xgap = 2.498
#       s1ycentre = 0.0025
#       s1ygap = 1.001
#       s2xcentre = -2.49999999999e-05
#       s2xgap = 20.0015
#       s2ycentre = 3.20175
#       s2ygap = 20.0005
#       s3xcentre = 4.4575
#       s3xgap = 24.998
#       s3ycentre = -0.69
#       s3ygap = 20.091
#       s4xcentre = -6.01275
#       s4xgap = 31.9469
#       s4ycentre = -0.115
#       s4ygap = 25.213
#       shtr3x = 11.925
#       shtr3y = 4.24
#     beta:NXcollection
#       beta = 4.13088604572623
#     delta_offset:NXcollection
#       delta_offset = 0.0
#     dettrans:NXcollection
#       dettrans = 0.0
#     diffractometer_sample:NXcollection
#       chi = 8.26358815991
#       delta = 60.1198887888
#       delta_axis_offset = 8.8
#       en = 7.99999891729
#       eta = 30.0409318431
#       gam = 0.0
# ...

# %%
n
# Out:
#     TimeFromEpoch        TimeSec  count_time  delta_axis_offset        eta  ic1monitor        kap     kdelta  kgam  kmu        kphi        kth  maxval   maxx  maxy  path          rc      sum
# 0    1.548867e+09  708863.688522         0.5                8.8  30.039944  740.786415 -10.793954  60.119889   0.0  0.0  224.109267  33.515083  2856.0  239.0  99.0   1.0  298.672729  25646.0
# 1    1.548867e+09  708864.928955         0.5                8.8  30.040944  740.780312 -10.793954  60.119889   0.0  0.0  224.109267  33.516083  3276.0  240.0  99.0   2.0  298.665222  28076.0
# 2    1.548867e+09  708865.914431         0.5                8.8  30.041944  740.819995 -10.793954  60.119889   0.0  0.0  224.109267  33.517083  3588.0  240.0  99.0   3.0  298.660828  30048.0
# 3    1.548867e+09  708867.025306         0.5                8.8  30.042944  740.621561 -10.793954  60.119889   0.0  0.0  224.109267  33.518083  4063.0  240.0  99.0   4.0  298.650146  33255.0
# ...

# %%
n.find('command')
print(n.nx.entry1.tree)
# Out:
# entry1:NXentry
#   before_scan:NXcollection
#     alpha:NXcollection
#       alpha = 4.126144034564215
#     beamline_slits:NXcollection
#       s1xcentre = -0.002
#       s1xgap = 2.498
#       s1ycentre = 0.0025
#       s1ygap = 1.001
#       s2xcentre = -2.49999999999e-05
#       s2xgap = 20.0015
#       s2ycentre = 3.20175
#       s2ygap = 20.0005
#       s3xcentre = 4.4575
#       s3xgap = 24.998
#       s3ycentre = -0.69
#       s3ygap = 20.091
#       s4xcentre = -6.01275
#       s4xgap = 31.9469
#       s4ycentre = -0.115
#       s4ygap = 25.213
#       shtr3x = 11.925
#       shtr3y = 4.24
#     beta:NXcollection
#       beta = 4.13088604572623
#     delta_offset:NXcollection
#       delta_offset = 0.0
#     dettrans:NXcollection
#       dettrans = 0.0
#     diffractometer_sample:NXcollection
#       chi = 8.26358815991
#       delta = 60.1198887888
#       delta_axis_offset = 8.8
#       en = 7.99999891729
#       eta = 30.0409318431
#       gam = 0.0
# ...

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

#from owen arnold (hkl map)
n=pdnx('/dls/science/users/spc93/misc_nexus_data/test_qlab_binned.nxs')
# Out:
# === Failed to create DataFrame from data - create empty DataFrame

# %%
n
# Out:
# Empty pdnx
# Columns: []
# Index: []

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   @HDF5_Version = '1.8.16'
#   @NeXus_version = '4.3.2'
#   @file_name = '/Users/spu92482/Desktop/test_qlab_binned.nxs'
#   @file_time = '2019-02-01T14:38:33+00:00'
#   MDHistoWorkspace:NXentry
#     @QConvention = 'Inelastic'
#     @SaveMDVersion = 2
#     coordinate_system = 1
#     data:NXdata
#       Q1 = float64(201)
#         @frame = 'QLab'
#         @long_name = 'Q_lab_x'
#         @units = 'Angstrom^-1'
#       Q2 = float64(201)
#         @frame = 'QLab'
#         @long_name = 'Q_lab_y'
#         @units = 'Angstrom^-1'
#       Q3 = float64(201)
#         @frame = 'QLab'
#         @long_name = 'Q_lab_z'
#         @units = 'Angstrom^-1'
#       errors_squared = float64(200x200x200)
#       mask = int8(200x200x200)
#       num_events = float64(200x200x200)
#       signal = float64(200x200x200)
#         @axes = 'Q3:Q2:Q1'
#         @signal = 1
#     experiment0:NXgroup
#       @version = 1
#       instrument:NXinstrument
#         @version = 1
# ...

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

#from nick (i22)
n=pdnx('/dls/science/users/spc93/misc_nexus_data/i22_feb_2019/i22-492541.nxs')
#d=pdnx('/dls/science/users/spc93/misc_nexus_data/i22_feb_2019/i22-492541-Pilatus2M_SAXS.h5')
# Out:
# === Failed to create DataFrame from data - create empty DataFrame

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   entry1:NXentry
#     I0:NXmonitor
#       data = float32(11)
#         @signal = 1
#         @units = 'counts'
#       description = 'Data scaled by 10000 and offset by 0.0000 for gainsettin...'
#       framesetsum = float64(11)
#         @local_name = 'ncddetectors.I0'
#         @units = 'counts'
#     It:NXmonitor
#       data = float32(11)
#         @signal = 1
#         @units = 'counts'
#       description = 'Data scaled by 1.0000e+08 and offset by 0.0000 for gains...'
#       framesetsum = float64(11)
#         @local_name = 'ncddetectors.It'
#         @units = 'counts'
#     Pilatus2M_WAXS:NXdata
#       data -> i22-492541-Pilatus2M_WAXS.h5['/entry/instrument/detector/data']
#       pixel_mask -> processing/WAXS_mask.nxs['/entry/mask/mask']
#     Scalers:NXdata
#       data -> /entry1/instrument/Scalers/data
#       pxy_y -> /entry1/instrument/pxy_y/pxy_y
#     TfgTimes:NXdata
#       data -> /entry1/instrument/TfgTimes/data
# ...

# %%
n.find('It')
# Out:
# .nx.entry1.It : 	 It

# %%
#n.nx.entry1.It.data.nxentry.detector.data.nxentry.detector.data ??????????
n.nx.entry1.It.data
# Out:
# NXfield(array([9.7980e+11, 1.0415e+12, 1.0502e+12, ..., 8.8610e+11, 8.8080e+11,
#        8.8630e+11], dtype=float32))

# %%
n.pruned_tree(2)
# Out:
# .entry1
# .entry1.I0
# .entry1.It
# .entry1.Pilatus2M_WAXS
# .entry1.Scalers
# .entry1.TfgTimes
# .entry1.detector
# .entry1.end_time
# .entry1.entry_identifier
# .entry1.experiment_identifier
# .entry1.instrument
# .entry1.program_name
# .entry1.sample
# .entry1.scan_command
# .entry1.scan_dimensions
# .entry1.scan_identifier
# .entry1.start_time
# .entry1.title
# .entry1.user01

# %%
print(n.nx.entry1.instrument.tree)
# Out:
# instrument:NXinstrument
#   Pilatus2M_WAXS:NXdetector
#     beam_center_x = 1113.3020923547774
#     beam_center_y = 1139.4578400287917
#     calibration_file:NXnote
#       calibration_file = '/dls/i22/data/2019/sm20541-1/processing/WAXS_calibration.nxs'
#     count_time = float32(11)
#       @units = 's'
#     data -> i22-492541-Pilatus2M_WAXS.h5['/entry/instrument/detector/data']
#     distance = 228.10872726676257
#       @units = 'mm'
#     local_name = Pilatus2M_WAXS
#     name = 'Pilatus2M_WAXS'
#     pixel_mask -> processing/WAXS_mask.nxs['/entry/mask/mask']
#     sas_type = 'WAXS'
#     serial_number = '24-0120'
#     wait_time = float32(11)
#       @units = 's'
#     x_pixel_size = 0.172
#       @units = 'mm'
#     y_pixel_size = 0.172
#       @units = 'mm'
#   Scalers:NXdetector
#     count_time = float32(11)
#       @units = 's'
#     data = float32(11x1x9)
#       @signal = 1
#       @target = '/entry1/instrument/Scalers/data'
#       @units = 'counts'
# ...

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

#i22 example data from tutorial
n=pdnx('/dls/science/users/spc93/misc_nexus_data/i22_feb_2019/data/I22 Beamline Calibrants/i22-363051.nxs')
# Out:
# === Failed to create DataFrame from data - create empty DataFrame

# %%
print(n.nx.entry1.detector.data.nxdata.shape)
#imshow(n.nx.entry1.detector.data.nxdata)
d=n.nx.entry1.detector.data.nxdata[0][0]
imshow(d)
# Out:
# (1, 1, 1679, 1475)
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

#i22 example data with 10 images

n=pdnx('/dls/science/users/spc93/misc_nexus_data/I22 Data Analysis Examples Workspace/data/I22 Data/I22 PEG Tutorial/i22-363107.nxs')
# Out:
# === Failed to create DataFrame from data - create empty DataFrame

# %%
imshow(np.log(n.nx.entry1.instrument.detector.data.nxdata[0][3]))
n.nx.entry1.instrument.detector.data.nxdata.shape
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# (1, 10, 1679, 1475)

# %%
# %matplotlib nbagg
#read a merlin detector file
mm='/dls/i16/data/2019/mm22314-1/'
#p='/dls/i16/data/2019/cm22970-1/%i.nxs'
#n=pdnx(p % )
n=746517
m = pdnx('/dls/i16/data/2019/mm22314-1/%i-merlin%i.hdf5' % (n, n))
figure()
imshow(m.nx.entry.data.data[0])
print(m.nx.tree)
# Out:
# ...
# === Error loading file /dls/i16/data/2019/mm22314-1/746517-merlin746517.hdf5
# <img src="data:image/png;base64,..." width="639.9999861283738">
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-47-1f490324bbf7> in <module>
#       7 m = pdnx('/dls/i16/data/2019/mm22314-1/%i-merlin%i.hdf5' % (n, n))
#       8 figure()
# ----> 9 imshow(m.nx.entry.data.data[0])
#      10 print(m.nx.tree)
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.8/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5269             return object.__getattribute__(self, name)
#    5270         else:
# -> 5271             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5272                 return self[name]
#    5273             return object.__getattribute__(self, name)
#
# ...

# %%
#read a merlin detector file
p='/dls/i16/data/2019/mm22314-1/%i.nxs'
n=pdnx(p % 746517)
# Out:
# === Error loading file /dls/i16/data/2019/mm22314-1/746517.nxs

# %%
n
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /dls_sw/apps/python/anaconda/1.7.0/64/envs/python3/lib/python3.6/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     700                 type_pprinters=self.type_printers,
#     701                 deferred_pprinters=self.deferred_printers)
# --> 702             printer.pretty(obj)
#     703             printer.flush()
#     704             return stream.getvalue()
#
# /dls_sw/apps/python/anaconda/1.7.0/64/envs/python3/lib/python3.6/site-packages/IPython/lib/pretty.py in pretty(self, obj)
#     400                         if cls is not object \
#     401                                 and callable(cls.__dict__.get('__repr__')):
# --> 402                             return _repr_pprint(obj, self, cycle)
#     403
#     404             return _default_pprint(obj, self, cycle)
#
# ...

# %%
print n.nx.tree
# Out:
#   File "<ipython-input-36-7bae13f4d956>", line 1
#     print n.nx.tree
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(n.nx.tree)?

# %%
n.find('merlin')

# %%
print n.nx.entry1.merlin.tree

# %%
##### look at new attributes
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 
p='/dls/i16/data/2019/mm22052-1/%i.nxs'

n=pdnx(p % 777946)

# %%
n

# %%
#n.nx.entry1.pil3_100k.plot()

# %%
print n.nx.tree

# %%
n.find('title')

# %%
n['ratio']=n['sum']/n['ic1monitor']

# %%
n

# %%
n.plt('eta','ratio')

# %%
n.find('Tb')

# %%
n['Tb']=n.nx.entry1.before_scan.lakeshore.Tb

# %%
n

# %%
##### load file, set attributes, save file
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 
p='/dls/i16/data/2019/mm22052-1/%i.nxs'

n=pdnx(p % 777946)

#n.nx.entry1.attrs['default'] = 'measurement'
n.nx.entry1.measurement.attrs['axes'] = 'eta'
#
##
###
#####
############# save new nexus file
s='/dls/i16/data/2019/mm22052-1/processing/%i.nxs'



nx.nxsave(s % 777946, n.nx)

# %%
new = pdnx(s % 777946)
new.nx.plot(linestyle='-')

# %%
print new.nx.tree

# %%
new.find('measurement')
print new.nx.entry1.measurement.tree

# %%
#ne = pdnx('/dls/science/users/spc93/misc_nexus_data/example.nxs')
ne = pdnx('/dls/science/users/spc93/misc_nexus_data/chopper.nxs')
print ne.nx.tree
ne.nx.plot()

# %%
ne.find('monitor1')

# %%
ne.nx.entry.monitor1.plot()

# %%
#p='/dls/i16/data/2019/mm22132-1/%i.nxs'
#n=pdnx(p % 778086)

p='/dls/i16/data/2019/mm21918-1/%i.nxs'
n=pdnx(p % 780431)

# %%
n.nx.plot()

# %%
n

# %%
print n.nx.tree

# %%
#ESRF examples

import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 



esrf1 = pdnx('/dls/science/users/spc93/misc_nexus_data/ESRF/xanes_new_py3.h5', entry = '207.1') #several entries

esrf2 = pdnx('/dls/science/users/spc93/misc_nexus_data/ESRF/test.h5', entry = 'entry154')

# %%
esrf1.plt('arr_energy','xmap_nika07')
figure(); esrf1.nx.plot()
esrf1

# %%
#print esrf1.nx.tree
#print esrf1.pruned_tree(2)
esrf1.find('plotselect')
esrf1.nx['202.1'].plotselect

# %%
print esrf1.nx['202.1'].tree

# %%
esrf2.nx.plot()

# %%
#print esrf2.nx.entry154.tree
dd=esrf2.nx.entry154.measurement.oned03

imshow(dd, aspect='auto')

# %%
esrf1.nx.plot()

# %%
#esrf1.nx['208.1'].att
esrf1.nx.attrs['default'] = '208.1'

# %%
esrf1.nx.plot()

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

n=pdnx('/dls/science/users/spc93/misc_nexus_data/soleil/MoS2_sample3_hkl_scan_00370.nxs')

# %%
n.nx

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

n=pdnx('/dls/science/users/spc93/misc_nexus_data/argonne/lmn40.nxs', entry = '/scan_1', measurement='/data')
n.nx.plot()
n

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

n=pdnx('/dls/science/users/spc93/misc_nexus_data/i15-1/i15-1-26743.nxs')
#n=pdnx('/dls/science/users/spc93/misc_nexus_data/i15-1/i15-1-26734-clusterProcessing2.nxs')

# %%
n.nx.plot()
# Out:
# ---------------------------------------------------------------------------
# NeXusError                                Traceback (most recent call last)
# <ipython-input-4-98590cfed531> in <module>
# ----> 1 n.nx.plot()
#
# /dls_sw/apps/python/anaconda/1.7.0/64/envs/python3/lib/python3.6/site-packages/nexusformat/nexus/tree.py in plot(self, **opts)
#    3808         plotdata = self.plottable_data
#    3809         if plotdata:
# -> 3810             plotdata.plot(**opts)
#    3811         else:
#    3812             raise NeXusError("There is no plottable data")
#
# /dls_sw/apps/python/anaconda/1.7.0/64/envs/python3/lib/python3.6/site-packages/nexusformat/nexus/tree.py in plot(self, fmt, xmin, xmax, ymin, ymax, zmin, zmax, **opts)
#    4952             raise NeXusError("No plotting signal defined")
#    4953         elif not signal.exists():
# -> 4954             raise NeXusError("Data for '%s' does not exist" % signal.nxpath)
#    4955         elif not signal.is_plottable():
# ...

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   @file_name = '/dls/i15-1/data/2019/cm22963-1/i15-1-26743.nxs'
#   entry:NXentry
#     duration = 13
#       @units = 's'
#     end_time = '2019-02-22T14:47:36.543Z'
#     experiment_identifier = 'cm22963-1'
#     instrument:NXinstrument
#       endstation:NXcollection
#         beam_stop:NXbeam_stop
#           description = 'circular'
#           motors:NXcollection
#             bs1X:NXpositioner
#               acceleration_time = 1.0
#               controller_record = 'BL15J-MO-SMAR-01:X'
#               description = 'Beam-stop 1 X piezo motor, SmarAct SLC-2430-D-M-E'
#               name = 'bs1X'
#               raw_value = -9825.532000000001
#                 @units = 'um'
#               soft_limit_max = 30000.0
#                 @units = 'um'
#               soft_limit_min = -30000.0
#                 @units = 'um'
#               target_value = -9825.55495801959
#                 @units = 'um'
#               tolerance = 750.328
# ...

# %%
#HZB test file with NXtransformations from Matt Jones

import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

#i22 example data from tutorial
n=pdnx('/dls/science/users/spc93/misc_nexus_data/HZB/V20_example.nxs')
print(n.nx.tree)
# Out:
# root:NXroot
#   entry:NXentry
#     features = [10138143369737381149 13302235172809145823]
#     instrument:NXinstrument
#       Lin1:NXpositioner
#         controller_record = 'HZB-V20:MC-MCU-01:m12.VAL'
#         value:NXgroup
#         value_status:NXgroup
#         value_target:NXgroup
#         value_velocity:NXgroup
#       Omega_1:NXpositioner
#         controller_record = 'HZB-V20:MC-MCU-01:m10.VAL'
#         value:NXgroup
#         value_status:NXgroup
#         value_target:NXgroup
#         value_velocity:NXgroup
#       Omega_2:NXpositioner
#         controller_record = 'HZB-V20:MC-MCU-01:m11.VAL'
#         value:NXgroup
#         value_status:NXgroup
#         value_target:NXgroup
#         value_velocity:NXgroup
#       Slit3:NXslit
#         x_center:NXgroup
#         x_center_status:NXgroup
#         x_center_target:NXgroup
#         x_center_velocity:NXgroup
#         x_gap:NXgroup
#         x_gap_status:NXgroup
#         x_gap_target:NXgroup
# ...

# %%
#I16 test with .hdf5 file

import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

#p='/dls/i16/data/2020/cm26473-1/%i.nxs' # this one works
#n=pdnx(p % 807001)


#p='/dls/i16/data/2020/mm25913-2/%i.nxs'
#n=pdnx(p % 828097)
#figure()
#imshow(n.nx.entry1.pilatus3.data[1])

p='/dls/i16/data/2020/mm25913-2/%i.nxs'
#n=pdnx(p % 828098)
#n=pdnx(p % 828101) #ok
n=pdnx(p % 828103)
figure()
#imshow(n.nx.entry1.pil3_100k.data[1])
imshow(n.nx.entry1.kthZebraPil3.data[1])


#p='/dls/i16/data/2020/mm23667-1/%i.nxs'
#n=pdnx(p % 810000)

#print(n.nx.tree)
#print(n.nx.entry1.pil3_100k.tree)
#print(n.nx.entry1.pil3_100k.data.shape, sum(sum(sum(n.nx.entry1.pil3_100k.data))) )
#print([sum(sum(n.nx.entry1.pil3_100k.data[i])) for i in range(n.nx.entry1.pil3_100k.data.shape[0])])
    
#figure()
#imshow(n.nx.entry1.pil3_100k.data[1])
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   entry1:NXentry
#     before_scan:NXcollection
#       PPR:NXcollection
#         ppchi = -44.996622923
#         pppiezo1 = 0.0
#         pppiezo2 = 12345.01236
#         ppth1 = 2.6375121968
#         ppth2 = -13.3799469544
#         ppz1 = 12.0
#         ppz2 = 12.0
#       alpha:NXcollection
#         alpha = -56.87769479
#       beamline_slits:NXcollection
#         s1xcentre = -0.0055
#         s1xgap = 2.511
#         s1ycentre = 0.001
#         s1ygap = 1.0
#         s2xcentre = -0.00079375
#         s2xgap = 4.9988625
#         s2ycentre = 0.499
#         s2ygap = 20.0
#         s3xcentre = 2.69725
#         s3xgap = 25.0015
#         s3ycentre = -0.682
#         s3ygap = 20.125
#         s4xcentre = -5.875
#         s4xgap = 36.6504
#         s4ycentre = 0.0
#         s4ygap = 28.005
#         shtr3x = 11.93
#         shtr3y = 4.32
#       beta:NXcollection
#         beta = 56.8734810283
#       delta_offset:NXcollection
#         delta_offset = 0.0
# ...

# %% [raw]
# data -> 807001-pilatus3_100k-files/807001.hdf['/entry/instrument/detector/data']

# %%
n.nx.entry1.pil3_100k.data_new = n.nx.entry1.pil3_100k.data
# Out:
# NeXusErrorTraceback (most recent call last)
# <ipython-input-16-5cd0a7606e35> in <module>()
# ----> 1 n.nx.entry1.pil3_100k.data_new = n.nx.entry1.pil3_100k.data
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/cctbx/lib/python2.7/site-packages/nexusformat/nexus/tree.pyc in __setattr__(self, name, value)
#    4604             object.__setattr__(self, name, value)
#    4605         else:
# -> 4606             super(NXdata, self).__setattr__(name, value)
#    4607
#    4608     def __getitem__(self, key):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/cctbx/lib/python2.7/site-packages/nexusformat/nexus/tree.pyc in __setattr__(self, name, value)
#    3371             self._attrs[name] = value
#    3372         else:
# -> 3373             self[name] = value
#    3374
#    3375     def __delattr__(self, name):
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/cctbx/lib/python2.7/site-packages/nexusformat/nexus/tree.pyc in __setitem__(self, idx, value)
# ...

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   entry1:NXentry
#     before_scan:NXcollection
#       PPR:NXcollection
#         ppchi = -44.999887279
#         pppiezo1 = 0.0
#         pppiezo2 = 12345.01236
#         ppth1 = -5.6770335804
#         ppth2 = 6.10168e-05
#         ppz1 = 12.0
#         ppz2 = 11.0
#       alpha:NXcollection
#         alpha = 69.3484084028
#       beamline_slits:NXcollection
#         s1xcentre = -0.005
#         s1xgap = 2.51
#         s1ycentre = 0.0015
#         s1ygap = 0.999
#         s2xcentre = -0.00079375
#         s2xgap = 4.9988625
#         s2ycentre = 0.499
#         s2ygap = 20.001
#         s3xcentre = 2.69725
#         s3xgap = 25.0015
#         s3ycentre = -0.682
#         s3ygap = 20.125
#         s4xcentre = -5.875
#         s4xgap = 36.6504
#         s4ycentre = 0.0
#         s4ygap = 28.005
#         shtr3x = 11.93
#         shtr3y = 4.25
#       beta:NXcollection
#         beta = -69.3486385109
#       delta_offset:NXcollection
#         delta_offset = 0.0
# ...

# %%
#I16 test with hklmapper file

c

# %%
print(n.nx.tree)
n.nx.entry1.reciprocal_space.plot()
# Out:
# root:NXroot
#   @default = 'processed'
#   entry0:NXentry -> /dls/i16/data/2019/cm22970-1/736956.nxs['/entry1']
#     before_scan:NXcollection
#       alpha:NXcollection
#         alpha = 5.005025085674024
#       beamline_slits:NXcollection
#         s1xcentre = -0.002
#         s1xgap = 2.498
#         s1ycentre = 0.0025
#         s1ygap = 1.001
#         s2xcentre = -2.49999999999e-05
#         s2xgap = 20.0015
#         s2ycentre = 3.20175
#         s2ygap = 20.0005
#         s3xcentre = 4.45725
#         s3xgap = 24.9975
#         s3ycentre = -0.69
#         s3ygap = 20.091
#         s4xcentre = -6.01275
#         s4xgap = 31.9469
#         s4ycentre = -0.115
#         s4ygap = 25.213
#         shtr3x = 11.925
#         shtr3y = 4.24
#       beta:NXcollection
#         beta = 24.99500634937908
#       delta_offset:NXcollection
#         delta_offset = 0.0
#       dettrans:NXcollection
#         dettrans = 0.0
#       diffractometer_sample:NXcollection
# ...

# %%
n
# Out:
#     TimeFromEpoch       TimeSec  count_time  delta_axis_offset    eta  ic1monitor         kap  kdelta  kgam  kmu       kphi        kth  maxval   maxx   maxy  path        rc   sum
# 0    1.549371e+09  1.212853e+06         0.5                0.0  5.000    0.348022 -134.755927    30.0   0.0  0.0  57.045165  62.045165     2.0   34.0   19.0   1.0 -0.019483  -7.0
# 1    1.549371e+09  1.212855e+06         0.5                0.0  5.005    0.320545 -134.755927    30.0   0.0  0.0  57.045165  62.050165     2.0   41.0  113.0   2.0 -0.019700 -11.0
# 2    1.549371e+09  1.212857e+06         0.5                0.0  5.010    0.357181 -134.755927    30.0   0.0  0.0  57.045165  62.055165     0.0    0.0    0.0   3.0 -0.019003 -16.0
# 3    1.549371e+09  1.212859e+06         0.5                0.0  5.015    0.427398 -134.755927    30.0   0.0  0.0  57.045165  62.060165     2.0  213.0  126.0   4.0 -0.018856   3.0
# ...

# %%
#I16 test with modifies NXclassic_scan subentry

import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

p='/dls/science/users/spc93/misc_nexus_data/modified/%i.nxs'

#n=pdnx(p % 815893) # use old version with fixed fields
n=pdnx(p % 815893, entry = None, data = None) # new version with NXclassic_scan

# %%
n
# Out:
#        eta  beamOK    kphi        kap       kth  kmu  kdelta  kgam  delta_axis_offset     TimeSec  TimeFromEpoch   ic1monitor        rc  count_time  path  maxx  maxy  maxval   sum  roi2_maxx  roi2_maxy  roi2_maxval  roi2_sum
# 0   30.968       1  64.357 -135.59775  88.55597  0.0  64.693   0.0                8.8  361029.445   1.582424e+09  2160.062235  298.0396         1.0     1   270     7     4.0  2109          4          1          2.0        69
# 1   30.988       1  64.357 -135.59775  88.57597  0.0  64.693   0.0                8.8  361031.739   1.582424e+09  2161.649749  298.0182         1.0     2   200   108     5.0  2061         26          3          2.0        65
# 2   31.008       1  64.357 -135.59775  88.59597  0.0  64.693   0.0                8.8  361034.027   1.582424e+09  2160.733886  297.9983         1.0     3   100   160     6.0  1986          7          9          2.0        62
# ...

# %%
n.nx.plot()
# Out:
# <img src="data:image/png;base64,..." width="422.727263564906">

# %%
import xlrd

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

#Example data from J08 in NXcxi_ptycho format
#============================================
#Everything under entry_1 inside the i08-1-*.nxs file is relevant here.
#The data is raw, but dark image is provided. The DAWN pre-processed data is in "processed".


p='/dls/science/users/spc93/misc_nexus_data/NXcxi_ptycho_example/i08-1-2121_dawn_processed.nxs'
n=pdnx(p)
# Out:
# === Failed to create DataFrame from data - create empty DataFrame

# %%
#print(n.nx.tree)

# %%
print(n.nx.entry.tree)
# Out:
# entry:NXentry
#   I0:NXdata
#     @SampleX_value_indices = [0 1 2]
#     @SampleX_value_set_indices = 0
#     @SampleY_value_indices = [0 1 2]
#     @SampleY_value_set_indices = 0
#     @axes = ['SampleX_value_set', '.', '.']
#     @signal = 'data'
#     SampleX_value = float64(79x1x1)
#       @NDAttrDescription = 'sample value'
#       @NDAttrName = 'INENC3.VAL.Mean'
#       @NDAttrSource = 'Driver'
#       @NDAttrSourceType = 'NDAttrSourceDriver'
#     SampleX_value_set = float64(79)
#       @units = 'mm'
#     SampleY_value = float64(79x1x1)
#       @NDAttrDescription = 'sample value'
#       @NDAttrName = 'INENC4.VAL.Mean'
#       @NDAttrSource = 'Driver'
#       @NDAttrSourceType = 'NDAttrSourceDriver'
#     SampleY_value_set = float64(79)
#       @units = 'mm'
#     data = float64(79x1x1)
#       @NDAttrDescription = 'sample value'
#       @NDAttrName = 'COUNTER1.OUT.Diff'
#       @NDAttrSource = 'Driver'
#       @NDAttrSourceType = 'NDAttrSourceDriver'
#   andor2:NXdata
# ...

# %%
print(n.nx.entry_1.tree)
# Out:
# entry_1:NXentry
#   data:NXdata
#     @axes = ['x_set', '.', '.']
#     @signal = 'data'
#     @x_indices = [0 1 2]
#     @x_set_indices = 0
#     @y_indices = [0 1 2]
#     @y_set_indices = 0
#     data = uint16(79x512x512)
#       @NDArrayDimBinning = [1 1]
#       @NDArrayDimOffset = [0 0]
#       @NDArrayDimReverse = [0 0]
#       @NDArrayNumDims = 2
#     x = float64(79x1x1)
#       @NDAttrDescription = 'sample value'
#       @NDAttrName = 'INENC3.VAL.Mean'
#       @NDAttrSource = 'Driver'
#       @NDAttrSourceType = 'NDAttrSourceDriver'
#     x_set = float64(79)
#       @units = 'mm'
#     y = float64(79x1x1)
#       @NDAttrDescription = 'sample value'
#       @NDAttrName = 'INENC4.VAL.Mean'
#       @NDAttrSource = 'Driver'
#       @NDAttrSourceType = 'NDAttrSourceDriver'
#     y_set = float64(79)
#       @units = 'mm'
#   data_1:NXcollection
#     data = uint16(79x512x512)
#       @NDArrayDimBinning = [1 1]
#       @NDArrayDimOffset = [0 0]
#       @NDArrayDimReverse = [0 0]
# ...

# %%
print(n.nx.processed.tree)
# Out:
# processed:NXentry
#   @default = 'result'
#   live:NXcollection
#     finished = 1
#   process:NXprocess
#     0:NXnote
#       data = '{"startFrame":0,"endFrame":1,"scaling":1.0,"datasetName"...'
#       id = 'uk.ac.diamond.scisoft.analysis.processing.operations.int...'
#       name = 'Subtract Frame'
#       passed = 0
#       saved = 0
#       type = 'application/json'
#     1:NXnote
#       data = '{"windowFraction":0.5}'
#       id = 'uk.ac.diamond.scisoft.analysis.processing.operations.bac...'
#       name = 'Top Bottom Profile Subtraction'
#       passed = 0
#       saved = 0
#       type = 'application/json'
#     2:NXnote
#       data = '{"upper":null,"lower":0.0}'
#       id = 'uk.ac.diamond.scisoft.analysis.processing.operations.thr...'
#       name = 'Threshold Mask'
#       passed = 0
#       saved = 0
#       type = 'application/json'
#     3:NXnote
#       data = '{"invalidation":"ZEROS"}'
#       id = 'uk.ac.diamond.scisoft.analysis.processing.operations.mas...'
# ...

# %%
n.nx.
# Out:
# NeXusErrorTraceback (most recent call last)
# <ipython-input-29-90be0cc8f555> in <module>()
# ----> 1 n.nx.processed.plot()
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/cctbx/lib/python2.7/site-packages/nexusformat/nexus/tree.pyc in plot(self, **opts)
#    3820         plotdata = self.plottable_data
#    3821         if plotdata:
# -> 3822             plotdata.plot(**opts)
#    3823         else:
#    3824             raise NeXusError("There is no plottable data")
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/cctbx/lib/python2.7/site-packages/nexusformat/nexus/tree.pyc in plot(self, fmt, xmin, xmax, ymin, ymax, vmin, vmax, **opts)
#    4980
#    4981         plotview.plot(self, fmt, xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax,
# -> 4982                       vmin=vmin, vmax=vmax, **opts)
#    4983
#    4984     def oplot(self, fmt='', **opts):
#
# ...

# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

p='/dls/i16/data/2021/cm28156-2/%i.nxs'

#n=pdnx(p % 879919)
n=pdnx(p % 880659)
# Out:
# Traceback (most recent call last):
#   File "/dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
#   File "/dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.8/lib/python3.8/site-packages/matplotlib/backends/backend_nbagg.py", line 236, in <lambda>
#     canvas.mpl_connect('close_event', lambda event: Gcf.destroy(num))
#   File "/dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.8/lib/python3.8/site-packages/matplotlib/_pylab_helpers.py", line 53, in destroy
#     cls._activeQue.remove(manager)
# ValueError: list.remove(x): x not in list
# Traceback (most recent call last):
#   File "/dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.8/lib/python3.8/site-packages/matplotlib/cbook/__init__.py", line 216, in process
#     func(*args, **kwargs)
# ...

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   entry1:NXentry
#     before_scan:NXcollection
#       PPR:NXcollection
#         ppchi = -44.999696604
#         pppiezo1 = 0.0
#         pppiezo2 = 12345.012359999999
#         ppth1 = 0.0007169474
#         ppth2 = -11.9993045666
#         ppz1 = 12.0
#         ppz2 = 12.0
#       alpha:NXcollection
#         alpha = 1.5270628363829852
#       beamline_slits:NXcollection
#         s1xcentre = -0.0045
#         s1xgap = 2.511
#         s1ycentre = 0.005
#         s1ygap = 0.9
#         s2xcentre = -0.00079375
#         s2xgap = 4.9988625
#         s2ycentre = 0.49775
#         s2ygap = 20.0005
#         s3xcentre = 2.34725
#         s3xgap = 24.9995
#         s3ycentre = -0.65
#         s3ygap = 20.0
#         s4xcentre = -5.875
#         s4xgap = 36.6504
#         s4ycentre = 0.00025
#         s4ygap = 28.0045
#         shtr3x = 11.93
#         shtr3y = 4.355
#       beta:NXcollection
#         beta = -12.2348538453221
#       delta_offset:NXcollection
# ...

# %%
n
# Out:
#     TimeFromEpoch        TimeSec  delta_axis_offset     diode  ic1monitor        kap  kdelta      kgam       kmu      kphi        kth        rc     x
# 0    1.617025e+09  359506.602396                0.0 -1.887020    0.616673 -63.521575    50.0  0.000005 -0.000002 -4.300589  49.599411  0.096232   1.0
# 1    1.617025e+09  359506.620079                0.0 -1.887020    0.616673 -63.521575    50.0  0.000005 -0.000002 -4.300589  49.599411  0.096232   2.0
# 2    1.617025e+09  359506.626297                0.0 -1.887020    0.616673 -63.521575    50.0  0.000005 -0.000002 -4.300589  49.599411  0.096232   3.0
# 3    1.617025e+09  359506.633165                0.0 -1.887020    0.616673 -63.521575    50.0  0.000005 -0.000002 -4.300589  49.599411  0.096232   4.0
# ..            ...            ...                ...       ...         ...        ...     ...       ...       ...       ...        ...       ...   ...
# ...

# %%
n.nx.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-98590cfed531> in <module>
# ----> 1 n.nx.plot()
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.8/lib/python3.8/site-packages/nexusformat/nexus/tree.py in plot(self, **kwargs)
#    4743         plotdata = self.plottable_data
#    4744         if plotdata:
# -> 4745             plotdata.plot(**kwargs)
#    4746         else:
#    4747             raise NeXusError("There is no plottable data")
#
# /dls_sw/apps/python/anaconda/4.6.14/64/envs/python3.8/lib/python3.8/site-packages/nexusformat/nexus/tree.py in plot(self, fmt, xmin, xmax, ymin, ymax, vmin, vmax, **kwargs)
#    6208             from .plot import plotview
#    6209
# -> 6210         plotview.plot(self, fmt, xmin=xmin, xmax=xmax, ymin=ymin, ymax=ymax,
#    6211                       vmin=vmin, vmax=vmax, **kwargs)
#    6212
#
# ...

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   entry1:NXentry
#     before_scan:NXcollection
#       PPR:NXcollection
#         ppchi = -44.999780501
#         pppiezo1 = 0.0
#         pppiezo2 = 12345.012359999999
#         ppth1 = 0.0005186428
#         ppth2 = -11.9994266002
#         ppz1 = 12.0
#         ppz2 = 12.0
#       alpha:NXcollection
#         alpha = -0.8150845779019144
#       beamline_slits:NXcollection
#         s1xcentre = -0.0045
#         s1xgap = 2.511
#         s1ycentre = 0.0055
#         s1ygap = 0.899
#         s2xcentre = -0.00079375
#         s2xgap = 4.9988625
#         s2ycentre = 0.49775
#         s2ygap = 20.0005
#         s3xcentre = 2.34725
#         s3xgap = 24.9995
#         s3ycentre = -0.65
#         s3ygap = 20.0
#         s4xcentre = -5.875
#         s4xgap = 36.6504
#         s4ycentre = 0.00025
#         s4ygap = 28.0045
#         shtr3x = 11.93
#         shtr3y = 4.355
#       beta:NXcollection
#         beta = 0.8150845779019144
#       delta_offset:NXcollection
# ...

# %%
# recent random file to check plotting tags

import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 

p='/dls/i16/data/2021/mm27800-1/%i.nxs'
n=pdnx(p % 874358)

# %%
n.nx.plot()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
print(n.nx.tree)
# Out:
# root:NXroot
#   entry1:NXentry
#     before_scan:NXcollection
#       PPR:NXcollection
#         ppchi = -44.999696604
#         pppiezo1 = 0.0
#         pppiezo2 = 12345.012359999999
#         ppth1 = 0.0007169474
#         ppth2 = -11.9993045666
#         ppz1 = 12.0
#         ppz2 = 12.0
#       alpha:NXcollection
#         alpha = 1.5270628363829852
#       beamline_slits:NXcollection
#         s1xcentre = -0.0045
#         s1xgap = 2.511
#         s1ycentre = 0.005
#         s1ygap = 0.9
#         s2xcentre = -0.00079375
#         s2xgap = 4.9988625
#         s2ycentre = 0.49775
#         s2ygap = 20.0005
#         s3xcentre = 2.34725
#         s3xgap = 24.9995
#         s3ycentre = -0.65
#         s3ygap = 20.0
#         s4xcentre = -5.875
#         s4xgap = 36.6504
#         s4ycentre = 0.00025
#         s4ygap = 28.0045
#         shtr3x = 11.93
#         shtr3y = 4.355
#       beta:NXcollection
#         beta = -12.2348538453221
#       delta_offset:NXcollection
# ...

# %%
n.nx.entry1.title
# Out:
# NXfield('scan x 1 10 1 ps diode')

# %%
n
# Out:
#     TimeFromEpoch        TimeSec  delta_axis_offset     diode  ic1monitor        kap  kdelta      kgam       kmu      kphi        kth        rc     x
# 0    1.617025e+09  359506.602396                0.0 -1.887020    0.616673 -63.521575    50.0  0.000005 -0.000002 -4.300589  49.599411  0.096232   1.0
# 1    1.617025e+09  359506.620079                0.0 -1.887020    0.616673 -63.521575    50.0  0.000005 -0.000002 -4.300589  49.599411  0.096232   2.0
# 2    1.617025e+09  359506.626297                0.0 -1.887020    0.616673 -63.521575    50.0  0.000005 -0.000002 -4.300589  49.599411  0.096232   3.0
# 3    1.617025e+09  359506.633165                0.0 -1.887020    0.616673 -63.521575    50.0  0.000005 -0.000002 -4.300589  49.599411  0.096232   4.0
# ..            ...            ...                ...       ...         ...        ...     ...       ...       ...       ...        ...       ...   ...
# ...
