# %%
import sys
sys.path.append('/dls_sw/i16/software/python')
from dlstools.pdnx import *
from matplotlib.pyplot import *
# %matplotlib notebook 
p='/dls/i16/data/2019/cm22970-1/%i.nxs'

n=pdnx(p % 734847)

# %%
n
# Out:
#     TimeFromEpoch        TimeSec  count_time  delta_axis_offset        eta  ic1monitor        kap     kdelta  kgam  kmu        kphi        kth  maxval   maxx  maxy  path          rc      sum
# 0    1.548867e+09  708863.688522         0.5                8.8  30.039944  740.786415 -10.793954  60.119889   0.0  0.0  224.109267  33.515083  2856.0  239.0  99.0   1.0  298.672729  25646.0
# 1    1.548867e+09  708864.928955         0.5                8.8  30.040944  740.780312 -10.793954  60.119889   0.0  0.0  224.109267  33.516083  3276.0  240.0  99.0   2.0  298.665222  28076.0
# 2    1.548867e+09  708865.914431         0.5                8.8  30.041944  740.819995 -10.793954  60.119889   0.0  0.0  224.109267  33.517083  3588.0  240.0  99.0   3.0  298.660828  30048.0
# 3    1.548867e+09  708867.025306         0.5                8.8  30.042944  740.621561 -10.793954  60.119889   0.0  0.0  224.109267  33.518083  4063.0  240.0  99.0   4.0  298.650146  33255.0
# ..            ...            ...         ...                ...        ...         ...        ...        ...   ...  ...         ...        ...     ...    ...   ...   ...         ...      ...
# 37   1.548867e+09  708906.822007         0.5                8.8  30.076944  739.998775 -10.793954  60.119889   0.0  0.0  224.109267  33.552083  1039.0  242.0  96.0  38.0  298.383942  15212.0
# 38   1.548867e+09  708907.922379         0.5                8.8  30.077944  739.992667 -10.793954  60.119889   0.0  0.0  224.109267  33.553083   930.0  242.0  96.0  39.0  298.378723  14045.0
# 39   1.548867e+09  708908.924138         0.5                8.8  30.078944  740.130049 -10.793954  60.119889   0.0  0.0  224.109267  33.554083   750.0  242.0  96.0  40.0  298.369507  12197.0
# 40   1.548867e+09  708910.139862         0.5                8.8  30.079944  739.974349 -10.793954  60.119889   0.0  0.0  224.109267  33.555083   650.0  242.0  96.0  41.0  298.362854  10926.0
#
# [41 rows x 18 columns]

# %%
n.find('before_scan')
# Out:
# .nx.entry1.before_scan : 	before_scan

# %%
n.nx.plot()
# Out:
# ---------------------------------------------------------------------------
# NeXusError                                Traceback (most recent call last)
# <ipython-input-11-98590cfed531> in <module>()
# ----> 1 n.nx.plot()
#
# /dls_sw/apps/python/anaconda/1.7.0/64/envs/cctbx/lib/python2.7/site-packages/nexusformat/nexus/tree.pyc in plot(self, **opts)
#    3820         plotdata = self.plottable_data
#    3821         if plotdata:
# -> 3822             plotdata.plot(**opts)
#    3823         else:
#    3824             raise NeXusError("There is no plottable data")
#
# /dls_sw/apps/python/anaconda/1.7.0/64/envs/cctbx/lib/python2.7/site-packages/nexusformat/nexus/tree.pyc in plot(self, fmt, xmin, xmax, ymin, ymax, vmin, vmax, **opts)
#    4962         signal = self.nxsignal
#    4963         if signal is None:
# -> 4964             raise NeXusError("No plotting signal defined")
#    4965         elif not signal.exists():
#    4966             raise NeXusError("Data for '%s' does not exist" % signal.nxpath)
#
# NeXusError: No plotting signal defined

# %%
n.nx.entry1.before_scan.keys()
# Out:
# [u'mirrors',
#  u'gains_atten',
#  u's7xtrans',
#  u'pp',
#  u'source',
#  u'offsets',
#  u'beamline_slits',
#  u'pa',
#  u'mono',
#  u'lakeshore',
#  u'psi',
#  u's7ytrans',
#  u'dettrans',
#  u'beta',
#  u'alpha',
#  u'mrwolf',
#  u's7xgap',
#  u'diffractometer_sample',
#  u's7ygap',
#  u'positions',
#  u'jjslits',
#  u'delta_offset',
#  u'dummypd']

# %%
n.nx.entry1.measurement.keys()
# Out:
# [u'kdelta',
#  u'maxx',
#  u'maxy',
#  u'maxval',
#  u'count_time',
#  u'sum',
#  u'eta',
#  u'kgam',
#  u'kmu',
#  u'TimeFromEpoch',
#  u'kth',
#  u'TimeSec',
#  u'rc',
#  u'path',
#  u'ic1monitor',
#  u'kphi',
#  u'delta_axis_offset',
#  u'kap']
